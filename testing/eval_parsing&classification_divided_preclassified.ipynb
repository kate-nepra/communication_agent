# %%
from dotenv import load_dotenv
import os
from src.agents.api_agent import LocalApiAgent, OpenAIApiAgent

load_dotenv()
mixtral = LocalApiAgent("http://localhost:8881/v1/", "ollama", "mixtral")
llama3_70 = LocalApiAgent("http://localhost:8881/v1/", "ollama", "llama3:70b")
llama2_70 = LocalApiAgent("http://localhost:8881/v1/", "ollama", "llama2:70b")
llama3_8 = LocalApiAgent("http://localhost:8881/v1/", "ollama", "llama3:8b")
gpt3 = OpenAIApiAgent("https://api.openai.com/v1", os.getenv("OPENAI_API_KEY"), "gpt-3.5-turbo-0125")
gpt4 = OpenAIApiAgent("https://api.openai.com/v1", os.getenv("OPENAI_API_KEY"), "gpt-4-turbo")

# %%
import pandas as pd

df_path = '/home/rinaen/PycharmProjects/communication_agent/testing/eval_chunks.csv'
df = pd.read_csv(df_path)

# %%
from src.data_acquisition.content_processing.content_parsing import get_parsed_content_by_divided_function_call
from src.agents.api_agent import ApiAgent


def get_classified(model: ApiAgent, data_df):
    classified_types = []
    parsed_chunks = []
    for index, row in data_df.iterrows():
        url = row['url']
        chunk = row['chunk']
        try:
            typ, parsed = get_parsed_content_by_divided_function_call(model, url, chunk)
            classified_types.append(typ)
            parsed_chunks.append(parsed)
        except Exception:
            classified_types.append(None)
            parsed_chunks.append(None)
    return classified_types, parsed_chunks

# %%
mixtral_t, mixtral_p = get_classified(mixtral, df)
# Out:
# [2024-04-28 00:41:49,996 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 00:41:49,999 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: function_name='assign_place'
# [2024-04-28 00:41:57,793 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Element Restaurant and Bar' text='An excellent fusion of top-quality meals and original drinks, ideal for a dinner with your partner or friends. Element combines first-rate food and cocktails. Behind its globally inspired menu from local ingredients stands the well-travelled head chef Tomaš Reger, who has gained culinary experience from around the world. His food is complemented by drinks from champion bartender Jan Liška.' brief='Element Restaurant and Bar offers high-quality meals and unique cocktails in a cozy atmosphere, featuring a globally inspired menu from local ingredients crafted by a well-travelled head chef and accompanied by drinks from a champion bartender.' address='Běhounská 7, Brno, Czech Republic'
# [2024-04-28 00:41:59,738 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 00:41:59,742 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: function_name='assign_place'
# [2024-04-28 00:42:07,726 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Stylish Restaurant U Semináru with Traditional Czech Cuisine' text='"In the mood for a Czech classic with a bit of nostalgia? Search no more!\nCome taste the magic of the olden days! Smetanova 30 U Semináru is a stylish restaurant with a unique atmosphere, Pilsner beer, and traditional cuisine inspired by the times of the Austro-Hungarian Empire.\nSmetanova 30\nwww.useminaru.cz"' brief='U Semináru is a stylish Czech restaurant located on Smetanova 30, serving traditional cuisine and Pilsner beer in a unique atmosphere reminiscent of the Austro-Hungarian Empire.' address='Smetanova 30'
# [2024-04-28 00:42:09,876 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 00:42:09,878 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: function_name='assign_place'
# [2024-04-28 00:42:19,471 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Kohout Na Víně Restaurant' text='This restaurant specializes in coq au vin (the Czech translation is the name of the restaurant), with the exact preparation changing and reflecting the chefs’ current ideas and skills. It offers more than 200 wines from around the world, with a primary focus on Moravia and Bohemia. For private celebrations and business events, the restaurant offers two tasting menus with annotated wine pairings.\nMalinovského náměstí 2\nkohout-na-vine.cz' brief='Kohout Na Víně is a restaurant in Brno, Czech Republic that specializes in coq au vin and offers over 200 wines from around the world. They provide two tasting menus with annotated wine pairings for private events and business meetings.' address='Malinovského náměstí 2, Brno, Czech Republic'
# [2024-04-28 00:42:21,550 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 00
t\t\t\t\t\t\t\t\t\t\t\t', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for get_params_base
#   Invalid JSON: EOF while parsing an object at line 4 column 35 [type=json_invalid, input_value='{\n"header": "Café Plac...t\t\t\t\t\t\t\t\t\t\t\t', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# [2024-04-28 00:45:04,380 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for get_params_base
#   Invalid JSON: EOF while parsing an object at line 4 column 35 [type=json_invalid, input_value='{\n"header": "Café Plac...t\t\t\t\t\t\t\t\t\t\t\t', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# [2024-04-28 00:45:04,381 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 1 validation error for get_params_base
#   Invalid JSON: EOF while parsing an object at line 4 column 35 [type=json_invalid, input_value='{\n"header": "Café Plac...t\t\t\t\t\t\t\t\t\t\t\t', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid. Retrying
# [2024-04-28 00:45:13,443 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Café Placzek - A Stylish Location for Any Time of Day' text='Brunch, a cup of coffee in the afternoon or a drink in the evening at Café Placzek. A place to meet up any time of day. From Minoritská 4, a cup of coffee in the morning made from beans from top-quality roasters, alongside home-baked desserts and authentic brunches made with fresh ingredients. To mixed drinks or a glass of good wine from local winemakers in the evening. All in a place with an interwar atmosphere and a superb view of the Church of Saint Johns in the very heart of Brno.' brief='Café Placzek is a stylish location in the heart of Brno offering brunch, coffee, and drinks throughout the day with a view of the Church of Saint Johns. The menu features top-quality roasted beans, home-baked desserts, fresh ingredients, and local wines.' address='Minoritská 4, Brno, Czech Republic'
# [2024-04-28 00:45:15,220 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 00:45:15,223 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: function_name='assign_place'
# [2024-04-28 00:45:24,130 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Jazzová kavárna Podobrazy - A Classic Family-Friendly Cafe in Brno, Czech Republic' text="Jazzová kavárna Podobrazy is a classic family-friendly café located in the heart of the Moravian capital, Brno, Czech Republic. This café features a great vibe to lift your spirits when you're feeling down. Visitors can enjoy premium coffee and cocktails, indulge in locally made mini desserts, and take advantage of year-round outdoor seating. The establishment is active on Facebook under the name 'podobrazy'." brief="Jazzová kavárna Podobrazy in Brno, Czech Republic offers a warm atmosphere with premium coffee and cocktails, locally made desserts, and outdoor seating. Find them on Facebook as 'podobrazy'." address='Zelný trh 14, Brno, Czech Republic'
# [2024-04-28 00:45:26,074 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 00:45:26,077 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: function_name='assign_place'
# [2024-04-28 00:45:35,700 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Kafe Friedrich - A Cozy Cafe with Delicious Coffee' text='Kafe Friedrich is a small, cozy cafe that prepares all its food and sweets using locally sourced ingredients. The exception to this is their premium coffee, which is imported from different parts of the world to showcase the diverse flavors it can offer. The cafe has a living-room-like atmosphere, making it a comfortable place to relax and enjoy a moment of sweet laziness. During summer, customers can sit by the window or on a bench outside and savor their coffee. Kafe Friedrich is located at Smetanova 45, Brno, Czech Republic and can be found online at kafefriedrich.cz.' brief='Kafe Friedrich is a cozy cafe in Brno that serves delicious locally sourced food and premium imported coffee. It has a living-room atmosphere and offers outdoor seating during summer.' address='Smetanova 45, Brno, Czech Republic'
# [2024-04-28 00:45:37,749 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 00:45:37,754 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: function_name='assign_place'
# [2024-04-28 00:45:46,868 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Welcome to Kafe v rozkladu - The Birthplace of Brinner' text="Kafe v rozkladu is a unique place where the old blends with the new. It offers a cozy atmosphere reminiscent of a visit to grandma's house, but with a modern twist. The menu features tasty and colorful cocktails, coffee, and breakfast items that are served all day long. Kafe v rozkladu is the birthplace of 'brinner', which is breakfast served with an evening twist.\n\nFB: kafevrozkladu" brief="Kafe v rozkladu is a unique cafe in Brno, Czech Republic that combines traditional and modern elements. It offers all-day breakfast, tasty cocktails, and coffee. The cafe is known as the birthplace of 'brinner', which is breakfast served with an evening twist." address='Veselá 6'
# [2024-04-28 00:45:48,808 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 00:45:48,812 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: function_name='assign_place'
# [2024-04-28 00:45:59,445 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 00:45:59,447 patch.py->retry_sync():318]ERROR: Retrying, exception: 4 validation errors for get_params_base
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Mitte Panská ...Brno', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': "One of the fir...e.cz", 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Mitte Panská ...ons.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Panská 7, Brn...blic', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 4 validation errors for get_params_base
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Mitte Panská ...Brno', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': "One of the fir...e.cz", 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Mitte Panská ...ons.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Panská 7, Brn...blic', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 00:45:59,450 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 4 validation errors for get_params_base
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Mitte Panská ...Brno', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': "One of the fir...e.cz", 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Mitte Panská ...ons.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Panská 7, Brn...blic', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 00:45:59,451 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 4 validation errors for get_params_base
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Mitte Panská ...Brno', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': "One of the fir...e.cz", 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Mitte Panská ...ons.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Panská 7, Brn...blic', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 00:46:07,344 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Mitte Panská - A Brewed Oasis in the Heart of Brno' text="One of the first cafés in Brno to work with premium coffee now has its own roasting place, bakes its own desserts, and has beautiful outdoor seating in a courtyard. Thanks to its wide range of coffee, everyone can find something to suit their palate and even learn about the coffee's origins. There are 4 Mitte cafés in Brno. Panská 7, mitte.cz" brief='Mitte Panská is one of the first cafés in Brno to work with premium coffee, featuring its own roasting place, desserts, and courtyard seating. They offer a wide range of coffee, with four locations throughout the city.' address='Panská 7, Brno'
# [2024-04-28 00:46:09,289 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 00:46:09,293 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: function_name='assign_place'
# [2024-04-28 00:46:16,566 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Punkt Cafe - A Piece of Berlin in Brno, Czech Republic' text='"A piece of Berlin at a pleasant, quiet place." Here you’ll find espresso and filtered coffees made from premium beans of Czech and foreign roasteries. Coffee specialties and wholesome home-made desserts, with gluten-free and vegan options. The cosy interior and cheerful staff ensure a pleasant experience in any weather.\nFB: punkt.cafe' brief='Punkt Cafe is a Berlin-inspired coffee shop located in Brno, Czech Republic, offering premium coffee, homemade desserts, and a cozy atmosphere.' address='Bayerova 7, Brno, Czech Republic'
# [2024-04-28 00:46:18,445 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 00:46:18,448 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: function_name='assign_place'
# [2024-04-28 00:46:29,361 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Qb Coffee Roasters - A Hidden Gem by the Svratka River in Brno' text='"You’d easily cross the Svratka River for their coffee!" An espresso bar and a roasting place producing premium coffee at the premises of a rowing club by the fizzing Svratka River. Grab a bag of their amazing beans to make your favourite drinks at home or enjoy a coffee and some of their sweet or savoury snacks right there. Relax in one of the two outdoor seating areas and take in the atmosphere of the place, nestled among old docks and an interwar building.\nVeslařská 179\nqb.coffee' brief='Qb Coffee Roasters is a premium espresso bar and roasting place situated in a rowing club by the Svratka River in Brno, Czech Republic. They offer high-quality coffee beans and various sweet or savoury snacks for on-site consumption or takeaway. The venue features two outdoor seating areas with a unique atmosphere.' address='Veslařská 179, Brno, Czech Republic'
# [2024-04-28 00:46:31,306 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 00:46:31,309 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: function_name='assign_place'
# [2024-04-28 00:46:39,505 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 00:46:39,507 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: static
# Response: header='Rebelbean Vlněna - A Paradise for Coffee Lovers' text='A stylish café with premium coffee from its own roasting place, which is all about quality, sustainability, and fair treatment of farmers. Offering wine by Jan Stávek from Němčičky, a wide range of alcoholic, soft, and coffee-based drinks, as well as a lot of delicacies, sandwiches, and desserts. And a great soup at lunchtime.' brief='Rebelbean Vlněna is a stylish café in Brno, Czech Republic that offers premium coffee from its own roasting place, a wide range of drinks, and various food options. They prioritize quality, sustainability, and fair treatment of farmers.' address='Přízova 5, Brno, Czech Republic'
# [2024-04-28 00:47:03,665 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 00
_client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 00:48:08,589 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: static
# ...
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 01:09:43,137 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 2 validation errors for get_params_event
# address
#   Field required [type=missing, input_value={'header': 'Mirandolina b.../05/2024 19:00 - 21:50'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# dates
#   Field required [type=missing, input_value={'header': 'Mirandolina b.../05/2024 19:00 - 21:50'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 01:09:43,137 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 2 validation errors for get_params_event
# address
#   Field required [type=missing, input_value={'header': 'Mirandolina b.../05/2024 19:00 - 21:50'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# dates
#   Field required [type=missing, input_value={'header': 'Mirandolina b.../05/2024 19:00 - 21:50'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing. Retrying
# [2024-04-28 01:10:03,619 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 01:10:03,623 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: header='Mirandolina by Carlo Goldoni' text='Dominated by masterstrokes of vivacious acting, this dynamic commedia dell´arte gives the audience an intense theatrical experience crowned by astonishing numbers sung by both actors and opera singers. An incredibly sophisticated systems of backdrops and drapes enriches the spectators’ visual delight.\n\nThe peculiar owner of an inn in Florence, as we know her from Carlo Goldoni’s comedy, is a very competent woman who is more versed in business than anybody else. Both the pub and the rooms are always full and many clients long to win her affection. Some of them let it show rather ostentatiously, such as the impoverished yet boastful Marquis Di Forlipopoli and the upstart, self-centred Earl d’Albafiorit. Even though serving such importunate admirers might seem amusing, the lively innkeeper finds their obtuseness gruelling.\n\nBeing a jovial person, she sits up and takes notice when baron Di Ripafratta – a sworn adversary of women – walks into her pub. Mirandolina is closely bound to the starring actress Tereza Groszmannová, whose translation of the play is custom-made both for herself and her fellow actors. The characters express themselves with a well-timed vigour, allowing dynamic acting.\n\nThe highly pertinent and jaunty language of the script plays skilfully with ambiguities.' brief='Mirandolina is a comedy play written by Carlo Goldoni and performed at Theatre Reduta. The story revolves around Mirandolina, the owner of an inn in Florence, and her interactions with various clients, including a sworn adversary of women, baron Di Ripafratta.' address='Brno, Czech Republic' dates='[{"start": "2024-03-05T19:00"}, {"start": "2024-03-05T21:50"}]'
# [2024-04-28 01:10:23,997 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 01:10:24,004 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: header='The Stories of Brno - A Humorous Play at Reduta Theatre' text="The Stories of Brno is a drama presented at the Reduta Theatre. It offers humorous stories and legends about the city of Brno, presented by an impish storyteller. The play is suitable for schoolchildren and their parents, as well as anyone who enjoys learning about the city's unknown places. The production team includes Jakub Šafránek (author), Roman Groszmann (adaptation and direction), Ilona Smejkalová (dramaturg), Michal Hejmovský (stage and costume design), Hana Halberstadt (music), and movement cooperation by the cast. The play is suitable for children aged 6 and above, with a performance length of 65 minutes without intermission.\n\nCast:\n- Monika Maláčová as Andulka\n- Michal Bumbálek as Vincek\n- Jakub Svojanovský as Kronikář\n- Jan Grygar as Birk\n\nUpcoming performances:\n- The Stories of Brno, Reduta Theatre, Drama, Last 5 tickets, April 28th, 2024, 14:00 - 15:15\n- The Stories of Brno, Reduta Theatre, Drama, Last 1 ticket, April 30th, 2024, 10:00 - 11:15\n- The Stories of Brno, Reduta Theatre, Drama, Last 12 tickets, May 5th, 2024, 14:00 - 15:15" brief='The Stories of Brno is a humorous play performed at the Reduta Theatre, telling stories and legends about the city of Brno. With upcoming performances and limited tickets available, book your seats to enjoy this captivating drama suitable for both children and adults.' address='Reduta Theatre, Brno, Czech Republic' dates='[{"start": "2024-04-28T14:00"}, {"start": "2024-04-30T10:00"}, {"start": "2024-05-05T14:00"}]'
# [2024-04-28 01:10:40,996 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Three Sisters by Anton Pavlovich Chekhov' text='Being happy is possible! But maybe at some other place or at some other time … After the decease of their father, who provided the whole family with financial support and maintained its thriving social life, the three sisters – Irina, Masha and Olga – are left all by themselves in their small town and their future is far from being bright. The family house, which used to be attended by renowned guests, now attracts merely eccentrics and outsiders. Soon, their brother dissipates the bequest and the necessity of earning their living makes them loose what aristocrats took for granted: free time. Their desire to live a happy and fuller life, their longing for love and for a new home leads the sisters into extreme situations. Bitter laughter, laughable tears – what seems to be ordinary fortunes of common people unlocks great stories of love and adversity. Three Sisters , one of the two plays that Anton Pavlovich Chekhov (1860–1904) wrote specifically for the Moscow Art Theater, is considered to be the Russian playwright’s masterpiece. The four-act drama had a significant impact on European theater, including the Czech one: performed by the Moscow ensemble in Prague in 1906 it revolutionized the local approach to modern acting and directing.' brief="Three Sisters is a dramatic play written by Anton Pavlovich Chekhov, following the lives of three sisters who are left alone after their father's passing. Set in a small town, they yearn for a happier life, leading them into unexpected situations. This masterpiece significantly influenced European theater." address='Mahen Theatre, Brno, Czech Republic' dates='[{"start": "2023-10-27T00:00:00"}]'
# [2024-04-28 01:10:45,706 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 01:10:45,711 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'Call thi...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'Call thi...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 01:10:45,713 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'Call thi...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 01:10:45,714 api_agent.py->_handle_call_exception():145]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'Call thi...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 01:10:47,037 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 01:10:47,040 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: function_name='assign_event'
# [2024-04-28 01:11:03,153 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 01:11:03,156 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: header='Intervention: Přemysl Hytych / Floral Object Exhibition' text="Florist Přemysl Hytych presents a fashion - floral object - a floral dress inspired by embroidery, which attracted him to traditional clothing in Moravia. The author worked on the basis of personal experience with the collection of the Ethnographic Institute of the MFA. The direct contact with the documents of traditional folk culture, as well as the opportunity to look 'behind the mirror', i.e. into the depositories of textiles, were subsequently reflected in his work. He was able to translate the floral motifs from costume embroidery into the plane of fashion and the carnation or tulip flowers thus acquired another dimension. This position is underlined by the colours in the basic tones of red - blue - white as a visual echo of the culture of the Moravian countryside. The accentuation of a simple, seemingly notorious detail evokes the message of the past, which the author has translated into the artistic language of today. The exhibited object takes the relationship between tradition and design to a new level of meaning." brief="Přemysl Hytych's Floral Object exhibition features a floral dress inspired by Moravian traditional clothing embroidery, exploring the connection between folk culture and contemporary fashion in red, blue, and white tones." address='Palace of the Nobility, Chapel of the Purification of the Virgin Mary, Kobližná 1, Brno, Czech Republic' dates='[{"start": "2024-04-22"}, {"start": "2024-05-12"}]'
# [2024-04-28 01:11:11,307 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 01:11:11,310 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: header='Opening of the exhibition Thousand Faces of Amazonia' text='The exhibition presents the cultural and natural diversity of the Greater Amazon region and provides insight into the lives of the indigenous inhabitants of this cultural area. What is innovative and remarkable is that it is primarily their own self-representation, meaning that members of local ethnic groups have contributed significantly to the preparation of the exhibition. Visitors will thus learn about their rich culture, understanding of nature, mythology, religion, cosmology and interpretation of the world, customs and rituals.' brief='The opening of an exhibition showcasing the cultural and natural diversity of Amazonia with a focus on self-representation from indigenous communities.' address='Pisárecká 5, Brno, Czech Republic' dates='[{"start": "2024-05-16T17:00"}]'
# [2024-04-28 01:11:26,565 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 01:11:26,568 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: header='Museum of Decorative Arts' text='Admission fee voluntary\nART DESIGN FASHION\nMuseum of Decorative Arts\nPermanent exhibitions\nThe building of the Museum of Decorative Arts of the Moravian Gallery has received a new concept in 2021: ART DESIGN FASHION. It foreshadows that the museum is dedicated not only to design itself, but also to fashion and the relationship between design and art. Visitors can look forward to a permanent exhibition, exhibitions and new facilities prepared exclusively for the Moravian Gallery by leading Czech designers. The changed appearance of the Museum of Decorative Arts in Brno represents an imaginary showcase of Czech designers and their products. This multi-layered concept is unparalleled in the Czech Republic in terms of scope and quality.\nWhen designing the interior, the gallery was primarily concerned with incorporating the idea of presenting contemporary designers through their designs for interior elements and spaces. The gallery involved Maxim Velčovský, Radek Wohlmuth and the edit! studio, Eva Eisler, David Karásek, the Olgoj Chorchoj studio and Marek Štěpán.\nCurrent interventions in the exhibition:\nKrištof Kintera - Demon of Growth' brief="The Museum of Decorative Arts in Brno has a new concept called ART DESIGN FASHION. The museum features permanent and temporary exhibitions, showcasing Czech designers' products and their relationship with art and fashion. Visitors can see an intervention by Krištof Kintera titled 'Demon of Growth'." address='Brno, Czech Republic' dates='[{"start": "2021-01-01"}]'
# [2024-04-28 01:11:41,311 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Exhibition interventions by Marie Filippovová at Pražák Palace' text='Admission fee voluntary\nExhibition interventions: Marie Filippovová\nFROM 19/4/2024\nPražák Palace\nPetr Ingerle\nArt - Exhibitions\nMarie Filippovová represents one of the most prominent figures on the Brno art scene. At first glance, her work impresses with its concentration, sense of rhythm, cyclicality and temporality. To a certain extent, it is also characterised by a certain austerity, or even asceticism. The orderliness with which he completes cycles, sets and volumes of drawings, watercolours and prints, as well as his reliance on lapidary means of expression, is probably related to his deep experience with writing, typography and calligraphy. The generational experience of the artist, who studied free and applied graphics, design and book culture at the Academy of Arts and Crafts in Prague at the turn of the 1950s and 1960s, and then settled permanently in Brno, where she began her independent creative career, is also undeniable.' brief="Marie Filippovová, a prominent figure on the Brno art scene, will have an exhibition intervention at Pražák Palace. Her work is characterized by concentration, rhythm, cyclicality, temporality, austerity, and asceticism. The artist's generational experience, who studied graphic design in Prague, adds to her unique style." address='Pražák Palace, Brno, Czech Republic' dates='[{"start": "2024-04-19"}]'

# %%
llama3_70_t, llama3_70_p = get_classified(llama3_70, df)
# Out:
# [2024-04-28 01:12:15,819 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 01:12:15,822 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: function_name='assign_place'
# [2024-04-28 01:12:54,323 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Element Restaurant' text='Element combines first-rate food and cocktails. Behind its globally inspired menu from local ingredients stands the well-travelled head chef Tomaš Reger, who has gained culinary experience from around the world. His food is complemented by drinks from champion bartender Jan Liška.' brief='A fusion of top-quality meals and original drinks, ideal for a dinner with friends or partner. The restaurant offers globally inspired menu from local ingredients, complemented by unique drinks.' address='Běhounská 7, Brno, Czech Republic'
# [2024-04-28 01:13:06,303 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 01:13:06,306 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: function_name='assign_place'
# [2024-04-28 01:13:42,042 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='
joseph II in 1782, and again in 1849 by the Moravian constitution. Today, the Moravian Land Tables are stored in the Moravian Regional Archive, and are included among the national cultural sights of the Czech Republic. During the 17th century Špilberk Castle was rebuilt as a huge baroque citadel. Brno was besieged by the Prussian Army in 1742 under the leadership of Frederick the Great, but the siege was ultimately unsuccessful. In 1777 the bishopric of Brno was established by the Catholic Church; Mathias Franz Graf von Chorinsky Freiherr von Ledske was the first Bishop. In December 1805 the Battle of Austerlitz was fought near the city; the battle is also known as the 'Battle of the Three Emperors'. Brno itself was not involved with the battle, but the French Emperor Napoleon Bonaparte spent several nights here at that time, and again in 1809. In 1839 the first train arrived in Brno from Vienna; this was the beginning of rail transport in what is now the Czech Republic. In the years 1859–1864 the city fortifications were almost completely removed. In 1869 a horse-car service started to operate in Brno, the first tram service in what would later become the Czech Republic. Gregor Mendel conducted his groundbreaking experiments in genetics while he was a monk at St. Thomas's Abbey in Brno in the 1850s." brief="Brno has a rich history dating back to the 17th century, serving as the sole capital of the Margraviate of Moravia during the Thirty Years' War. The city has been influenced by various historical events and figures, including Napoleon Bonaparte and Gregor Mendel. Today, Brno is a cultural hub with many national sights." address='Brno, Czech Republic'
# [2024-04-28 01:38:32,284 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 01:38:32,287 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for get_params_base
#   Invalid JSON: EOF while parsing an object at line 1 column 1387 [type=json_invalid, input_value='{"header": "Brno City In...t\t\t     \t\t\t\t     ', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for get_params_base
#   Invalid JSON: EOF while parsing an object at line 1 column 1387 [type=json_invalid, input_value='{"header": "Brno City In...t\t\t     \t\t\t\t     ', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# [2024-04-28 01:38:32,289 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for get_params_base
#   Invalid JSON: EOF while parsing an object at line 1 column 1387 [type=json_invalid, input_value='{"header": "Brno City In...t\t\t     \t\t\t\t     ', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# [2024-04-28 01:38:32,290 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 1 validation error for get_params_base
#   Invalid JSON: EOF while parsing an object at line 1 column 1387 [type=json_invalid, input_value='{"header": "Brno City In...t\t\t     \t\t\t\t     ', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid. Retrying
# [2024-04-28 01:40:41,003 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 01:40:41,005 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: static
# Response: header='Brno' text='Climate: Under the Köppen climate classification, Brno has an oceanic climate (Cfb) for −3 °C original isoterm, but near of the (−2.5 °C average temperature in January, month most cold) or include by updated classification in humid continental climate (Dfb) with cold winters and warm to hot summers. However, in the last 20 years the temperature has increased, and summer days with temperature above 30 °C (86 °F) are quite common. The average temperature is 9.4 °C (49 °F), the average annual precipitation is about 505 mm (19.88 in), the average number of precipitation days is 150, the average annual sunshine is 1,771 hours, and the prevailing wind direction is northwest. The weather box below shows average data between years 1961 and 1990. Its height above sea level varies from 190 m (623 ft) to 497 m (1,631 ft). The highest peak in the municipal area is the Kopeček Hill (479 m (1,572 ft)), and the highest point overall lies in Útěchov on the border with the municipality of Vranov. Festivals: The biggest festival in Brno is the fireworks competition festival, Ignis Brunensis (Latin for "Flame of Brno"), held annually in June, part of the "Brno – City in the Centre of Europe" festival. Ignis Brunensis is the biggest show of its kind in Central Europe, usually attracting 100,000–200,000 visitors to each display. The international film festival Cinema Mundi screens about 60 films competing for Oscar nomination in the category of Best Foreign Language Film. Theatre World Brno is another international festival held annually in the city, in which Brno theatres and the city centre stage around 100 performances by national and foreign ensembles. Other festivals held regularly in Brno include the International Music Festival Brno, the Spilberk International Music Festival, and the Summer Shakespeare Festival. Every September, Brno hosts a wine festival, Slavnosti vína, to celebrate the harvest in the surrounding wine-producing region.' brief='Brno has an oceanic climate with cold winters and warm summers. The city hosts various festivals throughout the year, including the Ignis Brunensis fireworks competition festival and the international film festival Cinema Mundi. The city also celebrates its wine-producing region with a wine festival every September.' address='Brno, Czech Republic'
# [2024-04-28 01:44:38,367 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 01:44:38,370 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for get_params_base
#   Invalid JSON: control character (\u0000-\u001F) found while parsing a string at line 4 column 0 [type=json_invalid, input_value='{"header": "Local Legend...n\n\n\n\n \n\n\n\n\n\n ', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for get_params_base
#   Invalid JSON: control character (\u0000-\u001F) found while parsing a string at line 4 column 0 [type=json_invalid, input_value='{"header": "Local Legend...n\n\n\n\n \n\n\n\n\n\n ', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# [2024-04-28 01:44:38,373 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for get_params_base
#   Invalid JSON: control character (\u0000-\u001F) found while parsing a string at line 4 column 0 [type=json_invalid, input_value='{"header": "Local Legend...n\n\n\n\n \n\n\n\n\n\n ', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# [2024-04-28 01:44:38,374 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 1 validation error for get_params_base
#   Invalid JSON: control character (\u0000-\u001F) found while parsing a string at line 4 column 0 [type=json_invalid, input_value='{"header": "Local Legend...n\n\n\n\n \n\n\n\n\n\n ', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid. Retrying
# [2024-04-28 01:47:16,678 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 01:47:16,682 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: static
# Response: header='Brno Local Legends' text='There are several legends connected with the City of Brno. One of the best known is the Legend of the Brno Dragon. According to this legend, a terrible creature was terrorizing the citizens of Brno. The people had never seen this animal before, so they called it a dragon. They lived in fear of the dragon until one citizen managed to kill the monster by tricking it into eating a carcass filled with lime. In reality the dragon was a crocodile, the preserved body of which is now displayed at the entrance of the Old Town Hall. Crocodile and dragon motifs are common in Brno. A crocodile (Czech: krokodýl) is the local stuffed baguette, and the city radio station is known as Radio Krokodýl. The local baseball team is named Draci Brno (English: Brno Dragons) and the local rugby club is named RC Dragon Brno. There is also a local American football team called the Brno Alligators. An Intercity train connecting Brno and Prague is called Brněnský drak (English: The Brno dragon). Next to the "dragon" at the Old Town Hall is the town\'s second well-known emblem, a wagon wheel made from a tree found and cut down 50 miles from the city. According to the legend, a local man made a wager that he could fell the tree, make a wheel out of it, and roll the wheel to the City of Brno, all within a single day. Since the achievement was deemed to be impossible by normal human means, the man was believed to have called on the devil for assistance, and died in poverty as a result. Another local legend relates to the siege of the city by Swedish forces in 1645. The locals and the Swedish army were in a stalemate, and the Swedish general declared that he would withdraw if his army had not won by noon. The bell ringer at Petrov Cathedral tricked him by ringing the bell an hour early, and keeping his word, the general and his army left. As a historic tribute to the event, the bell at Petrov Cathedral still rings for noon an hour earlier, at 11 o\'clock. At this time, the Brno astronomical clock also releases a glass ball as a souvenir. Twin towns – sister cities Brno is twinned with: Bratislava, Slovakia Dallas, United States Debrecen, Hungary Kaunas, Lithuania Kharkiv, Ukraine Leeds, England, United Kingdom Leipzig, Germany Poznań, Poland Rennes, France Sankt Pölten, Austria Stuttgart, Germany Cooperation agreements Brno also cooperates with: Daejeon, South Korea Lviv, Ukraine – twinning approved in 2022 Utrecht, Netherlands Vienna, Austria' brief='Brno has several local legends, including the Legend of the Brno Dragon and a legend about a wager to make a wagon wheel. The city is also twinned with many sister cities and cooperates with others.' address='Brno, Czech Republic'
# [2024-04-28 01:48:20,065 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 01
In Brno, Three Sisters will be staged by Štěpán Pácl, in-house director of the Dramatic Company of the National Theater Brno, whose successful production of Chekhov’s play The Seagull was adapted into film.\n' brief="The three sisters – Irina, Masha and Olga – are left alone after their father's death, struggling to maintain their social life and longing for a happy and fuller life. The play is considered a masterpiece of Russian playwright Anton Pavlovich Chekhov." address='Mahen Theatre' dates='[{"start": "2024-05-05T17:00", "end": "2024-05-05T19:45"}]'
# [2024-04-28 03:31:38,497 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 03:31:38,502 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: function_name='assign_event'
# [2024-04-28 03:33:14,776 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 03:33:14,781 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: header='Intervention: Přemysl Hytych / Floral Object' text='The event takes place as part of Brno Art Week 2024. Florist Přemysl Hytych presents a fashion - floral object - a floral dress inspired by embroidery, which attracted him to traditional clothing in Moravia. The author worked on the basis of personal experience with the collection of the Ethnographic Institute of the MFA. The direct contact with the documents of traditional folk culture, as well as the opportunity to look "behind the mirror", i.e. into the depositories of textiles, were subsequently reflected in his work. He was able to translate the floral motifs from costume embroidery into the plane of fashion and the carnation or tulip flowers thus acquired another dimension. This position is underlined by the colours in the basic tones of red - blue - white as a visual echo of the culture of the Moravian countryside. The accentuation of a simple, seemingly notorious detail evokes the message of the past, which the author has translated into the artistic language of today. The exhibited object takes the relationship between tradition and design to a new level of meaning.' brief="Přemysl Hytych presents a floral dress inspired by traditional Moravian embroidery as part of Brno Art Week 2024. The artwork reflects the author's personal experience with folk culture and translates traditional motifs into modern fashion. The object takes the relationship between tradition and design to a new level of meaning." address='Palace of the Nobility, Chapel of the Purification of the Virgin Mary, Kobližná 1, Brno' dates='[{"start": "2024-04-22"}, {"start": "2024-05-12"}]'
# [2024-04-28 03:34:01,547 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 03:34:01,553 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: header='Thousand Faces of Amazonia' text='The exhibition presents the cultural and natural diversity of the Greater Amazon region and provides insight into the lives of the indigenous inhabitants of this cultural area. What is innovative and remarkable is that it is primarily their own self-representation, meaning that members of local ethnic groups have contributed significantly to the preparation of the exhibition. Visitors will thus learn about their rich culture, understanding of nature, mythology, religion, cosmology and interpretation of the world, customs and rituals.' brief='Exhibition presenting cultural and natural diversity of Greater Amazon region and lives of indigenous inhabitants.' address='Anthropos Pavilion, Pisárecká 5, Brno' dates='[{"start": "2024-05-16T17:00"}]'
# [2024-04-28 03:35:22,142 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 03:35:22,147 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: header='Museum of Decorative Arts' text='The building of the Museum of Decorative Arts of the Moravian Gallery has received a new concept in 2021: ART DESIGN FASHION. It foreshadows that the museum is dedicated not only to design itself, but also to fashion and the relationship between design and art. Visitors can look forward to a permanent exhibition, exhibitions and new facilities prepared exclusively for the Moravian Gallery by leading Czech designers. The changed appearance of the Museum of Decorative Arts in Brno represents an imaginary showcase of Czech designers and their products. This multi-layered concept is unparalleled in the Czech Republic in terms of scope and quality.\nWhen designing the interior, the gallery was primarily concerned with incorporating the idea of presenting contemporary designers through their designs for interior elements and spaces. The gallery involved Maxim Velčovský, Radek Wohlmuth and the edit! studio, Eva Eisler, David Karásek, the Olgoj Chorchoj studio and Marek Štěpán.\nCurrent interventions in the exhibition:\nKrištof Kintera - Demon of Growth' brief='The Museum of Decorative Arts in Brno features a new concept, ART DESIGN FASHION, showcasing Czech designers and their products. The museum offers permanent exhibitions, temporary exhibitions, and facilities designed by leading Czech designers.' address='Brno, Czech Republic' dates='[{"start": "2021-01-01"}]'
# [2024-04-28 03:36:33,128 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Marie Filippovová Exhibition' text='Marie Filippovová represents one of the most prominent figures on the Brno art scene. At first glance, her work impresses with its concentration, sense of rhythm, cyclicality and temporality. To a certain extent, it is also characterised by a certain austerity, or even asceticism. The orderliness with which he completes cycles, sets and volumes of drawings, watercolours and prints, as well as his reliance on lapidary means of expression, is probably related to his deep experience with writing, typography and calligraphy. The generational experience of the artist, who studied free and applied graphics, design and book culture at the Academy of Arts and Crafts in Prague at the turn of the 1950s and 1960s, and then settled permanently in Brno, where she began her independent creative career, is also undeniable.' brief="Marie Filippovová's exhibition showcases her prominent art pieces with concentration, rhythm, and cyclicality. Her work is characterized by austerity and asceticism. The artist's experience with writing, typography, and calligraphy influences her style." address='Pražák Palace' dates='[{"start": "2024-04-19"}]'

# %%
llama2_70_t, llama2_70_p = get_classified(llama2_70, df)
# Out:
# [2024-04-28 11:35:51,699 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:35:51,700 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:35:51,702 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:35:51,703 api_agent.py->_handle_call_exception():145]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 11:35:52,586 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:35:52,589 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 11:35:52,590 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 11:35:52,590 api_agent.py->_handle_call_exception():145]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing. Retrying
# [2024-04-28 11:35:56,378 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:35:56,380 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:35:56,382 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:35:56,383 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 11:35:56,384 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 11:35:56,384 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: None
# [2024-04-28 11:35:56,386 content_parsing.py->get_parsed_content_by_divided_function_call():96]ERROR: Unknown content type: None
# [2024-04-28 11:36:02,041 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:36:02,043 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:02,044 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:02,044 api_agent.py->_handle_call_exception():145]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 11:36:08,378 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:36:08,379 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:08,380 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:08,381 api_agent.py->_handle_call_exception():145]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 11:36:14,636 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:36:14,637 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:14,638 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:14,638 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 11:36:14,639 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 11:36:14,639 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: None
# [2024-04-28 11:36:14,639 content_parsing.py->get_parsed_content_by_divided_function_call():96]ERROR: Unknown content type: None
# [2024-04-28 11:36:20,181 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:36:20,182 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:20,183 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:20,184 api_agent.py->_handle_call_exception():145]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 11:36:26,444 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:36:26,445 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:26,446 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:26,447 api_agent.py->_handle_call_exception():145]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 11:36:32,761 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:36:32,763 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:32,765 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:32,766 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 11:36:32,767 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 11:36:32,767 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: None
# [2024-04-28 11:36:32,768 content_parsing.py->get_parsed_content_by_divided_function_call():96]ERROR: Unknown content type: None
# [2024-04-28 11:36:38,377 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:36:38,378 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:38,379 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:38,380 api_agent.py->_handle_call_exception():145]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 11:36:42,489 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:36:42,490 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:42,491 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:42,492 api_agent.py->_handle_call_exception():145]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 11:36:48,735 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:36:48,737 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:48,738 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:48,739 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 11:36:48,740 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 11:36:48,740 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: None
# [2024-04-28 11:36:48,741 content_parsing.py->get_parsed_content_by_divided_function_call():96]ERROR: Unknown content type: None
# [2024-04-28 11:36:54,368 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:36:54,369 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:54,370 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:36:54,371 api_agent.py->_handle_call_exception():145]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 11:37:00,614 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:37:00,616 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:37:00,616 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:37:00,617 api_agent.py->_handle_call_exception():145]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 11:37:01,638 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:37:01,640 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 11:37:01,642 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 11:37:01,642 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing. Max retries reached. Skipping.
# [2024-04-28 11:37:01,643 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 11:37:01,644 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: None
# [2024-04-28 11:37:01,645 content_parsing.py->get_parsed_content_by_divided_function_call():96]ERROR: Unknown content type: None
# [2024-04-28 11:37:07,271 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:37:07,272 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:37:07,274 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:37:07,275 api_agent.py->_handle_call_exception():145]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 11:37:11,367 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:37:11,369 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:37:11,371 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:37:11,372 api_agent.py->_handle_call_exception():145]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 11:37:17,715 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:37:17,717 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:37:17,719 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:37:17,720 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 11:37:17,720 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 11:37:17,721 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: None
# [2024-04-28 11:37:17,722 content_parsing.py->get_parsed_content_by_divided_function_call():96]ERROR: Unknown content type: None
# [2024-04-28 11:37:23,347 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:37:23,349 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:37:23,351 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 11:37:23,352 api_agent.py->_handle_call_exception():145]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'assign_p...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 11:37:24,270 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 11:37:24,272 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
# ...
# --> 468 response = self.get_json_format_response(ChosenFunction, self.messages_storage)
#     469 self._add_message(Message(ASSISTANT, str(response)))
#     470 function_name = response["function_name"]
#
# File ~/PycharmProjects/communication_agent/src/agents/api_agent.py:394, in LocalApiAgent.get_json_format_response(self, response_model, messages, max_retries)
#     388 messages = [asdict(m) for m in messages]
#     389 client = instructor.patch(
#     390     self.client,
#     391     mode=instructor.Mode.JSON,
#     392 )
# --> 394 response = client.chat.completions.create(
#     395     model=self.model_name,
#     396     messages=messages,
#     397     response_model=response_model,
#     398     max_retries=0
#     399 )
#     400 print(f"Response: {response}")
#     401 self._add_message(Message(ASSISTANT, str(response)))
#
# File ~/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py:392, in wrap_chatcompletion.<locals>.new_chatcompletion_sync(response_model, validation_context, max_retries, *args, **kwargs)
#     381 @wraps(func)
#     382 def new_chatcompletion_sync(
#     383     response_model=None,
#    (...)
#     387     **kwargs,
#     388 ):
#     389     response_model, new_kwargs = handle_response_model(
#     390         response_model=response_model, kwargs=kwargs, mode=mode
#     391     )  # type: ignore
# --> 392     response = retry_sync(
#     393         func=func,
#     394         response_model=response_model,
#     395         validation_context=validation_context,
#     396         max_retries=max_retries,
#     397         args=args,
#     398         kwargs=new_kwargs,
#     399         mode=mode,
#     400     )  # type: ignore
#     401     return response
#
# File ~/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py:300, in retry_sync(func, response_model, validation_context, args, kwargs, max_retries, strict, mode)
#     297 while retries <= max_retries:
#     298     # Excepts ValidationError, and JSONDecodeError
#     299     try:
# --> 300         response = func(*args, **kwargs)
#     301         stream = kwargs.get("stream", False)
#     302         if isinstance(response, ChatCompletion) and response.usage is not None:
#
# File ~/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py:392, in wrap_chatcompletion.<locals>.new_chatcompletion_sync(response_model, validation_context, max_retries, *args, **kwargs)
#     381 @wraps(func)
#     382 def new_chatcompletion_sync(
#     383     response_model=None,
#    (...)
#     387     **kwargs,
#     388 ):
#     389     response_model, new_kwargs = handle_response_model(
#     390         response_model=response_model, kwargs=kwargs, mode=mode
#     391     )  # type: ignore
# --> 392     response = retry_sync(
#     393         func=func,
#     394         response_model=response_model,
#     395         validation_context=validation_context,
#     396         max_retries=max_retries,
#     397         args=args,
#     398         kwargs=new_kwargs,
#     399         mode=mode,
#     400     )  # type: ignore
#     401     return response
#
# File ~/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py:300, in retry_sync(func, response_model, validation_context, args, kwargs, max_retries, strict, mode)
#     297 while retries <= max_retries:
#     298     # Excepts ValidationError, and JSONDecodeError
#     299     try:
# --> 300         response = func(*args, **kwargs)
#     301         stream = kwargs.get("stream", False)
#     302         if isinstance(response, ChatCompletion) and response.usage is not None:
#
#     [... skipping similar frames: wrap_chatcompletion.<locals>.new_chatcompletion_sync at line 392 (180 times), retry_sync at line 300 (180 times)]
#
# File ~/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py:392, in wrap_chatcompletion.<locals>.new_chatcompletion_sync(response_model, validation_context, max_retries, *args, **kwargs)
#     381 @wraps(func)
#     382 def new_chatcompletion_sync(
#     383     response_model=None,
#    (...)
#     387     **kwargs,
#     388 ):
#     389     response_model, new_kwargs = handle_response_model(
#     390         response_model=response_model, kwargs=kwargs, mode=mode
#     391     )  # type: ignore
# --> 392     response = retry_sync(
#     393         func=func,
#     394         response_model=response_model,
#     395         validation_context=validation_context,
#     396         max_retries=max_retries,
#     397         args=args,
#     398         kwargs=new_kwargs,
#     399         mode=mode,
#     400     )  # type: ignore
#     401     return response
#
# File ~/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py:300, in retry_sync(func, response_model, validation_context, args, kwargs, max_retries, strict, mode)
#     297 while retries <= max_retries:
#     298     # Excepts ValidationError, and JSONDecodeError
#     299     try:
# --> 300         response = func(*args, **kwargs)
#     301         stream = kwargs.get("stream", False)
#     302         if isinstance(response, ChatCompletion) and response.usage is not None:
#
# File ~/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/openai/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/openai/resources/chat/completions.py:667, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     615 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     616 def create(
#     617     self,
#    (...)
#     665     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     666 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 667     return self._post(
#     668         "/chat/completions",
#     669         body=maybe_transform(
#     670             {
#     671                 "messages": messages,
#     672                 "model": model,
#     673                 "frequency_penalty": frequency_penalty,
#     674                 "function_call": function_call,
#     675                 "functions": functions,
#     676                 "logit_bias": logit_bias,
#     677                 "logprobs": logprobs,
#     678                 "max_tokens": max_tokens,
#     679                 "n": n,
#     680                 "presence_penalty": presence_penalty,
#     681                 "response_format": response_format,
#     682                 "seed": seed,
#     683                 "stop": stop,
#     684                 "stream": stream,
#     685                 "temperature": temperature,
#     686                 "tool_choice": tool_choice,
#     687                 "tools": tools,
#     688                 "top_logprobs": top_logprobs,
#     689                 "top_p": top_p,
#     690                 "user": user,
#     691             },
#     692             completion_create_params.CompletionCreateParams,
#     693         ),
#     694         options=make_request_options(
#     695             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     696         ),
#     697         cast_to=ChatCompletion,
#     698         stream=stream or False,
#     699         stream_cls=Stream[ChatCompletionChunk],
#     700     )
#
# File ~/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/openai/_base_client.py:1213, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1199 def post(
#    1200     self,
#    1201     path: str,
#    (...)
#    1208     stream_cls: type[_StreamT] | None = None,
#    1209 ) -> ResponseT | _StreamT:
#    1210     opts = FinalRequestOptions.construct(
#    1211         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1212     )
# -> 1213     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/openai/_base_client.py:902, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     893 def request(
#     894     self,
#     895     cast_to: Type[ResponseT],
#    (...)
#     900     stream_cls: type[_StreamT] | None = None,
#     901 ) -> ResponseT | _StreamT:
# --> 902     return self._request(
#     903         cast_to=cast_to,
#     904         options=options,
#     905         stream=stream,
#     906         stream_cls=stream_cls,
#     907         remaining_retries=remaining_retries,
#     908     )
#
# File ~/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/openai/_base_client.py:931, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     928     kwargs["auth"] = self.custom_auth
#     930 try:
# --> 931     response = self._client.send(
#     932         request,
#     933         stream=stream or self._should_stream_response_body(request=request),
#     934         **kwargs,
#     935     )
#     936 except httpx.TimeoutException as err:
#     937     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/htt
_client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Mlsná holka' text='A cosy confectionery in the centre of Brno with friendly staff to recommend the best from their wide offering. Leave the Faculty of Medicine to make her business dream come true? That’s Mlsná holka’s story! First a small shop selling doughnuts, now a real confectionary. A place where you can enjoy doughnuts as well as macarons and other authentic desserts. And it even serves premium coffee from the local Fiftybeans coffee roasters.' brief='A cozy confectionery in Brno with a wide offering of desserts and premium coffee. Founded by Mlsná holka, who turned her business dream into reality.' address='Poštovská 1'
# [2024-04-28 12:06:41,573 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 12:06:41,575 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: static
# Response: function_name='assign_static'
# [2024-04-28 12:07:12,595 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Sorry, pečeme jinak' text='A beautiful place with delicious cakes to make your head spin and your taste buds rejoice.\r\nGet ready for some different, colourful, crazy, funny-yet-serious, and always excellent baking! So much more than just desserts, these pieces of art are a feast for the eyes and ecstasy for the taste buds.\r\nKřídlovická 1\r\nFB: Sorry – pečeme jinak' brief='A bakery known for its artistic cakes and delicious treats.' address='Křádlovická 1, Brno, Czech Republic'
# [2024-04-28 12:07:20,894 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 12:07:20,897 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: function_name='assign_place'
# [2024-04-28 12:07:44,768 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 12:07:44,770 patch.py->retry_sync():318]ERROR: Retrying, exception: 2 validation errors for get_params_base
# brief
#   Field required [type=missing, input_value={'header': 'Zemanova cukr... specialties, such as '}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# address
#   Field required [type=missing, input_value={'header': 'Zemanova cukr... specialties, such as '}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for get_params_base
# brief
#   Field required [type=missing, input_value={'header': 'Zemanova cukr... specialties, such as '}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# address
#   Field required [type=missing, input_value={'header': 'Zemanova cukr... specialties, such as '}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 12:07:44,771 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 2 validation errors for get_params_base
# brief
#   Field required [type=missing, input_value={'header': 'Zemanova cukr... specialties, such as '}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# address
#   Field required [type=missing, input_value={'header': 'Zemanova cukr... specialties, such as '}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 12:07:44,772 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 2 validation errors for get_params_base
# brief
#   Field required [type=missing, input_value={'header': 'Zemanova cukr... specialties, such as '}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# address
#   Field required [type=missing, input_value={'header': 'Zemanova cukr... specialties, such as '}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing. Retrying
# [2024-04-28 12:08:21,107 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Zemanova cukárna a kavárna' text='Located in a functionalist building, protected as a national heritage site, it opened its doors in 1937, making this café and confectionary the longest-serving in Brno. Offering traditional Czech desserts, baked goods, premium coffee, and over 30 types of local liquors and spirits, it boasts several specialties, such as "Veletržní dort" and baked dragons. And its interwar vibe makes it an ideal place for the cultural events that take place here from time to time.' brief='A trip back to the interwar period in the best possible way.' address='Josefská 4, Brno, Czech Republic'
# [2024-04-28 12:08:35,555 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 12:08:35,560 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: function_name='assign_place'
# [2024-04-28 12:09:16,802 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Buchta C' text='An ideal stop for a quick cup of coffee and something sweet on the Vegetable Market. A younger sister of Buchta B café, this is Zelný trh 10 a small espresso bar hidden in the courtyard at the Vegetable Market. Enjoy its outdoor seating in one of the biggest vertical gardens in the whole country, open year-round. Sweet delicacies are brought here every day from Buchta B to complement their premium coffee from various Czech and European roasting places, or a glass of natural wine made for you by Moravian winemakers.' brief='A small espresso bar hidden in the courtyard at the Vegetable Market offering premium coffee, sweet delicacies, and a unique outdoor seating experience amidst one of the biggest vertical gardens in the country.' address='Zelný trh 10, Brno, Czech Republic'
# [2024-04-28 12:09:35,553 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 12:09:35,556 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: function_name='assign_place'
# [2024-04-28 12:10:08,602 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='
# [2024-04-28 12:27:55,545 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 12:27:55,548 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: static
# Response: header='Brno' text='Brno is located in the southeastern part of the Czech Republic, at the confluence of the Svitava and Svratka rivers, and there are also several brooks flowing through it, including the Veverka, Ponávka, and Říčka. The Svratka River flows through the city for about 29 km (18 mi), and the Svitava River cuts a 13 km (8 mi) path through the city. Brno is situated at the crossroads of ancient trade routes which have joined northern and southern European civilizations for centuries, and is a part of the Danube basin region. The city is historically connected with Vienna, which lies 110 km (68 mi) to the south. Brno is 21.5 km (13.4 mi) across, measured from east to west, and its total area is 230 km² (89 sq mi). Within the city limits are the Brno Reservoir, several ponds, and other standing bodies of water, such as the reservoirs in the Marian Valley and the Žebětín Pond. Brno is surrounded by wooded hills on three sides; about 6,379 ha (15,763 acres) of the area of the city is forest, 28% of the total. Due to its location between the Bohemian-Moravian Highlands and the Southern Moravian lowlands (Dyje-Svratka Vale), Brno has a moderate climate. Compared to other cities in the country, Brno has a very high air quality, which is ensured by a good natural circulation of air; no severe storms or similar natural disasters have ever been recorded in the city.' brief='Brno is a city located in the southeastern part of the Czech Republic, at the confluence of the Svitava and Svratka rivers. It has a moderate climate and very high air quality, with many natural bodies of water and surrounding wooded hills. The city has a rich history and is connected to Vienna.' address='Brno, Czech Republic'
# ...
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for get_params_event
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2021-01-11'},...t': '2024-01-14T15:00'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 14:06:06,883 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for get_params_event
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2021-01-11'},...t': '2024-01-14T15:00'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 14:06:06,883 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 1 validation error for get_params_event
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2021-01-11'},...t': '2024-01-14T15:00'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 14:07:07,089 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 14:07:07,094 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for get_params_event
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2021-01-11'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for get_params_event
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2021-01-11'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 14:07:07,095 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for get_params_event
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2021-01-11'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 14:07:07,096 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 1 validation error for get_params_event
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2021-01-11'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 14:07:35,022 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 14:07:35,028 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for get_params_event
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2021-01-11'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for get_params_event
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2021-01-11'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 14:07:35,029 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for get_params_event
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2021-01-11'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 14:07:35,030 api_agent.py->_handle_call_exception():148]ERROR: Error getting JSON format response: 1 validation error for get_params_event
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2021-01-11'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 14:07:35,031 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 14:08:27,882 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 14:08:27,887 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for get_params_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Marie Filippovová Exhibition'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for get_params_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Marie Filippovová Exhibition'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 14:08:27,889 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for get_params_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Marie Filippovová Exhibition'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 14:08:27,889 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 1 validation error for get_params_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Marie Filippovová Exhibition'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 14:08:53,380 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 14:08:53,385 patch.py->retry_sync():318]ERROR: Retrying, exception: 5 validation errors for get_params_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Marie Filippov...tion', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Representation...cene', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Artwork charac...lity', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Pražák Palace', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2024-04-19'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 5 validation errors for get_params_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Marie Filippov...tion', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Representation...cene', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Artwork charac...lity', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Pražák Palace', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2024-04-19'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 14:08:53,387 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 5 validation errors for get_params_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Marie Filippov...tion', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Representation...cene', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Artwork charac...lity', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Pražák Palace', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2024-04-19'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 14:08:53,387 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 5 validation errors for get_params_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Marie Filippov...tion', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Representation...cene', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Artwork charac...lity', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Pražák Palace', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2024-04-19'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 14:09:50,622 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Marie Filippovová: Representation of the Most Prominent Figure on the Brno Art Scene' text='Admission fee voluntary.\nExhibition interventions: Marie Filippovová\nFROM 19/4/20\nPražák Palace\nPetr Ingerle\nArt - Exhibitions\nMarie Filippovová represents one of the most prominent figures on the Brno art scene. At first glance, her work impresses with its concentration, sense of rhythm, cyclicality and temporality. To a certain extent, it is also characterised by a certain austerity, or even asceticism. The orderliness with which he completes cycles, sets and volumes of drawings, watercolours and prints, as well as his reliance on lapidary means of expression, is probably related to his deep experience with writing, typography and calligraphy.\nThe generational experience of the artist, who studied free and applied graphics, design and book culture at the Academy of Arts and Crafts in Prague at the turn of the 1950s and 1960s, and then settled permanently in Brno, where she began her independent creative career, is also undeniable.' brief='Artwork characteristics: concentration, sense of rhythm, cyclicality and temporality; a certain austerity or asceticism.' address='Pražák Palace' dates='[{"start": "2024-04-19"}]'

# %%
gpt3_t, gpt3_p = get_classified(gpt3, df)
# Out:
# [2024-04-28 07:31:34,444 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:31:34,447 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrQMHNWGCEXUbbGsjBdw7dmh40mW', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282294, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=434, total_tokens=444))
# [2024-04-28 07:31:37,405 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:31:37,407 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrQNN8WRqSZOTHca6RBxt2OBq7Hh', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Element","text":"\\"An excellent fusion of top-quality meals and original drinks, ideal for a dinner with your partner or friends.\\" Element combines first-rate food and cocktails. Behind its globally inspired menu from local ingredients stands the well-travelled head chef Tomaš Reger, who has gained culinary experience from around the world. His food is complemented by drinks from champion bartender Jan Liška. Visit Běhounská 7 or check their website elementbrno.com for more information.","brief":"Element offers a fantastic blend of high-quality dishes and unique drinks, perfect for a meal with your loved one or friends. The menu is globally inspired using locally sourced ingredients and is curated by the experienced head chef Tomaš Reger. Champion bartender Jan Liška crafts complementary beverages for an exceptional dining experience at Element.","address":"Běhounská 7"}', name='get_params_base'), tool_calls=None))], created=1714282295, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=182, prompt_tokens=519, total_tokens=701))
# [2024-04-28 07:31:38,429 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:31:38,431 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrQP8zy3XV7Vu4KtUf2QeCJvEjKI', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282297, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=429, total_tokens=439))
# [2024-04-28 07:31:40,687 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:31:40,689 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrQQlcwT8c4COm6lkOUiNrMIwoOJ', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Hostinec U Semináru","text":"“In the mood for a Czech classic with a bit of nostalgia? Search no more!\\" Come taste the magic of the olden days! Hostinec U Semináru is a stylish restaurant with a unique atmosphere, offering Pilsner beer, and traditional cuisine inspired by the times of the Austro-Hungarian Empire.","brief":"Hostinec U Semináru is a stylish restaurant in Czech Republic offering traditional cuisine inspired by the Austro-Hungarian Empire, with a unique atmosphere and Pilsner beer.","address":"Smetanova 30, Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282298, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=136, prompt_tokens=514, total_tokens=650))
# [2024-04-28 07:31:41,296 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:31:41,298 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrQS5ZtS1CUgMnnGDJfasfao7Q9g', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282300, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=463, total_tokens=473))
# [2024-04-28 07:31:43,720 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:31:43,721 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrQTA0M85qxFxgmSX5CvDzTWysNP', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Kohout NA VÍNĚ","text":"This restaurant specializes in coq au vin (the Czech translation is the name of the restaurant), with the exact preparation changing and reflecting the chefs’ current ideas and skills. It offers more than 200 wines from around the world, with a primary focus on Moravia and Bohemia. For private celebrations and business events, the restaurant offers two tasting menus with annotated wine pairings.","brief":"Restaurant specializing in coq au vin with a variety of wines from around the world, focusing on Moravia and Bohemia. Two tasting menus are available for private celebrations and business events.","address":"Malinovského náměstí 2"}', name='get_params_base'), tool_calls=None))], created=1714282301, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens
choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Singha Thai Restaurant","text":"Singha Thai Restaurant is located in the center of Brno and is known for serving fresh meals made with high-quality ingredients. Their experienced chefs turn these ingredients into works of art. The restaurant caters to vegetarians, vegans, and those who are gluten-sensitive, and focuses on providing a delightful dining experience without the use of glutamate.","brief":"Singha Thai Restaurant in Brno serves fresh meals with high-quality ingredients, catering to vegetarians, vegans, and gluten-sensitive individuals. Their experienced chefs create culinary works of art in a delightful dining atmosphere.","address":"Orlí 6, Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282316, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=137, prompt_tokens=513, total_tokens=650))
# [2024-04-28 07:32:00,035 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:00,037 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrQlejQwX3aDEeZEEqGMnT43Ty3b', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282319, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=436, total_tokens=446))
# [2024-04-28 07:32:02,288 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:02,291 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrQmrrZyVrrZuCHtiP59EQodQvC8', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Soul Bistro","text":"A bistro with a soul. A light, clean interior and simple, high-quality food reflecting the season. People come to Soul for breakfast, work lunches, celebratory dinners with friends, and family parties. You\'ll find here dishes ranging from fluffy cakes to light salads, excellent fish & chips, and shredded-beef sandwiches.","brief":"Soul Bistro is a cozy place with a light, clean interior that offers simple, high-quality food reflecting the season. It is popular for breakfast, work lunches, celebratory dinners with friends, and family parties, serving a variety of dishes like fluffy cakes, light salads, fish & chips, and shredded-beef sandwiches.","address":"Jezuitská 7"}', name='get_params_base'), tool_calls=None))], created=1714282320, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=154, prompt_tokens=521, total_tokens=675))
# [2024-04-28 07:32:03,005 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:03,007 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrQowtUov2k82SsoPQLHjCYcgPBs', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282322, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=435, total_tokens=445))
# [2024-04-28 07:32:05,155 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:05,157 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrQp9nrwFSuIUDRgJ28YwgiwCbvg', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Večerka Brno","text":"Večerka Brno is a café bistro located on Pekařská Street in Brno, Czech Republic. The establishment offers a fusion of Czech and Vietnamese cuisines along with premium coffee and their own kombucha KMBCH coffee. Despite its name meaning convenience store in Czech, it resembles a stylish place rather than a traditional convenience store.","brief":"Večerka Brno is a café bistro in Brno that offers a fusion of Czech and Vietnamese cuisines, premium coffee, and kombucha. It stands out for its stylish ambiance and unique menu offerings.","address":"Pekařská 9, Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282323, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=146, prompt_tokens=520, total_tokens=666))
# [2024-04-28 07:32:05,769 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:05,771 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrQro2rowqA55TMakeVO6rx8czUl', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282325, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=450, total_tokens=460))
# [2024-04-28 07:32:08,432 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:08,434 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrQsWLXDg6rVGo6iNAIfPWiQjzCo', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Cukrárna BezCukru","text":"\\"Delicious desserts for everyone.\\" Everything here feels like a regular cafe. From the rich aroma of Coffee Square coffee to the showcased delicacies. Only this is the first low-carb confectionary in Brno, using zero sugar or flour, so even celiac dieters can enjoy it. The small cream puff with a big heart sells best, and the select ingredients used are just the icing on the proverbial cake.","brief":"Cukrárna BezCukru is a low-carb confectionary in Brno that offers delicious desserts suitable for celiac dieters. Their specialties include a small cream puff with select ingredients.","address":"Novobranská 4, Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282326, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=159, prompt_tokens=535, total_tokens=694))
# [2024-04-28 07:32:09,353 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:09,355 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrQuViaL94CGFpokjEutQ7KypqFX', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282328, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=471, total_tokens=481))
# [2024-04-28 07:32:12,938 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:12,940 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrQv7mPSHHdwUFfE952gRs1DH2De', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"
model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=134, prompt_tokens=518, total_tokens=652))
# [2024-04-28 07:32:23,720 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:23,722 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrR9eIJgI94ys8IG2Tb7fPZZP0r9', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282343, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=490, total_tokens=500))
# [2024-04-28 07:32:27,377 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:27,379 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrRAtvu51rKkM80kaxnrw3a9jirz', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Zemanova cukrárna a kavárna","text":"Located in a functionalist building and protected as a national heritage site, Zemanova cukrárna a kavárna opened its doors in 1937, making it the longest-serving café and confectionary in Brno. It offers traditional Czech desserts, baked goods, premium coffee, and over 30 types of local liquors and spirits, including specialties like \\"Veletržní dort\\" and baked dragons. The interwar vibe of the place also makes it a perfect location for cultural events.","brief":"Zemanova cukrárna a kavárna is a historic café and confectionary in Brno, opened in 1937. It offers traditional Czech desserts, premium coffee, local liquors, and specialties like \\"Veletržní dort\\" and baked dragons. The place\'s interwar ambiance makes it a popular choice for cultural events.","address":"Josefská 4"}', name='get_params_base'), tool_calls=None))], created=1714282344, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=203, prompt_tokens=575, total_tokens=778))
# [2024-04-28 07:32:27,991 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:27,993 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrRDPoZgIjnmTqtrAyDjLWxi6ILd', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282347, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=471, total_tokens=481))
# [2024-04-28 07:32:31,600 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:31,602 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrREX5na5dpRt4hDKH9O1OqLEvCG', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Buchta C","text":"An ideal stop for a quick cup of coffee and something sweet on the Vegetable Market. A younger sister of Buchta B café, this is Zelný trh 10 a small espresso bar hidden in the courtyard at the Vegetable Market. Enjoy its outdoor seating in one of the biggest vertical gardens in the whole country, open year-round. Sweet delicacies are brought here every day from Buchta B to complement their premium coffee from various Czech and European roasting places, or a glass of natural wine made for you by Moravian winemakers.","brief":"Buchta C is a small espresso bar located on Zelný trh 10, offering a variety of premium coffee selections from Czech and European roasting places. Visitors can enjoy outdoor seating in a unique courtyard with a large vertical garden, open year-round. Sweet treats from its sister café, Buchta B, and natural wine from Moravian winemakers are also available.","address":"Zelný trh 10, Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282348, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=215, prompt_tokens=556, total_tokens=771))
# [2024-04-28 07:32:32,588 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:32,590 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrRIHmcAX0P3BBbqKAYlj9JsHp7D', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282352, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=474, total_tokens=484))
# [2024-04-28 07:32:35,569 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:35,571 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrRJBuXul2L7Se6ukC7ZMxm7wLLd', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Café Momenta","text":"\\"A luxurious dessert with great coffee and a breathtaking view as the cherry on the top.\\"\\nThis charming café in the very heart of Brno Zelný trh 2 offers a pleasant and comfortable experience. Filled with the rich aroma of freshly made coffee, with a wide range of delicious desserts and savory snacks, this is where you go when in need of a quiet place or a cozy corner to enjoy some time with friends. A place where every moment matters. A place to talk. A place where time slows down.","brief":"Café Momenta is a charming café located in the heart of Brno, offering a pleasant experience with freshly made coffee, delicious desserts, and savory snacks. It is a perfect spot to enjoy quiet time or catch up with friends in a cozy setting where every moment is valued.","address":"Zelný trh 2, Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282353, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=194, prompt_tokens=559, total_tokens=753))
# [2024-04-28 07:32:36,388 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:36,390 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrRMRHP9Y3z0A0Z2H2IxTjbDULDd', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282356, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=474, total_tokens=484))
# [2024-04-28 07:32:39,643 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:39,645 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrRMtU3hzTNvUMOsRVjA08L45UpN', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Café Placzek","text":"\\"Brunch, a cup of coffee in the afternoon or a drink in the evening at a stylish location.\\" A place to meet up any time of day. From Minoritská 4 a cup of coffee in the morning made from beans from top-quality roasters, alongside home-baked desserts and authentic brunches made with fresh ingredients to mixed drinks or a glass of good wine from local winemakers in the evening. All in a place with an interwar atmosphere and a superb view of the Church of Saint Johns in the very heart of Brno.\\nMinoritská 4\\ncafeplaczek.cz","brief":"Café Placzek is a stylish location in Brno where you can enjoy brunch, coffee, or drinks throughout the day. It offers top-quality coffee, home-baked desserts, authentic brunches, mixed drinks, and local wines in an interwar atmosphere with a panoramic view of the Church of Saint Johns.","address":"Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282356, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=214, prompt_tokens=559, total_tokens=773))
# [2024-04-28 07:32:40,484 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:40,486 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrRQ26auCVx229hr5boN3sk80Li1', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282360, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=431, total_tokens=441))
# [2024-04-28 07:32:42,942 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:42,943 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrRQtBrIVXOFdRZHPdGhikxF9ASP', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Jazzová kavárna Podobrazy","text":"A classic family-friendly café at an ideal spot in the heart of the Moravian capital. A place with a great vibe to pick you up when you’re feeling blue. Enjoy their premium coffee, savor a cocktail in their year-round outdoor seating, and treat your taste buds to one of their locally made mini desserts.","brief":"A classic family-friendly café in the heart of the Moravian capital with a great vibe offering premium coffee, cocktails, and locally made mini desserts.","address":"Zelný trh 14"}', name='get_params_base'), tool_calls=None))], created=1714282360, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=122, prompt_tokens=516, total_tokens=638))
# [2024-04-28 07:32:43,710 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:43,712 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrRTazi2cqRH4dYuNi6qINGXybGE', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282363, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=444, total_tokens=454))
# [2024-04-28 07:32:45,720 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:45,722 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrRUBvKIjBpTUwH1dveHwdmBJa7z', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Kafe Friedrich","text":"A minimalist, living-room-sized café in Brno that serves a perfect cup of coffee made with premium ingredients. The café also offers food and sweets made with local ingredients, except for their premium coffee. Guests can enjoy a moment of relaxation in summer by sitting in its window or on a bench.","brief":"Kafe Friedrich is a small café in Brno known for serving high-quality coffee and locally sourced food and sweets. It offers a cozy atmosphere for guests to relax and enjoy their premium coffee.","address":"Smetanova 45"}', name='get_params_base'), tool_calls=None))], created=1714282364, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=116, prompt_tokens=529, total_tokens=645))
# [2024-04-28 07:32:46,321 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:46,323 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrRVEOmQQH74GPXxIJm9cjkq5Ceb', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282365, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=453, total_tokens=463))
# [2024-04-28 07:32:48,983 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:32:48,985 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# ...
# [2024-04-28 07:36:13,376 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:36:13,378 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# [2024-04-28 07:36:13,380 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: ChatCompletion(id='chatcmpl-9IrUpehzgyNgLbDGQJaCGXu9ntXfC', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Brno Public Transport Ticket Purchase Process","text":"In order to buy a transferable public transport ticket for Brno Public Transport online, you need to create a registration on the eshop of BrnoID.cz using only an email address and setting up a password. The process involves adding a ticket carrier, selecting a ticket, choosing the start date and time of validity, and selecting a payment method (either GoPay or Pay via OFFLINE bank transfer). Immediate transfers for the ticket are limited, and further transfers require a 10-minute delay.","brief":"Guide on purchasing transferable public transport tickets for Brno Public Transport online, including registration on eshop, selecting ticket carrier, choosing validity start, and payment methods. Immediate transfers are limited, with further transfers requiring a delay of 10 minutes.","address":"Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282571, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=171, prompt_tokens=831, total_tokens=1002))
# [2024-04-28 07:36:13,731 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:13,733 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:13,990 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:13,991 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:14,399 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:14,400 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:14,850 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:14,852 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:15,218 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:15,220 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:15,841 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:15,843 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:16,243 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:16,245 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:16,652 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:16,654 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:17,062 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:17,064 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:17,471 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:17,473 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:17,871 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:17,873 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:18,290 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:18,292 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:18,700 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:18,701 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:19,110 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:19,634 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:36:19,637 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: ChatCompletion(id='chatcmpl-9IrUx1HZEgJtoDAFWri2dmiThtguq', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_event'), tool_calls=None))], created=1714282579, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=605, total_tokens=615))
# [2024-04-28 07:36:20,134 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:20,733 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:36:20,735 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrUy63hh8vusw4j16TIn5RXWRcYR', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282580, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=530, total_tokens=540))
# [2024-04-28 07:36:25,564 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:36:25,567 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrUzrB6KtpolTwwfqm0QdLydrtuX', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Relaxation under the stars at Small Planetarium","text":"Please note that the show is not taking place in the new digitalarium, but in a small planetarium. Even though it is already an old man, it can conjure up a beautiful starry sky, which you won\'t see anywhere in overlit Brno. Come and relax and sit under the stars for a while, sometimes in silence... The small planetarium is open to the public and is suitable for individuals aged 15 and above. The show lasts for 30 minutes and takes place in the small planetarium. The upcoming performance dates are as follows: 26. 4. 2024 at 17:15, 3. 5. 2024 at 17:15, 10. 5. 2024 at 17:15, 17. 5. 2024 at 17:15, 24. 5. 2024 at 17:15, and 31. 5. 2024 at 17:15.","brief":"Experience relaxation under the stars at the Small Planetarium in Brno. Enjoy a beautiful starry sky away from the city lights while sitting in silence during the 30-minute show. Open to individuals aged 15 and above, the upcoming performance dates are available for those seeking a unique stargazing experience.","address":"Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282581, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=292, prompt_tokens=615, total_tokens=907))
# [2024-04-28 07:36:26,175 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:36:26,178 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: static
# Response: ChatCompletion(id='chatcmpl-9IrV3zxsbMue0FpGTGjtsiFKUQAAC', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_static'), tool_calls=None))], created=1714282585, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=520, total_tokens=530))
# [2024-04-28 07:36:30,168 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:36:30,170 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# [2024-04-28 07:36:30,171 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: ChatCompletion(id='chatcmpl-9IrV5PBI8SY8Mu6HcqYvWlwjaQmks', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Black Holes 2D","text":"We all know the term: black hole. But what kind of space objects are they? Black holes are extreme in all their properties. If we approach them at a certain, very small distance (the so-called event horizon), we cannot escape the clutches of their gravitational field except by moving faster than light. But nothing in the universe can move that fast.\\n\\n- Suitable for ages 12 and up\\n- Duration: 55 minutes\\n- The performance includes a tour of the artificial sky\\n- English audio available\\n- The show is simultaneously projected with English audio in headphones. It may, however, contain a live part presented in Czech language exclusively. Headphones are available on request at the ticket desk. The deposit for headphones is 100 CZK per piece (cash only).","brief":"An educational show on black holes, suitable for ages 12 and up. The show lasts for 55 minutes and includes a tour of the artificial sky. English audio is available with the option of Czech language for some live parts. Headphones with a deposit of 100 CZK per piece are available at the ticket desk.","address":"Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282587, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=247, prompt_tokens=605, total_tokens=852))
# [2024-04-28 07:36:30,578 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:30,579 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:31,090 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:31,092 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:31,499 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:31,501 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:31,749 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:32,421 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:36:32,424 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: ChatCompletion(id='chatcmpl-9IrV9pkxWNWsu7V9yVIvIS8AMJGqP', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_event'), tool_calls=None))], created=1714282591, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=10, prompt_tokens=622, total_tokens=632))
# [2024-04-28 07:36:32,933 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:32,935 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:33,445 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:33,446 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:33,834 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:36:33,836 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:36:34,264 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"

# %%
gpt4_t, gpt4_p = get_classified(gpt4, df)
# Out:
# [2024-04-28 07:36:36,005 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:36:36,007 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrVCTtwQLaUvXGP7QRYPRAYrMLdJ', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282594, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=434, total_tokens=444))
# [2024-04-28 07:36:44,300 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:36:44,303 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrVEf04AohWvFv8wC0U3Thp1Ps8V', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Element Restaurant","text":"“An excellent fusion of top-quality meals and original drinks, ideal for a dinner with your partner or friends.\\" Element combines first-rate food and cocktails. Behind its globally inspired menu from local ingredients stands the well-travelled head chef Tomaš Reger, who has gained culinary experience from around the world. His food is complemented by drinks from champion bartender Jan Liška.","brief":"Element Restaurant offers a fine blend of high-quality cuisine and unique beverages. The menu, globally inspired yet based on local ingredients, is crafted by experienced head chef Tomaš Reger. The culinary offerings are paired with creations by award-winning bartender Jan Liška.","address":"Běhounská 7"}', name='get_params_base'), tool_calls=None))], created=1714282596, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=151, prompt_tokens=519, total_tokens=670))
# [2024-04-28 07:36:46,348 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:36:46,349 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrVMxZsiGtHZSXaIPEuvI5haIQs5', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282604, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=429, total_tokens=439))
# [2024-04-28 07:37:01,401 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:37:01,403 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrVOYOHvk3X2kMgBWmHI4Y5nnakJ', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Hostinec U Semináru","text":"“In the mood for a Czech classic with a bit of nostalgia? Search no more!\\"\\nCome taste the magic of the olden days! Smetanova 30 U Semináru is a stylish restaurant with a unique atmosphere, Pilsner beer, and traditional cuisine inspired by the times of the Austro-Hungarian Empire.","brief":"Hostinec U Semináru offers a nostalgic dining experience with traditional Czech cuisine inspired by the Austro-Hungarian era. The restaurant features a unique atmosphere and serves Pilsner beer. It is located at Smetanova 30.","address":"Smetanova 30"}', name='get_params_base'), tool_calls=None))], created=1714282606, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_46a93fa712', usage=CompletionUsage(completion_tokens=143, prompt_tokens=514, total_tokens=657))
# [2024-04-28 07:37:02,635 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:37:02,638 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrVdjySd92hNoywZCKbkvwQGgNiN', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282621, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=463, total_tokens=473))
# [2024-04-28 07:37:08,978 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:37:08,981 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrVeMaqZcEB12ODR4IXotNoy5jKX', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Kohout NA VÍNĚ","text":"This restaurant specializes in coq au vin (the Czech translation is the name of the restaurant), with the exact preparation changing and reflecting the chefs’ current ideas and skills. It offers more than 200 wines from around the world, with a primary focus on Moravia and Bohemia. For private celebrations and business events, the restaurant offers two tasting menus with annotated wine pairings.","brief":"Kohout NA VÍNĚ is a restaurant specializing in coq au vin and offers a wide selection of over 200 wines focused primarily on Moravia and Bohemia. The preparation of their signature dish varies to reflect the chefs\' creativity. They also provide tasting menus with annotated wine pairings for private and business events.","address":"Malinovského náměstí 2"}', name='get_params_base'), tool_calls=None))], created=1714282622, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=176, prompt_tokens=548, total_tokens=724))
# [2024-04-28 07:37:10,002 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:37:10,004 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrVluUKAGrw5FfKQ8XMDaqRLCpds', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282629, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=447, total_tokens=457))
# [2024-04-28 07:37:16,352 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:37:16,355 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrVmB5hBIcRsvR4jZblY9UVem6ZD', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"MANYA Sushi & Sake Izakaya","text":"Not a bistro or just another sushi bar. This is MANYA – Izakaya! opened the gate to Tokyo at night at Průchodní 2 and pass under Godzilla to share big and small bowls overflowing with Japanese food or delicate sushi, while absorbing the informal atmosphere as well as Japanese sake.","brief":"MANYA Sushi & Sake Izakaya offers a unique dining experience in Brno, capturing the spirit of a Tokyo night. Located at Průchodní 2, guests can pass under a Godzilla figure to enjoy overflowing bowls of Japanese cuisine and delicate sushi. The restaurant combines an informal atmosphere with a variety of sake.","address":"Průchodní 2"}', name='get_params_base'), tool_calls=None))], created=1714282630, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=160, prompt_tokens=532, total_tokens=692))
# [2024-04-28 07:37:17,580 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:37:17,583 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrVsusYUnuLCQzy7datq0xcCfxFC', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282636, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=460, total_tokens=470))
# [2024-04-28 07:37:24,237 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:37:24,239 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrVtO8XCecuWsw83zrL3NUPxZBHS', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Mikrofarma Bistro","text":"Perfectly crafted street food with excellent, slowly dry-aged meat by Moravian farmers. And the only bistro where you can get a cut-up steak in a cone to go. Pastrami in a sandwich, home-made sauce and brioche burger buns, with no chemicals needed! Add lemonades, good wine, fizzy drinks, and regional draught beer.","brief":"Mikrofarma offers an exceptional selection of street food featuring slowly dry-aged meat from Moravian farmers. Unique offerings include cut-up steak in a cone and chemical-free sandwiches with homemade sauce. The bistro also serves lemonades, good wines, fizzy drinks, and regional draught beer.","address":"Běhounská 18"}', name='get_params_base'), tool_calls=None))], created=1714282637, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=162, prompt_tokens=545, total_tokens=707))
# [2024-04-28 07:37:25,540 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:37:25,543 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrW0qKtFGtrVYNEnAZOuRyDgt58d', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282644, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=481, total_tokens=491))
# [2024-04-28 07:37:32,736 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:37:32,738 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrW1bjUGZhjFOhXtqZ50laorBRBK', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Ramen Brno Restaurant","text":"Ramen Brno offers a unique dining experience with a focus on freshly made Japanese ramen combining popular Czech flavours. Bowls are filled with homemade noodles in strong broths, enhanced with variously flavoured oils, and topped with marinated eggs, slow-cooked meat, and a variety of other ingredients. The food is prepared in a few minutes in an open kitchen, showcasing the fast food nature of the establishment. Ramen Brno also operates a second location at Křenová 62a.","brief":"Ramen Brno serves freshly made Japanese ramen with a Czech twist, featuring homemade noodles, strong broths, and various toppings. The food is quickly prepared in an open kitchen, emphasizing its fast food aspect. A second branch is located at Křenová 62a.","address":"Václavská 16, Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282645, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=191, prompt_tokens=566, total_tokens=757))
# [2024-04-28 07:37:34,067 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:37:34,068 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrW862386VMcMu2HxZMoBqzgcMVX', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282652, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=428, total_tokens=438))
# [2024-04-28 07:37:41,509 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:37:41,511 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrWAZ90S2hg3YsNOLrHKeYut10jg', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Singha Thai Restaurant","text":"“Serving fresh meals with a smile while absolutely spoiling you.\\" This Thai restaurant in the centre of Brno focuses on fresh, high-quality ingredients that you can watch get turned into works of art by their experienced chefs. Forget all about glutamate! This place also caters to vegetarians, vegans, and the gluten-sensitive.","brief":"Singha Thai Restaurant in Brno offers a culinary experience with fresh, high-quality ingredients and dishes free from glutamate. Their menu accommodates vegetarians, vegans, and those sensitive to gluten. The chefs prepare meals in an open kitchen, allowing customers to observe the art of cooking.","address":"Orlí 6, Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282654, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=152, prompt_tokens=513, total_tokens=665))
# [2024-04-28 07:37:42,566 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:37:42,568 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrWH9XlSC7pKo1ZmdLU7HMLcVmCV', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282661, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=436, total_tokens=446))
# [2024-04-28 07:37:50,246 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:37:50,248 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrWIgrWizaKSgui7MiOGxcM2kIEo', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Soul Bistro","text":"A bistro with a soul. A light, clean interior and simple, high-quality food reflecting the season. People come to Soul for breakfast, work lunches, celebratory dinners with friends, and family parties. You’ll find here dishes ranging from fluffy cakes to light salads, excellent fish & chips, and shredded-beef sandwiches.","brief":"Soul Bistro is described as a cozy place perfect for spending time with loved ones, offering a variety of dishes suitable for any meal of the day. The interior is clean and simple, focusing on high-quality, seasonal food. It\'s a venue for breakfast, work lunches, dinners with friends, and family parties.","address":"Jezuitská 7, Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282662, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=158, prompt_tokens=521, total_tokens=679))
# [2024-04-28 07:37:51,885 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:37:51,887 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrWQm1lYUznN3Wi7UX8rLQTUtySZ', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282670, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=435, total_tokens=445))
# [2024-04-28 07:38:03,251 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:38:03,253 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrWS1mZjEqzBAvs4M9MZDt9g0ogf', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Večerka Brno: A Unique Culinary Experience","text":"Večerka Brno, though named after a convenience store, is not your typical venue filled with random items. Instead, it\'s a café bistro located on Pekařská Street where the team daringly blends Czech and Vietnamese cuisines, offering a unique dining experience. Alongside their inventive dishes, they serve premium coffee and their own brand of kombucha named KMBCH coffee.","brief":"Večerka Brno combines Czech and Vietnamese cuisines in a chic café bistro setting. The venue also offers premium coffee and their own kombucha. Located on Pekařská Street, it provides a unique culinary experience.","address":"Pekařská 9, Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282672, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=165, prompt_tokens=520, total_tokens=685))
# [2024-04-28 07:38:04,173 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:38:04,175 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrWdYG4kLUsNY6aYld5BcwnHCK9Q', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282683, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=450, total_tokens=460))
# [2024-04-28 07:38:13,195 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:38:13,200 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrWeHxooZ5Lc0SBTeAfolQcbEdul', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Cukrárna BezCukru: A Low-Carb Confectionary","text":"Cukrárna BezCukru is Brno\'s first low-carb confectionery that stands out for using zero sugar or flour in its offerings. This makes it a unique spot for even celiac dieters to enjoy delicious desserts. The café feels like a typical one, complete with the rich aroma of Coffee Square coffee and a showcase of delicacies, but it caters specially to those seeking healthier dessert alternatives. The small cream puff, notable for its heartfelt creation, is the best-selling item, and the high-quality select ingredients used further enhance the indulgence of each treat.","brief":"Cukrárna BezCukru is Brno\'s unique low-carb confectionery, offering desserts without sugar or flour, making it suitable even for celiac dieters. It features a café-like ambiance with a special focus on healthier dessert options. The most popular item is the small cream puff, celebrated for both its quality and heartwarming preparation.","address":"Novobranská 4"}', name='get_params_base'), tool_calls=None))], created=1714282684, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=225, prompt_tokens=535, total_tokens=760))
# [2024-04-28 07:38:14,106 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:38:14,108 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrWnq6qrgdYGJvAwgQ92Jk8BMVuK', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282693, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=471, total_tokens=481))
# [2024-04-28 07:38:25,729 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:38:25,731 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrWo42Q4NUf70Q5lJSobB6pKNIpj', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"
Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282727, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=181, prompt_tokens=518, total_tokens=699))
# [2024-04-28 07:38:55,782 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:38:55,784 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrXSeWN1LuLmhpDeZnvAv9ckgXMR', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282734, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=490, total_tokens=500))
# [2024-04-28 07:39:04,282 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:39:04,285 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrXUMzqBn4OtjdVS55Pp6wbQs7HI', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Zemanova cukrárna a kavárna: A Vintage Cafe Experience","text":"Located in a functionalist building, protected as a national heritage site, Zemanova cukrárna a kavárna opened its doors in 1937, making this café and confectionary the longest-serving in Brno. Offering traditional Czech desserts, baked goods, premium coffee, and over 30 types of local liquors and spirits, it boasts several specialties, such as \\"Veletržní dort\\" and baked dragons. And its interwar vibe makes it an ideal place for the cultural events that take place here from time to time.","brief":"Zemanova cukrárna a kavárna, established in 1937, is housed in a national heritage site and serves as the oldest café in Brno. It offers traditional Czech desserts, premium coffee, and a variety of local liquors. Its vintage interwar ambiance makes it a popular venue for occasional cultural events.","address":"Josefská 4"}', name='get_params_base'), tool_calls=None))], created=1714282736, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=212, prompt_tokens=575, total_tokens=787))
# [2024-04-28 07:39:06,368 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:39:06,370 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrXc8mzShUjQVUMndZCXQLf38EH1', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282744, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=471, total_tokens=481))
# [2024-04-28 07:39:16,160 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:39:16,162 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrXeoEGslvEXspBZ3EZCwhsQy5jS', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Buchta C Café","text":"A younger sister of Buchta B café, this is a small espresso bar located at Zelný trh 10, hidden in the courtyard at the Vegetable Market. The café features outdoor seating in one of the largest vertical gardens in the country, which remains open year-round. Daily, sweet delicacies are transported from Buchta B to complement their premium coffee, sourced from various Czech and European roasters, or you can enjoy a glass of natural wine crafted by Moravian winemakers.","brief":"Buchta C is a quaint espresso bar nestled in the Vegetable Market at Zelný trh 10, boasting one of the country\'s largest vertical gardens. It offers premium coffee and sweet delicacies daily, sourced from its sister café, Buchta B, along with natural wine from Moravian winemakers.","address":"Zelný trh 10, Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282746, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=192, prompt_tokens=556, total_tokens=748))
# [2024-04-28 07:39:17,347 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:39:17,349 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrXoxaaLnxkAet4dRpxlCfjAuNBR', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282756, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=474, total_tokens=484))
# [2024-04-28 07:39:23,908 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:39:23,910 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrXp0adFo4vzy4nNTfUdFhCC4Kv9', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Café Momenta","text":"“A luxurious dessert with great coffee and a breathtaking view as the cherry on the top.\\" This charming café in the very heart of Brno Zelný trh 2 offers a pleasant and comfortable experience. Filled with the rich aroma of freshly made coffee, with a wide range of delicious desserts and savory snacks, this is where you go when in need of a quiet place or a cozy corner to enjoy some time with friends. A place where every moment matters. A place to talk. A place where time slows down.","brief":"Café Momenta is renowned for its luxurious desserts paired with excellent coffee, enjoyed with a stunning view, located at Zelný trh 2 in Brno. It offers a cozy environment perfect for quiet solitude or a comfortable gathering with friends. The café\'s ambiance is accentuated by the rich aroma of fresh coffee and a selection of delicious treats.","address":"Zelný trh 2, Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282757, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=207, prompt_tokens=559, total_tokens=766))
# [2024-04-28 07:39:24,902 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:39:24,904 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrXwe39x5J9zFNV8uXwCepnCROeD', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282764, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=474, total_tokens=484))
# [2024-04-28 07:39:34,183 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:39:34,185 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrXxFyc4M8PhlevKbsFO0BDeIk6t', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Café Placzek in Brno","text":"“Brunch, a cup of coffee in the afternoon or a drink in the evening at a stylish location.\\" A place to meet up any time of day. From Minoritská 4 a cup of coffee in the morning made from beans from top-quality roasters, alongside home-baked desserts and authentic brunches made with fresh ingredients to mixed drinks or a glass of good wine from local winemakers in the evening. All in a place with an interwar atmosphere and a superb view of the Church of Saint Johns in the very heart of Brno.","brief":"Café Placzek is a stylish café located in Brno, offering everything from morning coffee to evening drinks. It serves coffee made from beans supplied by top-quality roasters, fresh home-baked desserts, authentic brunches, and a selection of drinks and wines in the evening. The café features an interwar atmosphere and stunning views of the Church of Saint Johns.","address":"Minoritská 4"}', name='get_params_base'), tool_calls=None))], created=1714282765, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=214, prompt_tokens=559, total_tokens=773))
# [2024-04-28 07:39:35,309 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:39:35,311 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrY6noUq6TgpaRL9XiZ3gvDWmVZe', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282774, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=431, total_tokens=441))
# [2024-04-28 07:39:42,375 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:39:42,377 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrY7jH5OQ2Cvr4uf9YviLSsvSOY2', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Jazzová kavárna Podobrazy in Brno","text":"Jazzová kavárna Podobrazy is described as a classic family-friendly café, located ideally in the heart of the Moravian capital. It offers a great ambiance that can lighten up your mood, serving premium coffee, cocktails available for enjoying in their year-round outdoor seating, and a variety of locally made mini desserts.","brief":"Jazzová kavárna Podobrazy is a family-friendly café in the heart of Brno, known for its premium coffee and variety of cocktails and mini desserts. The café features an excellent ambiance and year-round outdoor seating. A perfect spot to relax and enjoy local delicacies.","address":"Zelný trh 14, Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714282775, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=164, prompt_tokens=516, total_tokens=680))
# [2024-04-28 07:39:44,067 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:39:44,069 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: place
# Response: ChatCompletion(id='chatcmpl-9IrYE5Uf3SqhG2XGNtp1oVoRRAXE1', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_place'), tool_calls=None))], created=1714282782, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=444, total_tokens=454))
# [2024-04-28 07:39:51,006 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:39:51,008 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9IrYG6puPKSb8FsKsMhZfBgOsw8w9', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Kafe Friedrich: Cozy Café in Brno","text":"A perfect cup of coffee served by the nicest staff in Brno. A minimalist, living-room-sized café which prepares all the food and sweets using ingredients that aren’t from the other side of the planet, with the exception of their premium coffee, which will show the other ingredients the wonderful ways of the world. In summer, you can sit down in its window or on a bench and enjoy a moment of sweet laziness.","brief":"Kafe Friedrich is a cozy café in Brno known for its perfect coffee and friendly staff. They focus on sustainable local ingredients for their food and sweets, while their premium coffee provides a global touch. The café offers a relaxing spot with options to sit by the window or on a bench during summer.","address":"Smetanova 45"}', name='get_params_base'), tool_calls=None))], created=1714282784, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=172, prompt_tokens=529, total_tokens=701))
# ...
# [2024-04-28 07:52:48,199 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:52:48,201 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# [2024-04-28 07:52:48,202 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: administration
# Response: ChatCompletion(id='chatcmpl-9IrkkpzK9GJfwBdVVIVw2dzuSvJH3', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Brno Public Transport Ticket Purchase and Verification Process","text":"After the first purchase of your public transport ticket, you also need to verify your personal data, either online or directly at one of the verification places. Detailed instructions for data verification can be found under \\"Where and how can you verify your personal information to get a full account or discounts entitlements ? And what is needed for it?” The period for verification of personal data is 30 days after purchasing a non-transferable ticket. In the case of temporarily assigned discount categories (which you have chosen by yourself with \\"Resolve\\" button), you have a shorter period of 5 working days to verify your selected discount entitlement (otherwise it will expire and result in shortening of the ticket validity for tickets for zones 100 and 101, or blocking of the ticket in other cases). The time limit for verifying the personal data mentioned above may continue to run if you do not have that data verified).","brief":"When purchasing a ticket for Brno Public Transport, it is necessary to verify personal details either online or at verification centers. A time period of 30 days is provided for verification post-purchase of a non-transferable ticket. For self-selected discount categories, a shorter verification period of 5 working days applies; failure to verify in time can lead to the loss of discounts or ticket validity.","address":"Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714283558, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=282, prompt_tokens=615, total_tokens=897))
# [2024-04-28 07:53:06,426 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:53:06,429 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# [2024-04-28 07:53:06,430 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: ChatCompletion(id='chatcmpl-9IrkuGO5NlEZ5QXTSBGOxgt6ped56', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"How to Purchase a Public Transport Ticket in Brno Online","text":"In order to buy a transferable public transport ticket you need to create a registration on eshop of BrnoID.cz (using just an e-mail adress and setting up your password). In order to buy it, just click on \\"Buy a ticket\\" button on the left side of the eshop. First you need to add a ticket carrier by using button \\"Add a new ticket carrier\\" and then select him with \\"Select a carrier\\". Next step is selecting a ticket itself and when you’re done, confirm it with \\"Select\\" button. As the last step you have to select a date and time when the validity of the ticket should start. You can select any date including the day when you are buying it, up to 30 days in advance. This step is confirmed using \\"Add to cart button\\" and then you have to confirm the whole selection with \\"Proceed to checkout\\" button. Now you can select the method of payment. You can select either the option of paying using GoPay that enables you to pay using internet banking of some banks, or you can pay via bank card online. If you don’t want to use this method, you can select the second one, but only if your transportation card begins its validity in 5 or more working days. This method is called Pay via OFFLINE bank transfer. If you’ll select GoPay, your payment will only need to be confirmed – you don’t need to fill anything in it. As for the second method, you’ll obtain data needed to make the payment. Attention: if you need to transfer this ticket to another carrier, this is limited by the number of immediate transfers (for short-term transfers to two, up to six for one-year portable salvia). Further transfers, after the immediate transfer limit is exceeded, are only possible with a 10-minute delay, after which the required transfer will need to be finally confirmed.","brief":"To purchase a transferable ticket for Brno public transport online, users must register at BrnoID.cz, select and confirm their ticket choices, and choose a payment method. Immediate transfer of tickets is limited, with further transfers only after a 10-minute delay. Options are provided for payment including GoPay and offline bank transfer, dependent on time constraints.","address":"Brno, Czech Republic"}', name='get_params_base'), tool_calls=None))], created=1714283568, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=481, prompt_tokens=831, total_tokens=1312))
# [2024-04-28 07:53:06,708 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:06,709 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:07,041 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:07,042 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:07,450 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:07,452 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:07,731 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:07,733 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:08,065 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:08,066 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:08,372 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:08,373 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:08,654 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:08,655 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:08,986 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:08,988 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:09,294 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:09,295 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:09,601 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:09,602 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:09,908 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:09,910 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:10,215 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:10,217 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:10,523 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:10,524 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:10,829 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:11,647 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:53:11,649 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: ChatCompletion(id='chatcmpl-9IrlHMlOgfETEnZVEmLCBkEHwDUKC', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_event'), tool_calls=None))], created=1714283591, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=605, total_tokens=615))
# [2024-04-28 07:53:11,956 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:13,287 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:53:13,289 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: ChatCompletion(id='chatcmpl-9IrlIK30C06e3vVEOEVPnQAs0t5Ts', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_event'), tool_calls=None))], created=1714283592, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=530, total_tokens=540))
# [2024-04-28 07:53:13,594 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:15,335 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:53:15,338 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: ChatCompletion(id='chatcmpl-9IrlJmU709HmHUVsyfQrqfoHoE8w1', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_event'), tool_calls=None))], created=1714283593, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=520, total_tokens=530))
# [2024-04-28 07:53:15,632 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:15,633 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:15,950 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:15,951 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:16,257 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:16,258 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:16,564 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:16,565 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:16,872 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:17,828 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 07:53:17,830 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# Response: ChatCompletion(id='chatcmpl-9IrlNPEzVZX9K2s74cHkQIE5OOfHu', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{}', name='assign_event'), tool_calls=None))], created=1714283597, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=10, prompt_tokens=622, total_tokens=632))
# [2024-04-28 07:53:18,202 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:18,204 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:18,509 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:18,511 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:18,768 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"
# [2024-04-28 07:53:18,769 content_parsing.py->get_parsed_content_by_divided_function_call():94]INFO: Content type: event
# [2024-04-28 07:53:19,124 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 400 Bad Request"

# %%
df['mixtral'] = mixtral_t
df['llama3_70'] = llama3_70_t
df['llama2_70'] = llama2_70_t
df['llama3_8'] = llama3_8_t
df['gpt3'] = gpt3_t
df['gpt4'] = gpt4_t

df['mixtral_parsed'] = mixtral_p
df['llama3_70_parsed'] = llama3_70_p
df['llama2_70_parsed'] = llama2_70_p
df['llama3_8_parsed'] = llama3_8_p
df['gpt3_parsed'] = gpt3_p
df['gpt4_parsed'] = gpt4_p

df.to_csv('divided-function-call.csv')

# %%
df_path = '/home/rinaen/PycharmProjects/communication_agent/testing/divided-function-call.csv'
df = pd.read_csv(df_path)

# %%
df['mixtral_same'] = df['mixtral'] == df['type']
df['llama3_70_same'] = df['llama3_70'] == df['type']
df['llama2_70_same'] = df['llama2_70'] == df['type']
df['llama3_8_same'] = df['llama3_8'] == df['type']
df['gpt3_same'] = df['gpt3'] == df['type']
df['gpt4_same'] = df['gpt4'] == df['type']

# %%
mixtral_same = df['mixtral_same'].sum()
llama3_70_same = df['llama3_70_same'].sum()
llama2_70_same = df['llama2_70_same'].sum()
llama3_8_same = df['llama3_8_same'].sum()
gpt3_same = df['gpt3_same'].sum()
gpt4_same = df['gpt4_same'].sum()

# %%
mixtral_none = df['mixtral'].isna().sum()
llama3_70_none = df['llama3_70'].isna().sum()
llama2_70_none = df['llama2_70'].isna().sum()
llama3_8_none = df['llama3_8'].isna().sum()
gpt3_none = df['gpt3'].isna().sum()
gpt4_none = df['gpt4'].isna().sum()

# %%
place_df = df[df['type'] == 'place']
mixtral_same_place = place_df['mixtral_same'].sum()
llama3_70_same_place = place_df['llama3_70_same'].sum()
llama2_70_same_place = place_df['llama2_70_same'].sum()
llama3_8_same_place = place_df['llama3_8_same'].sum()
gpt3_same_place = place_df['gpt3_same'].sum()
gpt4_same_place = place_df['gpt4_same'].sum()

# %%
static_df = df[df['type'] == 'static']
mixtral_same_static = static_df['mixtral_same'].sum()
llama3_70_same_static = static_df['llama3_70_same'].sum()
llama2_70_same_static = static_df['llama2_70_same'].sum()
llama3_8_same_static = static_df['llama3_8_same'].sum()
gpt3_same_static = static_df['gpt3_same'].sum()
gpt4_same_static = static_df['gpt4_same'].sum()

# %%
administration_df = df[df['type'] == 'administration']
mixtral_same_administration = administration_df['mixtral_same'].sum()
llama3_70_same_administration = administration_df['llama3_70_same'].sum()
llama2_70_same_administration = administration_df['llama2_70_same'].sum()
llama3_8_same_administration = administration_df['llama3_8_same'].sum()
gpt3_same_administration = administration_df['gpt3_same'].sum()
gpt4_same_administration = administration_df['gpt4_same'].sum()

# %%
event_df = df[df['type'] == 'event']
mixtral_same_event = event_df['mixtral_same'].sum()
llama3_70_same_event = event_df['llama3_70_same'].sum()
llama2_70_same_event = event_df['llama2_70_same'].sum()
llama3_8_same_event = event_df['llama3_8_same'].sum()
gpt3_same_event = event_df['gpt3_same'].sum()
gpt4_same_event = event_df['gpt4_same'].sum()

# %%
mixtral_same = str(mixtral_same) + ' %'
llama3_70_same = str(llama3_70_same) + ' %'
llama2_70_same = str(llama2_70_same) + ' %'
llama3_8_same = str(llama3_8_same) + ' %'
gpt3_same = str(gpt3_same) + ' %'
gpt4_same = str(gpt4_same) + ' %'

mixtral_none = str(mixtral_none) + ' %'
llama3_70_none = str(llama3_70_none) + ' %'
llama2_70_none = str(llama2_70_none) + ' %'
llama3_8_none = str(llama3_8_none) + ' %'
gpt3_none = str(gpt3_none) + ' %'
gpt4_none = str(gpt4_none) + ' %'

mixtral_same_place = str(mixtral_same_place / len(place_df) * 100) + ' %'
llama3_70_same_place = str(llama3_70_same_place / len(place_df) * 100) + ' %'
llama2_70_same_place = str(llama2_70_same_place / len(place_df) * 100) + ' %'
llama3_8_same_place = str(llama3_8_same_place / len(place_df) * 100) + ' %'
gpt3_same_place = str(gpt3_same_place / len(place_df) * 100) + ' %'
gpt4_same_place = str(gpt4_same_place / len(place_df) * 100) + ' %'

mixtral_same_static = str(mixtral_same_static / len(static_df) * 100) + ' %'
llama3_70_same_static = str(llama3_70_same_static / len(static_df) * 100) + ' %'
llama2_70_same_static = str(llama2_70_same_static / len(static_df) * 100) + ' %'
llama3_8_same_static = str(llama3_8_same_static / len(static_df) * 100) + ' %'
gpt3_same_static = str(gpt3_same_static / len(static_df) * 100) + ' %'
gpt4_same_static = str(gpt4_same_static / len(static_df) * 100) + ' %'

mixtral_same_administration = str(mixtral_same_administration / len(administration_df) * 100) + ' %'
llama3_70_same_administration = str(llama3_70_same_administration / len(administration_df) * 100) + ' %'
llama2_70_same_administration = str(llama2_70_same_administration / len(administration_df) * 100) + ' %'
llama3_8_same_administration = str(llama3_8_same_administration / len(administration_df) * 100) + ' %'
gpt3_same_administration = str(gpt3_same_administration / len(administration_df) * 100) + ' %'
gpt4_same_administration = str(gpt4_same_administration / len(administration_df) * 100) + ' %'

mixtral_same_event = str(mixtral_same_event / len(event_df) * 100) + ' %'
llama3_70_same_event = str(llama3_70_same_event / len(event_df) * 100) + ' %'
llama2_70_same_event = str(llama2_70_same_event / len(event_df) * 100) + ' %'
llama3_8_same_event = str(llama3_8_same_event / len(event_df) * 100) + ' %'
gpt3_same_event = str(gpt3_same_event / len(event_df) * 100) + ' %'
gpt4_same_event = str(gpt4_same_event / len(event_df) * 100) + ' %'

# %%
eval_df = pd.DataFrame({
    'Model': ['mixtral', 'llama3_70b', 'llama2_70b', 'llama3_8b', 'gpt-3.5', 'gpt-4'],
    'Celkem správně': [mixtral_same, llama3_70_same, llama2_70_same, llama3_8_same, gpt3_same, gpt4_same],
    'Špatný formát': [mixtral_none, llama3_70_none, llama2_70_none, llama3_8_none, gpt3_none, gpt4_none],
    'place': [mixtral_same_place, llama3_70_same_place, llama2_70_same_place, llama3_8_same_place, gpt3_same_place,
              gpt4_same_place],
    'static': [mixtral_same_static, llama3_70_same_static, llama2_70_same_static, llama3_8_same_static,
               gpt3_same_static, gpt4_same_static],
    'administration': [mixtral_same_administration, llama3_70_same_administration, llama2_70_same_administration,
                       llama3_8_same_administration, gpt3_same_administration, gpt4_same_administration],
    'event': [mixtral_same_event, llama3_70_same_event, llama2_70_same_event, llama3_8_same_event, gpt3_same_event,
              gpt4_same_event],
})

eval_df.to_csv('eval_divided_function_call_cls.csv')

# %%
display(eval_df)
# Out:
#         Model Celkem správně Špatný formát    place   static administration  \
# 0     mixtral           99 %           0 %  100.0 %  100.0 %        100.0 %
# 1  llama3-70b          100 %           0 %  100.0 %  100.0 %        100.0 %
# 2  llama2-70b           74 %          26 %    0.0 %  100.0 %        100.0 %
# 3   llama3-8b           99 %           0 %   96.0 %  100.0 %        100.0 %
# 4     gpt-3.5          100 %           0 %  100.0 %  100.0 %        100.0 %
# 5       gpt-4          100 %           0 %  100.0 %  100.0 %        100.0 %
#
#      event
# 0   96.0 %
# 1  100.0 %
# 2   96.0 %
# 3  100.0 %
# 4  100.0 %
# 5  100.0 %

# %%
mixtral_ok_p = str(df['mixtral_parsed'].notna().sum()) + ' %'
llama3_70_ok_p = str(df['llama3_70_parsed'].notna().sum()) + ' %'
llama2_70_ok_p = str(df['llama2_70_parsed'].notna().sum()) + ' %'
llama3_8_ok_p = str(df['llama3_8_parsed'].notna().sum()) + ' %'
gpt3_ok_p = str(df['gpt3_parsed'].notna().sum()) + ' %'
gpt4_ok_p = str(df['gpt4_parsed'].notna().sum()) + ' %'

# %%
mixtral_ok_p_place = str(df[df['type'] == 'place']['mixtral_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama3_70_ok_p_place = str(df[df['type'] == 'place']['llama3_70_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama2_70_ok_p_place = str(df[df['type'] == 'place']['llama2_70_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama3_8_ok_p_place = str(df[df['type'] == 'place']['llama3_8_parsed'].notna().sum() / len(event_df) * 100) + ' %'
gpt3_ok_p_place = str(df[df['type'] == 'place']['gpt3_parsed'].notna().sum() / len(event_df) * 100) + ' %'
gpt4_ok_p_place = str(df[df['type'] == 'place']['gpt4_parsed'].notna().sum() / len(event_df) * 100) + ' %'

mixtral_ok_p_static = str(df[df['type'] == 'static']['mixtral_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama3_70_ok_p_static = str(df[df['type'] == 'static']['llama3_70_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama2_70_ok_p_static = str(df[df['type'] == 'static']['llama2_70_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama3_8_ok_p_static = str(df[df['type'] == 'static']['llama3_8_parsed'].notna().sum() / len(event_df) * 100) + ' %'
gpt3_ok_p_static = str(df[df['type'] == 'static']['gpt3_parsed'].notna().sum() / len(event_df) * 100) + ' %'
gpt4_ok_p_static = str(df[df['type'] == 'static']['gpt4_parsed'].notna().sum() / len(event_df) * 100) + ' %'

mixtral_ok_p_administration = str(
    df[df['type'] == 'administration']['mixtral_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama3_70_ok_p_administration = str(
    df[df['type'] == 'administration']['llama3_70_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama2_70_ok_p_administration = str(
    df[df['type'] == 'administration']['llama2_70_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama3_8_ok_p_administration = str(
    df[df['type'] == 'administration']['llama3_8_parsed'].notna().sum() / len(event_df) * 100) + ' %'
gpt3_ok_p_administration = str(
    df[df['type'] == 'administration']['gpt3_parsed'].notna().sum() / len(event_df) * 100) + ' %'
gpt4_ok_p_administration = str(
    df[df['type'] == 'administration']['gpt4_parsed'].notna().sum() / len(event_df) * 100) + ' %'

mixtral_ok_p_event = str(df[df['type'] == 'event']['mixtral_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama3_70_ok_p_event = str(df[df['type'] == 'event']['llama3_70_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama2_70_ok_p_event = str(df[df['type'] == 'event']['llama2_70_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama3_8_ok_p_event = str(df[df['type'] == 'event']['llama3_8_parsed'].notna().sum() / len(event_df) * 100) + ' %'
gpt3_ok_p_event = str(df[df['type'] == 'event']['gpt3_parsed'].notna().sum() / len(event_df) * 100) + ' %'
gpt4_ok_p_event = str(df[df['type'] == 'event']['gpt4_parsed'].notna().sum() / len(event_df) * 100) + ' %'

# %%
mixtral_time = '23m 52s'
llama3_70_time = '102m 43s'
llama2_70_time = '145m 54s'
llama3_8_time = '59m 18s'
gpt3_time = '5m 58s'
gpt4_time = '12m 08s'

# %%
# eval parsing
eval_df = pd.DataFrame({
    'Model': ['mixtral', 'llama3_70b', 'llama2_70b', 'llama3_8b', 'gpt-3.5', 'gpt-4'],
    'Správný formát': [mixtral_ok_p, llama3_70_ok_p, llama2_70_ok_p, llama3_8_ok_p, gpt3_ok_p, gpt4_ok_p],
    'place': [mixtral_ok_p_place, llama3_70_ok_p_place, llama2_70_ok_p_place, llama3_8_ok_p_place, gpt3_ok_p_place,
              gpt4_ok_p_place],
    'static': [mixtral_ok_p_static, llama3_70_ok_p_static, llama2_70_ok_p_static, llama3_8_ok_p_static,
               gpt3_ok_p_static, gpt4_ok_p_static],
    'administration': [mixtral_ok_p_administration, llama3_70_ok_p_administration, llama2_70_ok_p_administration,
                       llama3_8_ok_p_administration, gpt3_ok_p_administration, gpt4_ok_p_administration],
    'event': [mixtral_ok_p_event, llama3_70_ok_p_event, llama2_70_ok_p_event, llama3_8_ok_p_event, gpt3_ok_p_event,
              gpt4_ok_p_event],
    'Čas': [mixtral_time, llama3_70_time, llama2_70_time, llama3_8_time, gpt3_time, gpt4_time]
})

eval_df.to_csv('eval_divided_function_call_par.csv')

# %%
display(eval_df)
# Out:
#         Model Správný formát    place   static administration    event  \
# 0     mixtral           98 %  100.0 %   96.0 %         96.0 %  100.0 %
# 1  llama3_70b          100 %  100.0 %  100.0 %        100.0 %  100.0 %
# 2  llama2_70b            0 %    0.0 %    0.0 %          0.0 %    0.0 %
# 3   llama3_8b           85 %  100.0 %  100.0 %        100.0 %   40.0 %
# 4     gpt-3.5          100 %  100.0 %  100.0 %        100.0 %  100.0 %
# 5       gpt-4          100 %  100.0 %  100.0 %        100.0 %  100.0 %
#
#         Čas
# 0   23m 52s
# 1  102m 43s
# 2  145m 54s
# 3   59m 18s
# 4    5m 58s
# 5   12m 08s
