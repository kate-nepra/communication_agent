# %%
from src.agents.message import SystemMessage, UserMessage
from src.vector_store.vector_storage import VectorStorage
from dotenv import load_dotenv
from src.app.frontend_utils import choose_action
from src.agents_constants import MIXTRAL_AGENT, LLAMA3_8_AGENT, LLAMA3_70_AGENT, LLAMA3_70_API_AGENT, GPT_3_AGENT

load_dotenv()
vec_db = VectorStorage()
con = SystemMessage("You are AI Brno communication agent for information about Brno city.").as_dict()

query = "What is Element Restaurant known for?"
msgs = [con, UserMessage(query).as_dict()]
# Out:
# /usr/lib/python3.10/enum.py:289: DeprecationWarning: FUNCTIONS is deprecated and will be removed in future versions
#   enum_member = __new__(enum_class, *args)
# /home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic_core/core_schema.py:4044: DeprecationWarning: `FieldValidationInfo` is deprecated, use `ValidationInfo` instead.
#   warnings.warn(msg, DeprecationWarning, stacklevel=1)
# [2024-05-30 23:14:53,153 _client.py->_send_single_request():1026]INFO: HTTP Request: GET http://localhost:8080/v1/.well-known/openid-configuration "HTTP/1.1 404 Not Found"
# [2024-05-30 23:14:53,201 _client.py->_send_single_request():1026]INFO: HTTP Request: GET http://localhost:8080/v1/meta "HTTP/1.1 200 OK"
# [2024-05-30 23:14:53,332 _client.py->_send_single_request():1026]INFO: HTTP Request: GET https://pypi.org/pypi/weaviate-client/json "HTTP/1.1 200 OK"

# %%
d = choose_action(LLAMA3_70_AGENT, query, msgs, vec_db)
print(d)
# Out:
# [2024-05-30 23:14:53,390 local_api_agent.py->get_json_format_response():33]INFO: Messages: [{'role': 'system', 'content': 'You are a helpful assistant with access to the following functions, your task is to choose one of the functions according to the descriptions: ```[{\'function_name\': \'needs_base_brno_infos\', \'description\': \'Call this function when the user asks questions about anything that can not be a cultural event, like places (sights, restaurants or galleries etc.), administration or just Brno city in general, famous personalities that might be connected to the city ...,  e.g. "What is the address of the city hall?" or "What are the opening hours of the zoo?", "Where to get coffee?" or "How to get a tram ticket?\'}, {\'function_name\': \'needs_event_infos\', \'description\': \'Call this function when the user wants to get information about cultural events like festivals, exhibitions, theatrical plays, e.g. "What to do this week?" or "Is something happening tomorrow in 
# ...

# %%
d = choose_action(LLAMA3_8_AGENT, query, msgs, vec_db)
print(d)

# %%
d = choose_action(MIXTRAL_AGENT, query, msgs, vec_db)
print(d)

# %%
d = choose_action(LLAMA3_70_API_AGENT, query, msgs, vec_db)
print(d)

# %%
d = choose_action(GPT_3_AGENT, query, msgs, vec_db)
print(d)
# Out:
# [2024-05-30 23:55:11,810 api_agent.py->get_base_call_response():51]INFO: Messages: [{'role': 'system', 'content': "Your task is to choose a function based on user's message. End with the function call response in valid JSON format, escape JSON reserved characters properly. Do NOT add any additional text."}, {'role': 'user', 'content': 'What is Element Restaurant known for?'}]
# [2024-05-30 23:55:12,627 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...
