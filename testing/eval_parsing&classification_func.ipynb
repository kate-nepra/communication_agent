# %%
from dotenv import load_dotenv
import os
from src.agents.api_agent import LocalApiAgent, OpenAIApiAgent

load_dotenv()
mixtral = LocalApiAgent("http://localhost:8881/v1/", "ollama", "mixtral")
llama3_70 = LocalApiAgent("http://localhost:8881/v1/", "ollama", "llama3:70b")
llama2_70 = LocalApiAgent("http://localhost:8881/v1/", "ollama", "llama2:70b")
llama3_8 = LocalApiAgent("http://localhost:8881/v1/", "ollama", "llama3:8b")
gpt3 = OpenAIApiAgent("https://api.openai.com/v1", os.getenv("OPENAI_API_KEY"), "gpt-3.5-turbo-0125")
gpt4 = OpenAIApiAgent("https://api.openai.com/v1", os.getenv("OPENAI_API_KEY"), "gpt-4-turbo")

# %%
import pandas as pd

df_path = '/home/rinaen/PycharmProjects/communication_agent/testing/eval_chunks.csv'
df = pd.read_csv(df_path)

# %%
from src.data_acquisition.content_processing.content_parsing import get_parsed_content_by_function_call
from src.agents.api_agent import ApiAgent


def get_classified(model: ApiAgent, data_df):
    classified_types = []
    parsed_chunks = []
    for index, row in data_df.iterrows():
        url = row['url']
        chunk = row['chunk']
        try:
            typ, parsed = get_parsed_content_by_function_call(model, url, chunk)
            classified_types.append(typ)
            parsed_chunks.append(parsed)
        except Exception:
            classified_types.append(None)
            parsed_chunks.append(None)
    return classified_types, parsed_chunks
# Out:
# 2024-04-28 16:01:33.553866: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-28 16:01:34.321780: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
mixtral_t, mixtral_p = get_classified(mixtral, df)
# Out:
# [2024-04-28 16:01:54,727 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 16:02:03,588 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Element Restaurant' text='An excellent fusion of top-quality meals and original drinks, ideal for a dinner with your partner or friends.\nElement combines first-rate food and cocktails.\nBehind its globally inspired menu from local ingredients stands the well-travelled head chef Tomaš Reger, who has gained culinary experience from around the world.\nHis food is complemented by drinks from champion bartender Jan Liška.' brief='Element Restaurant offers high-quality meals and unique cocktails for a perfect dinner. The menu features global cuisine prepared by well-traveled chef Tomaš Reger, who uses local ingredients, accompanied by beverages from award-winning bartender Jan Liška.' address='Běhounská 7'
# [2024-04-28 16:02:05,329 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 16:02:13,931 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Hostinec U Semináru - A Traditional Czech Restaurant' text='"In the mood for a Czech classic with a bit of nostalgia? Search no more!\nCome taste the magic of the olden days! Smetanova 30 U Semináru is a stylish restaurant with a unique atmosphere, Pilsner beer, and traditional cuisine inspired by the times of the Austro-Hungarian Empire.\nSmetanova 30\nwww.useminaru.cz"' brief='Hostinec U Semináru is a traditional Czech restaurant with a nostalgic atmosphere, offering Pilsner beer and cuisine inspired by the Austro-Hungarian Empire.' address='Smetanova 30'
# [2024-04-28 16:02:15,900 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 16:02:25,471 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Coq au Vin Restaurant - Kohout Na Víně' text='This restaurant specializes in coq au vin (the Czech translation is the name of the restaurant), with the exact preparation changing and reflecting the chefs’ current ideas and skills. It offers more than 200 wines from around the world, with a primary focus on Moravia and Bohemia. For private celebrations and business events, the restaurant offers two tasting menus with annotated wine pairings.\nMalinovského náměstí 2,\nikohout-na-vine.cz' brief='Kohout Na Víně is a restaurant specializing in coq au vin, offering over 200 wines and two tasting menus for private celebrations and business events.' address='Malinovského náměstí 2, Brno, Czech Republic'
# [2024-04-28 16:02:27,380 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 16:02:36,356 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 16:02:36,358 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for add_place
# address
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for add_place
# address
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 16:02:36,368 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for add_place
# address
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 16:02:36,369 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 1 validation error for add_place
# address
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 16:02:43,320 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='MANYA Sushi & Sake Izakaya - A Unique Japanese Dining Experience' text='Not a bistro or just another sushi bar. This is MANYA – Izakaya! opened the gate to Tokyo at night at Průchodní 2 and pass under Godzilla to share big and small bowls overflowing with Japanese food or delicate sushi, while absorbing the informal atmosphere as well as Japanese sake.\nPrůchodní 2\nmanyabrno.cz' brief='MANYA Sushi & Sake Izakaya offers a unique and authentic Japanese dining experience, with a variety of dishes to share in an informal atmosphere.' address='Průchodní 2, Brno, Czech Republic'
# [2024-04-28 16:02:45,266 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 16:02:55,198 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 16:02:55,200 patch.py->retry_sync():318]ERROR: Retrying, exception: 4 validation errors for add_place
# header
#   Input should be a valid string [type=string_type, input_value={'title': "Mikrofarma - A...dise", 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Excerpt from M...ite:', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Mikrofarma is ...uns.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Address', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 4 validation errors for add_place
# header
#   Input should be a valid string [type=string_type, input_value={'title': "Mikrofarma - A...dise", 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Excerpt from M...ite:', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Mikrofarma is ...uns.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Address', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 16:02:55,202 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 4 validation errors for add_place
# header
#   Input should be a valid string [type=string_type, input_value={'title': "Mikrofarma - A...dise", 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Excerpt from M...ite:', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Mikrofarma is ...uns.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Address', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 16:02:55,203 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 4 validation errors for add_place
# header
#   Input should be a valid string [type=string_type, input_value={'title': "Mikrofarma - A...dise", 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Excerpt from M...ite:', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Mikrofarma is ...uns.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Address', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 16:03:04,024 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Mikrofarma - A Street Food Experience with Excellent Slowly Dry-Aged Meat' text='Perfectly crafted street food with excellent, slowly dry-aged meat by Moravian farmers. And the only bistro where you can get a cut-up steak in a cone to go. Pastrami in a sandwich, home-made sauce and brioche burger buns, with no chemicals needed! Add lemonades, good wine, fizzy drinks, and regional draught beer.\n' brief='Mikrofarma is a street food bistro offering perfectly crafted dishes made from excellent dry-aged meat by Moravian farmers. They serve pastrami sandwiches, homemade sauce, and brioche burger buns with no chemicals. The menu also includes lemonades, good wine, fizzy drinks, and regional draught beer.' address='Běhounská 18'
# [2024-04-28 16:03:06,155 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 16:03:11,396 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 16:03:11,399 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for add_place
#   Invalid JSON: EOF while parsing an object at line 5 column 29 [type=json_invalid, input_value='{\n"header": "Ramen Brno...t\t\t\t\t\t\t\t\t\t\t\t', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for add_place
#   Invalid JSON: EOF while parsing an object at line 5 column 29 [type=json_invalid, input_value='{\n"header": "Ramen Brno...t\t\t\t\t\t\t\t\t\t\t\t', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# [2024-04-28 16:03:11,400 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for add_place
#   Invalid JSON: EOF while parsing an object at line 5 column 29 [type=json_invalid, input_value='{\n"header": "Ramen Brno...t\t\t\t\t\t\t\t\t\t\t\t', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# [2024-04-28 16:03:11,401 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 1 validation error for add_place
#   Invalid JSON: EOF while parsing an object at line 5 column 29 [type=json_invalid, input_value='{\n"header": "Ramen Brno...t\t\t\t\t\t\t\t\t\t\t\t', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid. Retrying
# [2024-04-28 16:03:19,466 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Ramen Brno - A taste of Japan in Brno' text='Ramen Brno is a restaurant that brings the authentic Japanese ramen experience to Brno, Czech Republic. They offer bowls full of homemade noodles covered in strong broths with variously flavored oils and topped with marinated eggs, slow-cooked meat, and many other ingredients. The preparation process is done right before your eyes in an open kitchen, making it a type of fast food. They have two locations, one at Václavská 16 and another at Křenová 62a.' brief='Ramen Brno is a restaurant serving authentic Japanese ramen in Brno, Czech Republic with two locations. The noodles are freshly prepared in an open kitchen with various toppings.' address='Václavská 16, Brno, Czech Republic'
# [2024-04-28 16:03:21,265 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 16:03:25,919 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 16:03:25,920 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for add_place
#   Invalid JSON: EOF while parsing an object at line 4 column 30 [type=json_invalid, input_value='{\n"header": "Singha Tha...t\t\t\t\t\t\t\t\t\t\t\t', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for add_place
#   Invalid JSON: EOF while parsing an object at line 4 column 30 [type=json_invalid, input_value='{\n"header": "Singha Tha...t\t\t\t\t\t\t\t\t\t\t\t', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# [2024-04-28 16:03:25,921 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for add_place
#   Invalid JSON: EOF while parsing an object at line 4 column 30 [type=json_invalid, input_value='{\n"header": "Singha Tha...t\t\t\t\t\t\t\t\t\t\t\t', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# [2024-04-28 16:03:25,922 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 1 validation error for add_place
#   Invalid JSON: EOF while parsing an object at line 4 column 30 [type=json_invalid, input_value='{\n"header": "Singha Tha...t\t\t\t\t\t\t\t\t\t\t\t', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid. Retrying
# [2024-04-28 16:03:32,495 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Singha Thai Restaurant - A Fresh and Welcoming Dining Experience in Brno' text='"Serving fresh meals with a smile while absolutely spoiling you." This Thai restaurant in the center of Brno focuses on fresh, high-quality ingredients that you can watch get turned into works of art by their experienced chefs. They cater to vegetarians, vegans, and those who are gluten-sensitive.\nOrlí 6\nsinghathairestaurant.cz' brief='Singha Thai Restaurant in Brno offers fresh, high-quality Thai cuisine with a smile, catering to various dietary preferences.' address='Brno, Czech Republic'
# [2024-04-28 16:03:34,385 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 16:03:42,425 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Soul Bistro - A cosy place for all occasions' text='A bistro with a soul. A light, clean interior and simple, high-quality food reflecting the season. People come to Soul for breakfast, work lunches, celebratory dinners with friends, and family parties. You’ll find here dishes ranging from fluffy cakes to light salads, excellent fish & chips, and shredded-beef sandwiches.' brief='Soul Bistro is a versatile venue offering a variety of delicious dishes for breakfast, lunch, and dinner. Its clean and comfortable interior makes it suitable for both casual visits and special occasions.' address='Jezuitská 7'
# [2024-04-28 16:03:44,351 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 16:03:53,356 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Večerka Brno - A café bistro offering a fusion of Czech and Vietnamese cuisines' text='Its name means convenience store in Czech, but you won’t find all kinds of stuff there. In this café bistro on Pekařská Street, the crew bravely combines Czech and Vietnamese cuisines and prepares premium coffee as well as their own kombucha KMBCH coffee.\nFB: vecerkabrno' brief='Večerka Brno is a café bistro on Pekařská Street, serving a fusion of Czech and Vietnamese cuisines with premium coffee and self-brewed kombucha KMBCH coffee.' address='Pekařská 9, Brno, Czech Republic'
# [2024-04-28 16:03:55,356 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 16:04:04,935 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Cukrárna BezCukru - The First Low-Carb Confectionary in Brno' text='"Delicious desserts for everyone." Everything here feels like a regular cafe. From the rich aroma of Coffee Square coffee to the showcased delicacies. Only this is the first low-carb confectionary in Brno, using zero sugar or flour, so even celiac dieters can enjoy it. The small cream puff with a big heart sells best, and the select ingredients used are just the icing on the proverbial cake.\n' brief="Cukrárna BezCukru is Brno's first low-carb confectionary offering delicious desserts made with zero sugar or flour. The small cream puff is their best-seller." address='Novobranská 4, Brno, Czech Republic'
# [2024-04-28 16:04:06,892 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 16:04:17,878 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 16:04:17,879 patch.py->retry_sync():318]ERROR: Retrying, exception: 4 validation errors for add_place
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Cukrářství ...nák', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Discover the s...ell!', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Cukrářství ...nts.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Veveří 14', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 4 validation errors for add_place
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Cukrářství ...nák', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Discover the s...ell!', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Cukrářství ...nts.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Veveří 14', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 16:04:17,880 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 4 validation errors for add_place
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Cukrářství ...nák', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Discover the s...ell!', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Cukrářství ...nts.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': '
_client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Zemanova Cukrarna and Coffeehouse - A Trip Back to the Interwar Period' text="Located in a functionalist building, protected as a national heritage site, it opened its doors in 1937, making this café and confectionary the longest-serving in Brno. Offering traditional Czech desserts, baked goods, premium coffee, and over 30 types of local liquors and spirits, it boasts several specialties, such as 'Veletržní dort' and baked dragons. And its interwar vibe makes it an ideal place for the cultural events that take place here from time to time.\nAddress: Josefská 4\nWebsite: [www.zemanovacukrarna.cz](http://www.zemanovacukrarna.cz)" brief="Zemanova Cukrarna and Coffeehouse, established in 1937, is a traditional Czech confectionary located in a functionalist building in Brno's center. It offers various desserts, coffee, and local liquors, and occasionally hosts cultural events." address='Josefská 4, Brno, Czech Republic'
# [2024-04-28 16:05:32,179 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 16:05:43,444 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header="Buchta C - A Hidden Gem in Brno's Vegetable Market" text='An ideal stop for a quick cup of coffee and something sweet on the Vegetable Market. A younger sister of Buchta B café, this is Zelný trh 10 and it is a small espresso bar hidden in the courtyard at the Vegetable Market. Enjoy its outdoor seating in one of the biggest vertical gardens in the whole country, open year-round. Sweet delicacies are brought here every day from Buchta B to complement their premium coffee from various Czech and European roasting places, or a glass of natural wine made for you by Moravian winemakers.\nZelný trh 10\nFB: Buchta C' brief="Buchta C is a small espresso bar located in the courtyard of Brno's Vegetable Market, offering premium coffee, sweet delicacies from Buchta B, and natural wine. It features outdoor seating in a large vertical garden." address='Zelný trh 10, Brno, Czech Republic'
# [2024-04-28 16:05:45,594 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 16:05:54,955 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header="Cafe Momenta - A Cozy Corner in Brno's Heart" text='This charming cafe, located in the very heart of Brno on Zelný trh 2, offers a pleasant and comfortable experience filled with the rich aroma of freshly made coffee. The cafe features a wide range of delicious desserts and savory snacks, making it an ideal place for enjoying some quiet time or catching up with friends in a cozy corner. At Cafe Momenta, every moment matters, providing a perfect spot for conversation while time slows down.' brief="Cafe Momenta is a charming establishment located in Brno's center, serving a variety of coffee and food options. The cafe offers a comfortable setting for enjoying quality time with friends or a peaceful break." address='Zelný trh 2, Brno, Czech Republic'
# [2024-04-28 16:05:56,953 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 16:06:08,635 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 16:06:08,636 patch.py->retry_sync():318]ERROR: Retrying, exception: 4 validation errors for add_place
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Cafe Placzek', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Brunch, a cup ...rno.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'A versatile ca...hns.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Minoritská 4', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 4 validation errors for add_place
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Cafe Placzek', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Brunch, a cup ...rno.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'A versatile ca...hns.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Minoritská 4', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 16:06:08,637 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 4 validation errors for add_place
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Cafe Placzek', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Brunch, a cup ...rno.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'A versatile ca...hns.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Minoritská 4', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 16:06:08,638 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 4 validation errors for add_place
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Cafe Placzek', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Brunch, a cup ...rno.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'A versatile ca...hns.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'title': 'Minoritská 4', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 16:06:17,850 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# ...
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for add_event
# address
#   Field required [type=missing, input_value={'header': 'Mirandolina b...", 'date': '03/05/2024'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# dates
#   Field required [type=missing, input_value={'header': 'Mirandolina b...", 'date': '03/05/2024'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 16:38:45,728 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 2 validation errors for add_event
# address
#   Field required [type=missing, input_value={'header': 'Mirandolina b...", 'date': '03/05/2024'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# dates
#   Field required [type=missing, input_value={'header': 'Mirandolina b...", 'date': '03/05/2024'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 16:38:45,729 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 2 validation errors for add_event
# address
#   Field required [type=missing, input_value={'header': 'Mirandolina b...", 'date': '03/05/2024'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# dates
#   Field required [type=missing, input_value
_client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Three Sisters by Anton Pavlovich Chekhov in Mahen Theatre' text='Being happy is possible! But maybe at some other place or at some other time … After the decease of their father, who provided the whole family with financial support and maintained its thriving social life, the three sisters – Irina, Masha and Olga – are left all by themselves in their small town and their future is far from being bright. The family house, which used to be attended by renowned guests, now attracts merely eccentrics and outsiders. Soon, their brother dissipates the bequest and the necessity of earning their living makes them loose what aristocrats took for granted: free time. Their desire to live a happy and fuller life, their longing for love and for a new home leads the sisters into extreme situations. Bitter laughter, laughable tears – what seems to be ordinary fortunes of common people unlocks great stories of love and adversity. Three Sisters , one of the two plays that Anton Pavlovich Chekhov (1860–1904) wrote specifically for the Moscow Art Theater, is considered to be the Russian playwright’s masterpiece. The four-act drama had a significant impact on European theater, including the Czech one: performed by the Moscow ensemble in Prague in 1906 it revolutionized the local approach to modern acting and directing. In Brno, Three Sisters will be staged by Štěpán Pácl, in-house director of the Dramatic Company of the National Theater Brno, whose successful production of Chekhov’s play The Seagull was adapted into film.' brief="The play 'Three Sisters' by Anton Pavlovich Chekhov is going to be performed at Mahen Theatre in Brno, exploring themes of love, longing for a new home and the desire to live a happy life. The performance is directed by Štěpán Pácl." address='Mahen Theatre, Brno, Czech Republic' dates='[{"start": "2024-05-05T17:00"}, {"start": "2024-05-05T19:45"}]'
# [2024-04-28 16:40:01,909 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 16:40:01,912 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'Call thi...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'Call thi...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 16:40:01,913 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'Call thi...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 16:40:01,914 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'Call thi...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 16:40:01,914 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 16:40:03,359 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_event'
# [2024-04-28 16:40:14,607 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Opening of the exhibition Thousand Faces of Amazonia' text='Anthropos Pavilion, Pisárecká 5, Brno\nThe exhibition presents the cultural and natural diversity of the Greater Amazon region and provides insight into the lives of the indigenous inhabitants of this cultural area. What is innovative and remarkable is that it is primarily their own self-representation, meaning that members of local ethnic groups have contributed significantly to the preparation of the exhibition. Visitors will thus learn about their rich culture, understanding of nature, mythology, religion, cosmology and interpretation of the world, customs and rituals.' brief='The Opening of the exhibition Thousand Faces of Amazonia in Anthropos Pavilion, Brno, showcases the cultural and natural diversity of the Greater Amazon region and provides insight into the lives of the indigenous inhabitants through their self-representation.' address='Pisárecká 5, Brno' dates='[{"start": "2024-05-16T17:00"}]'
# [2024-04-28 16:40:21,002 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 16:40:21,005 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'Call thi...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'Call thi...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 16:40:21,007 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'Call thi...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 16:40:21,007 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'Call thi...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 16:40:21,008 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 16:40:22,595 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_event'
# [2024-04-28 16:40:37,852 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Exhibition interventions: Marie Filippovová' text='Admission fee voluntary\nExhibition interventions: Marie Filippovová\nFROM 19/4/2024\nPražák Palace\nPetr Ingerle\nArt - Exhibitions\nMarie Filippovová represents one of the most prominent figures on the Brno art scene. At first glance, her work impresses with its concentration, sense of rhythm, cyclicality and temporality. To a certain extent, it is also characterised by a certain austerity, or even asceticism. The orderliness with which he completes cycles, sets and volumes of drawings, watercolours and prints, as well as his reliance on lapidary means of expression, is probably related to his deep experience with writing, typography and calligraphy. The generational experience of the artist, who studied free and applied graphics, design and book culture at the Academy of Arts and Crafts in Prague at the turn of the 1950s and 1960s, and then settled permanently in Brno, where she began her independent creative career, is also undeniable.' brief="The exhibition 'Exhibition interventions: Marie Filippovová' by one of the most prominent figures on the Brno art scene starts at Pražák Palace on 19th April 2024. The admission is voluntary." address='Pražák Palace, Brno, Czech Republic' dates='[{"start": "2024-04-19"}]'

# %%
llama3_70_t, llama3_70_p = get_classified(llama3_70, df)
# Out:
# [2024-04-28 16:41:00,116 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 16:41:34,377 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='
of Brno was established by the Catholic Church; Mathias Franz Graf von Chorinsky Freiherr von Ledske was the first Bishop.\r\nIn December 1805 the Battle of Austerlitz was fought near the city; the battle is also known as the "Battle of the Three Emperors". Brno itself was not involved with the battle, but the French Emperor Napoleon Bonaparte spent several nights here at that time, and again in 1809.\r\nIn 1839 the first train arrived in Brno from Vienna; this was the beginning of rail transport in what is now the Czech Republic.\r\nIn the years 1859–1864 the city fortifications were almost completely removed. In 1869 a horsecar service started to operate in Brno, the first tram service in what would later become the Czech Republic.\r\nGregor Mendel conducted his groundbreaking experiments in genetics while he was a monk at St. Thomas\'s Abbey in Brno in the 1850s.' brief="Brno is a city in the Czech Republic that served as the capital of the Margraviate of Moravia during the Thirty Years' War. It has a rich history, including being besieged by the Prussian Army and having a bishopric established by the Catholic Church. The city is also home to Špilberk Castle and St. Thomas's Abbey." address='Brno, Czech Republic'
# [2024-04-28 17:06:13,066 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_event'
# [2024-04-28 17:08:01,334 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Brno' text='Under the Köppen climate classification, Brno has an oceanic climate (Cfb) for −3 °C original isoterm, but near of the (−2.5 °C average temperature in January, month most cold) or include by updated classification in humid continental climate (Dfb) with cold winters and warm to hot summers. However, in the last 20 years the temperature has increased, and summer days with temperature above 30 °C (86 °F) are quite common. The average temperature is 9.4 °C (49 °F), the average annual precipitation is about 505 mm (19.88 in), the average number of precipitation days is 150, the average annual sunshine is 1,771 hours, and the prevailing wind direction is northwest. The weather box below shows average data between years 1961 and 1990. Its height above sea level varies from 190 m (623 ft) to 497 m (1,631 ft). The highest peak in the municipal area is the Kopeček Hill (479 m (1,572 ft)), and the highest point overall lies in Útěchov on the border with the municipality of Vranov. Festivals held in Brno include the fireworks competition festival Ignis Brunensis, the international film festival Cinema Mundi, Theatre World Brno, the International Music Festival Brno, the Spilberk International Music Festival, and the Summer Shakespeare Festival. Every September, Brno hosts a wine festival, Slavnosti vína, to celebrate the harvest in the surrounding wine-producing region.' brief='Brno is a city with an oceanic climate and humid continental features. It has cold winters and warm summers, with an average temperature of 9.4 °C. The city hosts various festivals throughout the year, including fireworks, film, theatre, music, and wine festivals.' address='Brno, Czech Republic' dates='[{"start": ""]'
# [2024-04-28 17:08:18,181 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 17:11:03,353 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='City of Brno' text='There are several legends connected with the City of Brno. One of the best known is the Legend of the Brno Dragon. According to this legend, a terrible creature was terrorizing the citizens of Brno. The people had never seen this animal before, so they called it a dragon. They lived in fear of the dragon until one citizen managed to kill the monster by tricking it into eating a carcass filled with lime. In reality the dragon was a crocodile, the preserved body of which is now displayed at the entrance of the Old Town Hall. Crocodile and dragon motifs are common in Brno. A crocodile (Czech: krokodýl) is the local stuffed baguette, and the city radio station is known as Radio Krokodýl. The local baseball team is named Draci Brno (English: Brno Dragons) and the local rugby club is named RC Dragon Brno. There is also a local American football team called the Brno Alligators. An Intercity train connecting Brno and Prague is called Brněnský drak (English: The Brno dragon). Next to the "dragon" at the Old Town Hall is the town\'s second well-known emblem, a wagon wheel made from a tree found and cut down 50 miles from the city. According to the legend, a local man made a wager that he could fell the tree, make a wheel out of it, and roll the wheel
_client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Brno City Administration' text="Legally, Brno is a statutory city, consisting of 29 administrative divisions known as city districts. The highest body of self-government is the Brno City Assembly. The city is headed by the lord mayor, who has the right to use the mayor's insignia and represents the city externally. As of 2021, the lord mayor is Markéta Vaňková of the Civic Democratic Party (ODS). The executive body is the city council and local councils of the city districts; the city council has 11 members including the lord mayor and her four deputies. The assembly of the city elects the lord mayor and other members of the city council, establishes the local police, and is also entitled to grant citizenship of honour and the Awards of the City of Brno. The head of the Assembly of the City of Brno in personal matters is the Chief Executive, who according to certain special regulations carries out the function of employer of the other members of the city management. The Chief Executive is directly responsible to the Lord Mayor." brief='Brno is a statutory city with 29 administrative divisions, headed by the lord mayor and having a city assembly that elects the mayor and council members.' address='Brno, Czech Republic'
# [2024-04-28 17:25:11,538 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_static'
# [2024-04-28 17:27:00,351 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Brno City Profile' text='According to the 2021 census, Brno had 398,510 inhabitants. The largest ethnic groups reported (without options to choose between) were Czechs (51.6%), Moravians (18.7%), Slovaks (1.5%), Ukrainians (0.9%), Vietnamese (0.4%), and Poles (0.2%). 23.7% of inhabitants did not write any nationality. In the 2001 census, when the most common nationalities were list to choose between, 76.1% were Czechs and 18.7% Moravians (94.8% Czechs in the broader sense). Brno experienced its largest increases in population during the 19th century at the time of the Industrial Revolution, and in 1919 due to a merger with surrounding municipalities. The city spends about 30 million euro every year on culture. A vibrant university city with about 60,000 students, Brno is home to many museums, theatres and other cultural institutions, and also hosts a number of festivals and other cultural events. Since the 1990s Brno has experienced a great cultural "rebirth": façades of historical monuments are being repaired and various exhibitions, shows, etc., are being established or extended. In 2007 a summit of 15 presidents of EU Member States was held in Brno. Despite its urban character, some of the city districts still preserve traditional Moravian folklore, including folk festivals with traditional Moravian costumes, Moravian wines, folk music and dances. Unlike smaller municipalities, in Brno annual traditional Moravian folk festivals are held in several city districts, including Židenice, Líšeň, and Ivanovice. Hantec is a unique slang that originated in Brno.' brief='Brno is a city with a population of 398,510 inhabitants, known for its cultural heritage, vibrant university atmosphere, and traditional Moravian folklore. The city has experienced significant growth and cultural rebirth since the 1990s.'
# [2024-04-28 17:27:13,890 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 17:29:29,691 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# [2024-04-28 19:04:36,585 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_event'
# [2024-04-28 19:05:43,062 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Black Holes 2D' text='We all know the term: black hole. But what kind of space objects are they? Black holes are extreme in all their properties. If we approach them at a certain, very small distance (the so-called event horizon), we cannot escape the clutches of their gravitational field except by moving faster than light. But nothing in the universe can move that fast.\ndigitarium - public\nsuitable for ages 12 and up\n55 minutes\nthe performance includes a tour of the artificial sky\nEnglish audio available\nThe show is simultaneously projected with English audio in headphones. It may, however, contain a live part presented in Czech language exclusively. Headphones are available on request at the ticket desk. The deposit for headphones is 100 CZK per piece (cash only).\n' brief='A 55-minute performance about black holes, suitable for ages 12 and up, with English audio available and a tour of the artificial sky.' address='Brno, Czech Republic' dates='[{"start": "2024-04-28T17:45"}]'
# [2024-04-28 19:05:57,268 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_event'
# [2024-04-28 19:07:36,312 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Robert Icke - Lady Doctor' text='Ruth Wolff is the chief physician at an institute for neurological patients. She admits a 14-year-old girl who hasn’t much time to live, trying to give her the most peaceful departure. The next morning, after a tumultuous night, an unexpected visitor shows up at the door of the young patient: the priest from the parish to which the girl’s parents belong. He has come to give her the last sacrament. By refusing an unknown and uninvited priest permission to enter the patient’s room, the physician creates a chaotic situation, resulting in what could be termed a witch hunt. But why didn’t anyone listen to the priest? And was the girl Catholic or not? Was the pri
_client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Museum of Decorative Arts' text='The building of the Museum of Decorative Arts of the Moravian Gallery has received a new concept in 2021: ART DESIGN FASHION. It foreshadows that the museum is dedicated not only to design itself, but also to fashion and the relationship between design and art. Visitors can look forward to a permanent exhibition, exhibitions and new facilities prepared exclusively for the Moravian Gallery by leading Czech designers. The changed appearance of the Museum of Decorative Arts in Brno represents an imaginary showcase of Czech designers and their products. This multi-layered concept is unparalleled in the Czech Republic in terms of scope and quality.\nWhen designing the interior, the gallery was primarily concerned with incorporating the idea of presenting contemporary designers through their designs for interior elements and spaces. The gallery involved Maxim Velčovský, Radek Wohlmuth and the edit! studio, Eva Eisler, David Karásek, the Olgoj Chorchoj studio and Marek Štěpán.\nCurrent interventions in the exhibition:\nKrištof Kintera - Demon of Growth' brief='The Museum of Decorative Arts in Brno has a new concept: ART DESIGN FASHION, showcasing Czech designers and their products. The museum features permanent exhibitions, exhibitions, and new facilities designed by leading Czech designers.' address='Brno, Czech Republic'
# [2024-04-28 19:17:58,499 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_event'
# [2024-04-28 19:19:15,710 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header="Marie Filippovová's Exhibition" text='Marie Filippovová represents one of the most prominent figures on the Brno art scene. At first glance, her work impresses with its concentration, sense of rhythm, cyclicality and temporality. To a certain extent, it is also characterised by a certain austerity, or even asceticism. The orderliness with which he completes cycles, sets and volumes of drawings, watercolours and prints, as well as his reliance on lapidary means of expression, is probably related to his deep experience with writing, typography and calligraphy. The generational experience of the artist, who studied free and applied graphics, design and book culture at the Academy of Arts and Crafts in Prague at the turn of the 1950s and 1960s, and then settled permanently in Brno, where she began her independent creative career, is also undeniable.' brief="Marie Filippovová's exhibition showcases her prominent work on the Brno art scene, characterised by concentration, rhythm, and austerity. Her experience with writing, typography, and calligraphy influences her art. The artist studied at the Academy of Arts and Crafts in Prague before settling in Brno to start her independent career." address='Pražák Palace' dates='[{"start": "2024-04-19"}]'

# %%
llama2_70_t, llama2_70_p = get_classified(llama2_70, df)
# Out:
# [2024-04-28 19:19:37,214 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:19:37,227 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:19:37,229 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:19:37,229 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:19:37,229 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:19:43,395 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:19:43,396 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:19:43,397 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:19:43,398 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:19:43,398 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:19:50,014 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:19:50,016 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:19:50,017 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:19:50,018 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:19:50,018 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:19:54,349 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:19:54,351 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:19:54,352 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:19:54,354 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:19:54,354 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:20:00,869 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:20:00,870 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:00,871 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:00,871 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:20:00,872 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:20:07,368 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:20:07,370 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:07,371 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:07,371 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:20:07,372 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:20:13,669 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:20:13,670 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:13,671 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:13,672 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:20:13,672 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:20:17,765 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:20:17,766 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:17,767 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:17,768 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:20:17,768 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:20:21,861 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:20:21,862 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:21,864 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:21,865 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:20:21,866 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:20:28,357 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:20:28,359 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:28,360 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:28,360 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:20:28,361 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:20:34,968 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:20:34,969 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:34,970 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:34,971 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:20:34,971 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:20:39,317 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:20:39,318 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:39,318 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:39,319 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:20:39,320 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:20:45,823 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:20:45,825 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:45,826 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:45,827 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:20:45,828 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:20:52,069 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:20:52,070 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:52,072 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:52,073 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:20:52,074 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:20:58,623 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:20:58,624 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:58,625 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:20:58,626 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:20:58,627 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:21:05,177 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:21:05,179 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:21:05,180 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:21:05,181 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:21:05,182 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:21:09,580 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:21:09,582 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:21:09,584 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:21:09,584 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:21:09,585 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:21:16,093 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:21:16,095 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:21:16,096 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:21:16,097 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:21:16,098 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:21:22,324 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:21:22,327 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:21:22,328 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
# ...
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_even...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_even...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:34:33,227 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_even...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:34:33,228 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_even...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:34:33,228 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:34:40,493 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:34:40,497 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:34:40,498 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:34:40,499 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_plac...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 19:34:40,500 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 19:34:47,064 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_event'
# [2024-04-28 19:35:06,399 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:35:06,403 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for add_event
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2024-04-19T00... '2024-04-19T23:59:59'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for add_event
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2024-04-19T00... '2024-04-19T23:59:59'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:35:06,404 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for add_event
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2024-04-19T00... '2024-04-19T23:59:59'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:35:06,404 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 1 validation error for add_event
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2024-04-19T00... '2024-04-19T23:59:59'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 19:35:07,731 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:35:07,734 patch.py->retry_sync():318]ERROR: Retrying, exception: 5 validation errors for add_event
# header
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# text
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# brief
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# address
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# dates
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 5 validation errors for add_event
# header
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# text
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# brief
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# address
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# dates
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 19:35:07,735 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 5 validation errors for add_event
# header
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# text
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# brief
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# address
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# dates
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 19:35:07,735 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 5 validation errors for add_event
# header
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# text
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# brief
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# address
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# dates
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing. Retrying
# [2024-04-28 19:35:32,071 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:35:32,073 patch.py->retry_sync():318]ERROR: Retrying, exception: 3 validation errors for add_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Exhibition Int...ns: Marie Filippovová'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'street': 'Pražák Pala...ntry': 'Czech Republic'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2024-04-19T15...4-04-19T17:00:00.000Z'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 3 validation errors for add_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Exhibition Int...ns: Marie Filippovová'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'street': 'Pražák Pala...ntry': 'Czech Republic'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2024-04-19T15...4-04-19T17:00:00.000Z'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:35:32,074 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 3 validation errors for add_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Exhibition Int...ns: Marie Filippovová'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'street': 'Pražák Pala...ntry': 'Czech Republic'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2024-04-19T15...4-04-19T17:00:00.000Z'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:35:32,075 api_agent.py->_handle_call_exception():148]ERROR: Error getting JSON format response: 3 validation errors for add_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Exhibition Int...ns: Marie Filippovová'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# address
#   Input should be a valid string [type=string_type, input_value={'street': 'Pražák Pala...ntry': 'Czech Republic'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# dates
#   Input should be a valid string [type=string_type, input_value=[{'start': '2024-04-19T15...4-04-19T17:00:00.000Z'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.

# %%
llama3_8_t, llama3_8_p = get_classified(llama3_8, df)
# Out:
# [2024-04-28 19:35:56,606 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 19:36:24,838 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Element' text='An excellent fusion of top-quality meals and original drinks, ideal for a dinner with your partner or friends. Element combines first-rate food and cocktails. Behind its globally inspired menu from local ingredients stands the well-travelled head chef Tomaš Reger, who has gained culinary experience from around the world. His food is complemented by drinks from champion bartender Jan Liška.' brief="Element offers top-quality meals and original drinks in a unique fusion. The head chef's globally inspired menu features local ingredients." address='Běhounská 7'
# [2024-04-28 19:36:48,288 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 19:37:11,967 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Hostinec U Semináru' text='Come taste the magic of the olden days! Smetanova 30 U Semináru is a stylish restaurant with a unique atmosphere, Pilsner beer, and traditional cuisine inspired by the times of the Austro-Hungarian Empire.' brief='A Czech classic restaurant with nostalgic atmosphere serving traditional cuisine inspired by the Austro-Hungarian Empire.' address='Smetanova 30'
# [2024-04-28 19:37:19,317 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 19:37:52,289 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Kohout NA VÍNĚ' text='This restaurant specializes in coq au vin (the Czech translation is the name of the restaurant), with the exact preparation changing and reflecting the chefs’ current ideas and skills. It offers more than 200 wines from around the world, with a primary focus on Moravia and Bohemia. For private celebrations and business events, the restaurant offers two tasting menus with annotated wine pairings.\r\n\r\n“Ideal for festive occasions to get pampered by its excellent staff.”' brief='Specializing in coq au vin, this restaurant offers over 200 wines from around the world and provides private event options.' address='Malinovského náměstí 2'
# [2024-04-28 19:38:10,209 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 19:38:39,803 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='MANYA Sushi & Sake Izakaya' text='Not a bistro or just another sushi bar. This is MANYA – Izakaya! opened the gate to Tokyo at night at Průchodní 2 and pass under Godzilla to share big and small bowls overflowing with Japanese food or delicate sushi, while absorbing the informal atmosphere as well as Japanese sake.' brief='Experience a taste of Tokyo in Brno with MANYA Izakaya. Enjoy Japanese food and sake in an informal setting. Discover new flavors and atmosphere.' address='Průchodní 2, manyabrno.cz'
# [2024-04-28 19:38:56,494 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 19:39:27,683 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Mikrofarma' text='Perfectly crafted street food with excellent, slowly dry-aged meat by Moravian farmers. And the only bistro where you can get a cut-up steak in a cone to go. Pastrami in a sandwich, home-made sauce and brioche burger buns, with no chemicals needed! Add lemonades, good wine, fizzy drinks, and regional draught beer.' brief='Mikrofarma offers high-quality street food, dry-aged meat from local farmers, and unique cut-up steak cones. Also features pastrami sandwiches, homemade sauces, and more.' address='Běhounská 18'
# [2024-04-28 19:39:45,528 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_static'
# [2024-04-28 19:40:23,945 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Ramen' text='“No need to head for Japan to get a balanced ramen made of premium ingredients. This is your place now!”\nRamen is a quick Japanese meal surprisingly combining popular Czech flavours. Bowls full of home-made noodles are covered in strong broths with variously flavoured oils and topped with marinated eggs, slow-cooked meat, and many other ingredients. Ramen is prepared freshly within a few minutes right before your eyes in an open kitchen, which is why the owners claim it’s a type of fast food. They also have a second location at Křenová 62a.\nVáclavská 16\nramen-brno.cz' brief='Ramen Brno offers a unique fusion of Japanese and Czech flavors in a bowl. Freshly made noodles with various toppings are prepared quickly and served right before your eyes.'
# [2024-04-28 19:40:39,720 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 19:41:04,906 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Singha Thai Restaurant' text='This Thai restaurant in the centre of Brno focuses on fresh, high-quality ingredients that you can watch get turned into works of art by their experienced chefs. Forget all about glutamate! This place also caters to vegetarians, vegans, and the gluten-sensitive.' brief='Singha Thai Restaurant serves fresh, high-quality Thai meals with a smile, catering to various dietary needs and offering a unique dining experience in Brno.' address='Orlí 6'
# [2024-04-28 19:41:29,072 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 19:41:59,540 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Soul Bistro' text='A cosy place to spend time with loved ones.\n\nA bistro with a soul. A light, clean interior and simple, high-quality food reflecting the season. People come to Soul for breakfast, work lunches, celebratory dinners with friends, and family parties.\nYou’ll find here dishes ranging from fluffy cakes to light salads, excellent fish & chips, and shredded-beef sandwiches.' brief='Cozy bistro serving simple, high-quality food and drinks in a light and clean atmosphere, perfect for breakfasts, lunches, celebrations and family gatherings.' address='Jezuitská 7'
# [2024-04-28 19:42:14,947 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 19:42:23,430 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:42:23,433 patch.py->retry_sync():318]ERROR: Retrying, exception: 2 validation errors for add_place
# brief
#   Field required [type=missing, input_value={'header': 'Večerka Brno', 'text': ''}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# address
#   Field required [type=missing, input_value={'header': 'Večerka Brno', 'text': ''}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for add_place
# brief
#   Field required [type=missing, input_value={'header': 'Večerka Brno', 'text': ''}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# address
#   Field required [type=missing, input_value={'header': 'Večerka Brno', 'text': ''}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 19:42:23,435 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 2 validation errors for add_place
# brief
#   Field required [type=missing, input_value={'header': 'Večerka Brno', 'text': ''}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# address
#   Field required [type=missing, input_value={'header': 'Večerka Brno', 'text': ''}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 19:42:23,436 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response:
_client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Punkt' text='A piece of Berlin at a pleasant, quiet place.\r\nHere you’ll find espresso and filtered coffees made from premium beans of Czech and foreign roasteries. Coffee specialities and wholesome home-made desserts, with gluten-free and vegan options. The cosy interior and cheerful staff ensure a pleasant experience in any weather.' brief='A cozy cafe serving coffee and desserts with gluten-free and vegan options in a peaceful atmosphere.' address='Bayerova 7'
# [2024-04-28 19:53:14,459 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 19:53:45,540 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='QB Coffee Roasters' text='An espresso bar and a roasting place producing premium coffee at the premises of a rowing club by the fizzing Svratka River. Grab a bag of their amazing beans to make your favourite drinks at home or enjoy a coffee and some of their sweet or savoury snacks right there. Relax in one of the two outdoor seating areas and take in the atmosphere of the place, nestled among old docks and an interwar building.' brief='Premium coffee roasters with outdoor seating and snack options at the premises of a rowing club by the Svratka River.' address='Veslařská 179'
# [2024-04-28 19:53:55,457 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_place'
# [2024-04-28 19:54:23,325 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Rebelbean Vlněna' text='A stylish café with premium coffee from its own roasting place, which is all about quality, sustainability, and fair treatment of farmers. Offering wine by Jan Stávek from Němčičky, a wide range of alcoholic, soft, and coffee-based drinks, as well as a lot of delicacies, sandwiches, and desserts. And a great soup at lunchtime.' brief='A paradise for those who prefer a café to their office or simply love perfectly prepared coffee.' address='Přízova 5'
# [2024-04-28 19:54:36,535 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_static'
# [2024-04-28 19:55:51,185 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:55:51,187 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for add_static
#   Invalid JSON: control character (\u0000-\u001F) found while parsing a string at line 3 column 0 [type=json_invalid, input_value='{ "header": {"title": "H...                   \n\n', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for add_static
#   Invalid JSON: control character (\u0000-\u001F) found while parsing a string at line 3 column 0 [type=json_invalid, input_value='{ "header": {"title": "H...                   \n\n', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# [2024-04-28 19:55:51,188 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for add_static
#   Invalid JSON: control character (\u0000-\u001F) found while parsing a string at line 3 column 0 [type=json_invalid, input_value='{ "header": {"title": "H...                   \n\n', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# [2024-04-28 19:55:51,188 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 1 validation error for add_static
#   Invalid JSON: control character (\u0000-\u001F) found while parsing a string at line 3 column 0 [type=json_invalid, input_value='{ "header": {"title": "H...                   \n\n', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid. Retrying
# [2024-04-28 19:57:42,474 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:57:42,476 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for add_static
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'History of Brno', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for add_static
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'History of Brno', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:57:42,478 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for add_static
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'History of Brno', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:57:42,478 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 1 validation error for add_static
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'History of Brno', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 19:58:42,532 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='History of Brno' text='Brno was besieged by the Prussian Army in 1742 under the leadership of Frederick the Great, but the siege was ultimately unsuccessful. In 1777 the bishopric of Brno was established by the Catholic Church; Mathias Franz Graf von Chorinsky Freiherr von Ledske was the first Bishop.\r\n\r\nIn December 1805 the Battle of Austerlitz was fought near the city; the battle is also known as the "Battle of the Three Emperors". Brno itself was not involved with the battle, but the French Emperor Napoleon Bonaparte spent several nights here at that time, and again in 1809.\r\n\r\nIn 1839 the first train arrived in Brno from Vienna; this was the beginning of rail transport in what is now the Czech Republic. In the years 1859-1864 the city fortifications were almost completely removed. In 1869 a horsecar service started to operate in Brno, the first tram service in what would later become the Czech Republic.\r\n\r\nGregor Mendel conducted his groundbreaking experiments in genetics while he was a monk at St. Thomas\'s Abbey in Brno in the 1850s.' brief='Brno has had a rich history, from being besieged by Prussian forces to establishing its own bishopric and playing host to Napoleon Bonaparte. The city also saw the introduction of rail transport and tram services.'
# [2024-04-28 19:58:52,537 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_static'
# [2024-04-28 19:59:14,137 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 19:59:14,139 patch.py->retry_sync():318]ERROR: Retrying, exception: 2 validation errors for add_static
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Climate of Brno', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Weather and Fe...Brno', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 2 validation errors for add_static
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Climate of Brno', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Weather and Fe...Brno', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:59:14,140 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 2 validation errors for add_static
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Climate of Brno', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Weather and Fe...Brno', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 19:59:14,141 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 2 validation errors for add_static
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Climate of Brno', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Weather and Fe...Brno', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 20:00:11,985 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Climate of Brno' text='Under the Köppen climate classification, Brno has an oceanic climate (Cfb) for −3 °C original isoterm, but near of the (−2.5 °C average temperature in January, month most cold) or include by updated classification in humid continental climate (Dfb) with cold winters and warm to hot summers. However, in the last 20 years the temperature has increased, and summer days with temperature above 30 °C (86 °F) are quite common. The average temperature is 9.4 °C (49 °F), the average annual precipitation is about 505 mm (19.88 in), the average number of precipitation days is 150, the average annual sunshine is 1,771 hours, and the prevailing wind direction is northwest. The weather box below shows average data between years 1961 and 1990. Its height above sea level varies from 190 m (623 ft) to 497 m (1,631 ft). The highest peak in the municipal area is the Kopeček Hill (479 m (1,572 ft)), and the highest point overall lies in Útěchov on the border with the municipality of Vranov. ' brief='Brno has an oceanic climate with cold winters and warm to hot summers, and its average temperature is 9.4 °C (49 °F).'
# [2024-04-28 20:00:20,041 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_static'
# [2024-04-28 20:00:40,776 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 20:00:40,779 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for add_static
#   Invalid JSON: EOF while parsing an object at line 45 column 13 [type=json_invalid, input_value='{ "header": {"title": "L...      \n\n             ', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for add_static
#   Invalid JSON: EOF while parsing an object at line 45 column 13 [type=json_invalid, input_value='{ "header": {"title": "L...      \n\n             ', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# [2024-04-28 20:00:40,780 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for add_static
#   Invalid JSON: EOF while parsing an object at line 45 column 13 [type=json_invalid, input_value='{ "header": {"title": "L...      \n\n             ', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid
# [2024-04-28 20:00:40,781 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 1 validation error for add_static
#   Invalid JSON: EOF while parsing an object at line 45 column 13 [type=json_invalid, input_value='{ "header": {"title": "L...      \n\n             ', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/json_invalid. Retrying
# [2024-04-28 20:01:06,785 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 20:01:06,787 patch.py->retry_sync():318]ERROR: Retrying, exception: 3 validation errors for add_static
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'City of Brno L...ends', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Local legends ...all.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Summary of loc...ends', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 3 validation errors for add_static
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'City of Brno L...ends', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Local legends ...all.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Summary of loc...ends', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 20:01:06,788 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 3 validation errors for add_static
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'City of Brno L...ends', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Local legends ...all.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Summary of loc...ends', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 20:01:06,789 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 3 validation errors for add_static
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'City of Brno L...ends', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# text
#   Input should be a valid string [type=string_type, input_value={'title': 'Local legends ...all.', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Input should be a valid string [type=string_type, input_value={'title': 'Summary of loc...ends', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 20:01:24,399 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='City of Brno Legends' text='Local legends connected with the City of Brno. One legend is about a dragon, another one is about a wagon wheel and third about Swedish forces siege.' brief='The city has three famous legends: about a dragon, a wagon wheel and a Swedish siege.'
# [2024-04-28 20:01:32,077 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_static'
# [2024-04-28 20:02:01,264 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 20:02:01,265 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for add_static
# header
# ...
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 21:46:56,060 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 3 validation errors for add_event
# brief
#   Field required [type=missing, input_value={'header': 'Přemysl Hyty...e opportunity to look '}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# address
#   Field required [type=missing, input_value={'header': 'Přemysl Hyty...e opportunity to look '}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# dates
#   Field required [type=missing, input_value={'header': 'Přemysl Hyty...e opportunity to look '}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing. Retrying
# [2024-04-28 21:47:44,901 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:47:44,908 patch.py->retry_sync():318]ERROR: Retrying, exception: 4 validation errors for add_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': "Palace of the ...ject", 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Field required [type=missing, input_value={'header': {'title': "Pal...ew level of meaning."}'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# address
#   Field required [type=missing, input_value={'header': {'title': "Pal...ew level of meaning."}'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# dates
#   Field required [type=missing, input_value={'header': {'title': "Pal...ew level of meaning."}'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 4 validation errors for add_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': "Palace of the ...ject", 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Field required [type=missing, input_value={'header': {'title': "Pal...ew level of meaning."}'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# address
#   Field required [type=missing, input_value={'header': {'title': "Pal...ew level of meaning."}'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# dates
#   Field required [type=missing, input_value={'header': {'title': "Pal...ew level of meaning."}'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 21:47:44,910 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 4 validation errors for add_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': "Palace of the ...ject", 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Field required [type=missing, input_value={'header': {'title': "Pal...ew level of meaning."}'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# address
#   Field required [type=missing, input_value={'header': {'title': "Pal...ew level of meaning."}'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# dates
#   Field required [type=missing, input_value={'header': {'title': "Pal...ew level of meaning."}'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# [2024-04-28 21:47:44,911 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 4 validation errors for add_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': "Palace of the ...ject", 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# brief
#   Field required [type=missing, input_value={'header': {'title': "Pal...ew level of meaning."}'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# address
#   Field required [type=missing, input_value={'header': {'title': "Pal...ew level of meaning."}'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing
# dates
#   Field required [type=missing, input_value={'header': {'title': "Pal...ew level of meaning."}'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/missing. Retrying
# [2024-04-28 21:48:53,407 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:48:53,411 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for add_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Floral object ...ions', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for add_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Floral object ...ions', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 21:48:53,412 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for add_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Floral object ...ions', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 21:48:53,412 api_agent.py->_handle_call_exception():148]ERROR: Error getting JSON format response: 1 validation error for add_event
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Floral object ...ions', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 21:49:04,056 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:49:04,059 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_even...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_even...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 21:49:04,061 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_even...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 21:49:04,061 api_agent.py->_handle_call_exception():148]ERROR: Error getting function call response: 1 validation error for ChosenFunction
# function_name
#   Input should be a valid string [type=string_type, input_value={'description': 'add_even...Name', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Max retries reached. Skipping.
# [2024-04-28 21:49:04,062 api_agent.py->get_function_call():422]ERROR: Error choosing function and schema: not enough values to unpack (expected 2, got 0)
# [2024-04-28 21:49:11,224 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_static'
# [2024-04-28 21:50:06,692 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='ART DESIGN FASHION' text='The building of the Museum of Decorative Arts of the Moravian Gallery has received a new concept in 2021: ART DESIGN FASHION. It foreshadows that the museum is dedicated not only to design itself, but also to fashion and the relationship between design and art. Visitors can look forward to a permanent exhibition, exhibitions and new facilities prepared exclusively for the Moravian Gallery by leading Czech designers. The changed appearance of the Museum of Decorative Arts in Brno represents an imaginary showcase of Czech designers and their products. This multi-layered concept is unparalleled in the Czech Republic in terms of scope and quality.\r\n\r\nWhen designing the interior, the gallery was primarily concerned with incorporating the idea of presenting contemporary designers through their designs for interior elements and spaces. The gallery involved Maxim Velčovský, Radek Wohlmuth and the edit! studio, Eva Eisler, David Karásek, the Olgoj Chorchoj studio and Marek Štěpán.\r\n\r\nCurrent interventions in the exhibition:\r\nKrištof Kintera - Demon of Growth' brief='The Museum of Decorative Arts has received a new concept incorporating art, design, and fashion. The museum features permanent exhibitions, new facilities, and designs from leading Czech designers.'
# [2024-04-28 21:50:44,850 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: function_name='add_static'
# [2024-04-28 21:51:31,272 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:51:31,280 patch.py->retry_sync():318]ERROR: Retrying, exception: 1 validation error for add_static
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Exhibition Int...ions', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# Traceback (most recent call last):
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 309, in retry_sync
#     return process_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/patch.py", line 168, in process_response
#     model = response_model.from_response(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/instructor/function_calls.py", line 175, in from_response
#     return cls.model_validate_json(
#   File "/home/rinaen/PycharmProjects/communication_agent/venv_3_10/lib/python3.10/site-packages/pydantic/main.py", line 561, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
# pydantic_core._pydantic_core.ValidationError: 1 validation error for add_static
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Exhibition Int...ions', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 21:51:31,281 patch.py->retry_sync():345]WARNING: Max retries reached, exception: 1 validation error for add_static
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Exhibition Int...ions', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type
# [2024-04-28 21:51:31,282 api_agent.py->_handle_call_exception():145]ERROR: Error getting JSON format response: 1 validation error for add_static
# header
#   Input should be a valid string [type=string_type, input_value={'title': 'Exhibition Int...ions', 'type': 'string'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.7/v/string_type. Retrying
# [2024-04-28 21:52:19,027 _client.py->_send_single_request():1026]INFO: HTTP Request: POST http://localhost:8881/v1/chat/completions "HTTP/1.1 200 OK"
# Response: header='Exhibition interventions: Marie Filippovová' text='Marie Filippovová represents one of the most prominent figures on the Brno art scene. At first glance, her work impresses with its concentration, sense of rhythm, cyclicality and temporality. To a certain extent, it is also characterised by a certain austerity, or even asceticism. The orderliness with which he completes cycles, sets and volumes of drawings, watercolours and prints, as well as his reliance on lapidary means of expression, is probably related to his deep experience with writing, typography and calligraphy. The generational experience of the artist, who studied free and applied graphics, design and book culture at the Academy of Arts and Crafts in Prague at the turn of the 19...0s and 19...0s, and then settled permanently in Brno, where she began her independent creative career, is also undeniable.' brief='Marie Filippovová represents a prominent figure on the Brno art scene with characteristic concentration and rhythm. Her work often features cycles, sets, and volumes of drawings, watercolours, and prints.'

# %%
gpt3_t, gpt3_p = get_classified(gpt3, df)
# Out:
# [2024-04-28 21:52:21,490 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:52:21,493 api_agent.py->_handle_call_exception():148]ERROR: No function call found in the response.. Max retries reached. Skipping.
# [2024-04-28 21:52:21,494 api_agent.py->_handle_function_call_return():170]ERROR: Error calling function None: 'NoneType' object has no attribute 'name'
# [2024-04-28 21:52:21,495 api_agent.py->_handle_function_call_return_errors():185]ERROR: Could not make function call, max retries reached. Skipping.
# Response: ChatCompletion(id='chatcmpl-9J4rLLbmVnYU5UoMgyabrLb7JLnZE', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```json\n{\n    "header": "Element Restaurant & Bar",\n    "text": "Element combines first-rate food and cocktails. Behind its globally inspired menu from local ingredients stands the well-travelled head chef Tomaš Reger, who has gained culinary experience from around the world. His food is complemented by drinks from champion bartender Jan Liška.",\n    "brief": "An excellent fusion of top-quality meals and original drinks, ideal for a dinner with your partner or friends.",\n    "address": "Běhounská 7"\n}\n```', role='assistant', function_call=None, tool_calls=None))], created=1714333939, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=117, prompt_tokens=818, total_tokens=935))
# [2024-04-28 21:52:23,880 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:52:23,886 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4rOOdIeYENpzn1QXxt9k43MpPI2', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Hostinec U Semináru","text":"\\n“In the mood for a Czech classic with a bit of nostalgia? Search no more!\\" Come taste the magic of the olden days! Smetanova 30 U Semináru is a stylish restaurant with a unique atmosphere, Pilsner beer, and traditional cuisine inspired by the times of the Austro-Hungarian Empire. www.useminaru.cz","brief":"Stylish restaurant with a unique atmosphere, offering Pilsner beer and traditional cuisine inspired by the Austro-Hungarian Empire.","address":"Smetanova 30, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714333942, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=142, prompt_tokens=813, total_tokens=955))
# [2024-04-28 21:52:27,219 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:52:27,222 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4rQbJUzzQpX5xuVHF9GJGww58xp', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Kohout NA VÍNĚ","text":"This restaurant specializes in coq au vin (the Czech translation is the name of the restaurant), with the exact preparation changing and reflecting the chefs’ current ideas and skills. It offers more than 200 wines from around the world, with a primary focus on Moravia and Bohemia. For private celebrations and business events, the restaurant offers two tasting menus with annotated wine pairings.","brief":"Specializes in coq au vin with a wide selection of wines from around the world. Two tasting menus available for private celebrations and business events.","address":"Malinovského náměstí 2"}', name='add_place'), tool_calls=None))], created=1714333944, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=147, prompt_tokens=847, total_tokens=994))
# [2024-04-28 21:52:30,291 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:52:30,294 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4rTwwP7MjhyF2IPCx65we6SAFAe', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"MANYA Sushi & Sake Izakaya","text":"\\"Think you know everything about Japanese cuisine? Then you’re in for a pleasant surprise.\\"\\nNot a bistro or just another sushi bar. This is MANYA – Izakaya! opened the gate to Tokyo at night at Průchodní 2 and pass under Godzilla to share big and small bowls overflowing with Japanese food or delicate sushi, while absorbing the informal atmosphere as well as Japanese sake.","brief":"Japanese Izakaya restaurant offering a unique dining experience with Japanese food, sushi, and sake. Located at Průchodní 2, the restaurant aims to recreate the nightlife atmosphere of Tokyo.","address":"Průchodní 2, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714333947, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=167, prompt_tokens=831, total_tokens=998))
# [2024-04-28 21:52:35,104 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:52:35,106 api_agent.py->_handle_call_exception():148]ERROR: No function call found in the response.. Max retries reached. Skipping.
# [2024-04-28 21:52:35,107 api_agent.py->_handle_function_call_return():170]ERROR: Error calling function None: 'NoneType' object has no attribute 'name'
# [2024-04-28 21:52:35,108 api_agent.py->_handle_function_call_return_errors():185]ERROR: Could not make function call, max retries reached. Skipping.
# Response: ChatCompletion(id='chatcmpl-9J4rW64L1adu9C5UJLsQVIKFl9qBT', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='I will use the `add_place` function for this text since it contains information about a place in Brno serving street food with excellent meat and beverages.\n\nThe text is about Mikrofarma, a place in Brno offering street food with excellent, slowly dry-aged meat by Moravian farmers. They serve cut-up steak in a cone to go, pastrami sandwiches, home-made sauce, brioche burger buns, along with lemonades, good wine, fizzy drinks, and regional draught beer. The address of Mikrofarma is Běhounská 18, and their website is mikrofarma.cz. \n\n```json\n{\n\t"header": "Mikrofarma",\n\t"text": "Mikrofarma is a place in Brno offering street food with excellent, slowly dry-aged meat by Moravian farmers. They serve cut-up steak in a cone to go, pastrami sandwiches, home-made sauce, brioche burger buns, along with lemonades, good wine, fizzy drinks, and regional draught beer.",\n\t"brief": "Mikrofarma offers street food with excellent meat by Moravian farmers, including cut-up steak in a cone, pastrami sandwiches, and a variety of beverages.",\n\t"address": "Běhounská 18"\n}\n```', role='assistant', function_call=None, tool_calls=None))], created=1714333950, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=280, prompt_tokens=844, total_tokens=1124))
# [2024-04-28 21:52:37,664 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:52:37,667 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4rbCccUav9f6LuhabfYhC5w2EVx', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Ramen Brno","text":"Ramen is a quick Japanese meal surprisingly combining popular Czech flavours. Bowls full of home-made noodles are covered in strong broths with variously flavoured oils and topped with marinated eggs, slow-cooked meat, and many other ingredients. Ramen is prepared freshly within a few minutes right before your eyes in an open kitchen. They also have a second location at Křenová 62a.","brief":"Ramen restaurant offering a fusion of Japanese and Czech flavors with home-made noodles and various toppings, prepared freshly in an open kitchen.","address":"Václavská 16, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714333955, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=147, prompt_tokens=865, total_tokens=1012))
# [2024-04-28 21:52:39,659 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:52:39,662 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4rdSkr6wA7cEWP2VT9ElwXG8R7D', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Singha Thai Restaurant","text":"This Thai restaurant in the centre of Brno focuses on fresh, high-quality ingredients that you can watch get turned into works of art by their experienced chefs. Forget all about glutamate! This place also caters to vegetarians, vegans, and the gluten-sensitive.","brief":"Thai restaurant serving fresh, high-quality meals in Brno with options for vegetarians, vegans, and those gluten-sensitive.","address":"Orlí 6"}', name='add_place'), tool_calls=None))], created=1714333957, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=108, prompt_tokens=812, total_tokens=920))
# [2024-04-28 21:52:42,144 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:52:42,146 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4rgPmxyGJTNTtR849TBwwvtFaEZ', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Soul Bistro","text":"A bistro with a soul. A light, clean interior and simple, high-quality food reflecting the season. People come to Soul for breakfast, work lunches, celebratory dinners with friends, and family parties. You’ll find here dishes ranging from fluffy cakes to light salads, excellent fish & chips, and shredded-beef sandwiches.","brief":"A cosy place to spend time with loved ones. Serving high-quality food for breakfast, work lunches, celebratory dinners, and family parties. Menu includes fluffy cakes, light salads, fish & chips, and shredded-beef sandwiches.","address":"Jezuitská 7"}', name='add_place'), tool_calls=None))], created=1714333960, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=143, prompt_tokens=820, total_tokens=963))
# [2024-04-28 21:52:44,429 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:52:44,431 api_agent.py->_handle_call_exception():148]ERROR: No function call found in the response.. Max retries reached. Skipping.
# [2024-04-28 21:52:44,432 api_agent.py->_handle_function_call_return():170]ERROR: Error calling function None: 'NoneType' object has no attribute 'name'
# [2024-04-28 21:52:44,432 api_agent.py->_handle_function_call_return_errors():185]ERROR: Could not make function call, max retries reached. Skipping.
# Response: ChatCompletion(id='chatcmpl-9J4rifvIyYDY56zhB742WAJPKQNG0', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```json\n{\n  "header": "Večerka Brno",\n  "text": "Its name means convenience store in Czech, but you won’t find all kinds of stuff there. In this café bistro on Pekařská Street, the crew bravely combines Czech and Vietnamese cuisines and prepares premium coffee as well as their own kombucha KMBCH coffee.",\n  "brief": "Večerka Brno is a café bistro on Pekařská Street that offers a fusion of Czech and Vietnamese cuisines. They also serve premium coffee and their own kombucha KMBCH coffee.",\n  "address": "Pekařská 9"\n}\n```', role='assistant', function_call=None, tool_calls=None))], created=1714333962, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=144, prompt_tokens=819, total_tokens=963))
# [2024-04-28 21:52:47,190 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:52:47,193 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4rltPUJtnQaYBb1mM2uVJJswrUf', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Cukrárna BezCukru","text":"Cukrárna BezCukru\\n“Delicious desserts for everyone.\\"\\nEverything here feels like a regular cafe.\\nFrom the rich aroma of Coffee Square coffee to the showcased delicacies. Only this is the first low-carb confectionary in Brno, using zero sugar or flour, so even celiac dieters can enjoy it. The small cream puff with a big heart sells best, and the select ingredients used are just the icing on the proverbial cake.","brief":"Low-carb confectionary offering delicious desserts for everyone in Brno, using zero sugar or flour so even celiac dieters can enjoy. Best-selling item is the small cream puff with select ingredients.","address":"Novobranská 4"}', name='add_place'), tool_calls=None))], created=1714333965, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=174, prompt_tokens=834, total_tokens=1008))
# [2024-04-28 21:52:50,225 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:52:50,228 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4rnt0uDCVjL732CCRJMAqQGtyZi', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Cukrářství Martinák","text":"“Discover the sweetest things from Europe thanks to Portuguese pastéis de nata and French canelés. Or stay in the Czech Republic and enjoy the unique věneček. A modern twist on traditions. A modern interpretation of flawless recipes from interwar bakers made of premium ingredients. Looking to please your taste buds? Come and taste their legendary sweet liquor whips, currant krembos or simply amazing, fresh ice cream. Now with some hot new additions for lovers of salty desserts as well!","brief":"Cukrářství Martinák offers a modern twist on traditional European desserts along with unique Czech pastries. They provide a variety of sweet treats made with premium ingredients, including legendary sweet liquor whips, currant krembos, and fresh ice cream. Visitors can also enjoy new additions for lovers of salty desserts.","address":"Veveří 14"}', name='add_place'), tool_calls=None))], created=1714333967, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=206, prompt_tokens=855, total_tokens=1061))
# [2024-04-28 21:52:52,884 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:52:52,887 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4rqWvTALyZEon3YAwGzjqbzQxJL', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Kobliha Brno","text":"This cosy café in the Old Town is a go-to place for doughnut lovers. For six years now, this is where Marek has been successfully fusing traditions with modern trends. Apart from ten types of doughnuts with flavours that change every month, you can enjoy a cup of premium coffee from Father’s Coffee roasters from Ostrava and even bring home a bottle of salted caramel.","brief":"Cosy café in the Old Town known for doughnuts with monthly changing flavors and premium coffee from Father’s Coffee roasters. Offers a variety of doughnut types and a special salted caramel product available for purchase.","address":"Pekařská 68"}', name='add_place'), tool_calls=None))], created=1714333970, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=156, prompt_tokens=847, total_tokens=1003))
# [2024-04-28 21:52:55,721 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:52:55,723 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4rt6zKbHCmeVXCzzoUX0W3IvkRP', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Mlsná holka","text":"A cosy confectionery in the centre of Brno with friendly staff to recommend the best from their wide offering. Leave the Faculty of Medicine to make her business dream come true? That’s Mlsná holka’s story! First a small shop selling doughnuts, now a real confectionary. A place where you can enjoy doughnuts as well as macarons and other authentic desserts. And it even serves premium coffee from the local Fiftybeans coffee roasters.","brief":"Cosy confectionery in the centre of Brno offering a variety of authentic desserts and premium coffee.","address":"Poštovská 1, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714333973, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=156, prompt_tokens=867, total_tokens=1023))
# [2024-04-28 21:52:57,805 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:52:57,807 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4rvfoUUHqddduM4aaZclqazpYAy', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Sorry - pečeme jinak","text":"A beautiful place with delicious cakes to make your head spin and your taste buds rejoice. Get ready for some different, colourful, crazy, funny-yet-serious, and always excellent baking! So much more than just desserts, these pieces of art are a feast for the eyes and ecstasy for the taste buds.","brief":"A beautiful place with delicious cakes offering a unique and excellent baking experience.","address":"Křídlovická 1"}', name='add_place'), tool_calls=None))], created=1714333975, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=112, prompt_tokens=817, total_tokens=929))
# [2024-04-28 21:53:01,438 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:53:01,440 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4ryMURQZLF6uU4x5icKEVK55iIp', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Zemanova cukrárna a kavárna","text":"Located in a functionalist building, protected as a national heritage site, Zemanova cukrárna a kavárna opened its doors in 1937, making it the longest-serving café and confectionary in Brno. It offers traditional Czech desserts, baked goods, premium coffee, over 30 types of local liquors and spirits, as well as specialties like \\"Veletržní dort\\" and baked dragons. The interwar vibe of the place also makes it a perfect venue for occasional cultural events.","brief":"The oldest café and confectionary in Brno, Zemanova cukrárna a kavárna offers traditional Czech desserts, premium coffee, and specialties like \\"Veletržní dort\\" and baked dragons. The café, located in a functionalist building from 1937, hosts cultural events and boasts an interwar ambience.","address":"Josefská 4"}', name='add_place'), tool_calls=None))], created=1714333978, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=212, prompt_tokens=874, total_tokens=1086))
# [2024-04-28 21:53:05,107 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:53:05,110 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4s18sOOhJVJ2wNjMVphzYYzmIxY', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Buchta C","text":"An ideal stop for a quick cup of coffee and something sweet on the Vegetable Market. A younger sister of Buchta B café, this is Zelný trh 10 a small espresso bar hidden in the courtyard at the Vegetable Market. Enjoy its outdoor seating in one of the biggest vertical gardens in the whole country, open year-round. Sweet delicacies are brought here every day from Buchta B to complement their premium coffee from various Czech and European roasting places, or a glass of natural wine made for you by Moravian winemakers.","brief":"Buchta C is a small espresso bar located in the courtyard at the Vegetable Market. It offers premium coffee from Czech and European roasting places, sweet delicacies from Buchta B, and a selection of natural wines from Moravian winemakers. Guests can enjoy outdoor seating in one of the largest vertical gardens in the country.","address":"Zelný trh 10, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714333981, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=214, prompt_tokens=855, total_tokens=1069))
# [2024-04-28 21:53:07,361 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:53:07,363 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4s5fXAHVv4GZ5aEynEEFGkG5M4t', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Café Momenta","text":"Café Momenta offers a luxurious dessert with great coffee and a breathtaking view in the very heart of Brno. The café at Zelný trh 2 provides a pleasant and comfortable experience with a rich aroma of freshly made coffee, a wide range of delicious desserts, and savory snacks.","brief":"Café Momenta offers luxurious desserts, great coffee, and a breathtaking view in Brno.","address":"Zelný trh 2"}', name='add_place'), tool_calls=None))], created=1714333985, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=112, prompt_tokens=858, total_tokens=970))
# [2024-04-28 21:53:11,195 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:53:11,198 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4s7Er024NkeDXknMX4hSB0AfFtV', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Café Placzek","text":"\\"Brunch, a cup of coffee in the afternoon or a drink in the evening at a stylish location.\\" A place to meet up any time of day. From Minoritská 4 a cup of coffee in the morning made from beans from top-quality roasters, alongside home-baked desserts and authentic brunches made with fresh ingredients to mixed drinks or a glass of good wine from local winemakers in the evening. All in a place with an interwar atmosphere and a superb view of the Church of Saint Johns in the very heart of Brno.","brief":"Café Placzek offers a stylish location for brunch, coffee, or drinks at any time of day, featuring top-quality coffee, home-baked desserts, authentic brunches, and local wines. The café boasts an interwar atmosphere and a stunning view of the Church of Saint Johns in the heart of Brno.","address":"Minoritská 4, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714333987, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=216, prompt_tokens=858, total_tokens=1074))
# [2024-04-28 21:53:13,092 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:53:13,093 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4sBAEkkp9bHLUwCg41PnI9QFxbu', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Jazzová kavárna Podobrazy","text":"A classic family-friendly café at an ideal spot in the heart of the Moravian capital. A place with a great vibe to pick you up when you’re feeling blue. Enjoy their premium coffee, savor a cocktail in their year-round outdoor seating, and treat your taste buds to one of their locally made mini desserts.","brief":"Classic family-friendly café with premium coffee, cocktail bar, and locally made mini desserts.","address":"Zelný trh 14"}', name='add_place'), tool_calls=None))], created=1714333991, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=119, prompt_tokens=815, total_tokens=934))
# [2024-04-28 21:53:15,427 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:53:15,429 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4sDUduGsKhMNnLogyLrmEyp0vQC', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Kafe Friedrich","text":"A minimalist, living-room-sized café which prepares all the food and sweets using ingredients that aren’t from the other side of the planet, with the exception of their premium coffee, which will show the other ingredients the wonderful ways of the world. In summer, you can sit down in its window or on a bench and enjoy a moment of sweet laziness.","brief":"A cozy café serving locally sourced food and sweets, with a focus on premium coffee. Customers can enjoy a relaxing atmosphere in the summer.","address":"Smetanova 45"}', name='add_place'), tool_calls=None))], created=1714333993, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=126, prompt_tokens=828, total_tokens=954))
# [2024-04-28 21:53:18,500 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:53:18,504 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4sF9t81qBOO7Ir7R0uwsSvPXM6Q', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Kafe v rozkladu","text":"Welcome to the place where the old blends Veselá 6 with the new, like a cosy visit to grandma’s but with a modern vibe. Where each bite and gulp provide an unusual connection between traditions and fresh combinations. Tasty and colourful cocktails, coffee and breakfast served all day. The birthplace of brinner – breakfast served with an evening twist.","brief":"A cozy cafe where old meets new, offering a modern twist to traditional dishes and drinks. Known for serving tasty and colorful cocktails, coffee, and breakfast all day, including the innovative concept of brinner (breakfast served in the evening).","address":"Veselá 6"}', name='add_place'), tool_calls=None))], created=1714333995, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=154, prompt_tokens=837, total_tokens=991))
# [2024-04-28 21:53:21,471 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:53:21,473 api_agent.py->_handle_call_exception():148]ERROR: No function call found in the response.. Max retries reached. Skipping.
# [2024-04-28 21:53:21,474 api_agent.py->_handle_function_call_return():170]ERROR: Error calling function None: 'NoneType' object has no attribute 'name'
# [2024-04-28 21:53:21,474 api_agent.py->_handle_function_call_return_errors():185]ERROR: Could not make function call, max retries reached. Skipping.
# Response: ChatCompletion(id='chatcmpl-9J4sJyG53V21PP67XG7b46jcT7yi3', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```json\n{\n    "header": "Mitte Panská",\n    "text": "One of the first cafés in Brno to work with premium coffee now has its own roasting place, bakes its own desserts, and has beautiful outdoor seating in a courtyard. Thanks to its wide range of coffee, everyone can find something to suit their palate and even learn about the coffee\'s origins. There are 4 Mitte cafés in Brno.",\n    "brief": "Mitte Panská is one of the first cafés in Brno to specialize in premium coffee, offering its own roasted coffee, homemade desserts, and a charming outdoor seating area. With a wide range of coffees available, visitors can find the perfect option to enjoy while learning about the coffee\'s origins.",\n    "address": "Panská 7, Brno, Czech Republic"\n}\n```', role='assistant', function_call=None, tool_calls=None))], created=1714333999, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=181, prompt_tokens=831, total_tokens=1012))
# [2024-04-28 21:53:23,745 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:53:23,747 api_agent.py->_handle_call_exception():148]ERROR: No function call found in the response.. Max retries reached. Skipping.
# [2024-04-28 21:53:23,748 api_agent.py->_handle_function_call_return():170]ERROR: Error calling function None: 'NoneType' object has no attribute 'name'
# [2024-04-28 21:53:23,748 api_agent.py->_handle_function_call_return_errors():185]ERROR: Could not make function call, max retries reached. Skipping.
# Response: ChatCompletion(id='chatcmpl-9J4sLspLgwmYdxpU2FySlkqZpNCgO', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```json\n{\n  "header": "Punkt Cafe",\n  "text": "A piece of Berlin at a pleasant, quiet place. Here you’ll find espresso and filtered coffees made from premium beans of Czech and foreign roasteries. Coffee specialities and wholesome home-made desserts, with gluten-free and vegan options. The cosy interior and cheerful staff ensure a pleasant experience in any weather.",\n  "brief": "A piece of Berlin at a pleasant, quiet place offering espresso, filtered coffees, coffee specialities, and wholesome home-made desserts with gluten-free and vegan options. The cosy interior and cheerful staff ensure a pleasant experience in any weather.",\n  "address": "Bayerova 7"\n}\n```', role='assistant', function_call=None, tool_calls=None))], created=1714334001, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=146, prompt_tokens=803, total_tokens=949))
# [2024-04-28 21:53:26,612 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:53:26,614 api_agent.py->_handle_call_exception():148]ERROR: No function call found in the response.. Max retries reached. Skipping.
# [2024-04-28 21:53:26,615 api_agent.py->_handle_function_call_return():170]ERROR: Error calling function None: 'NoneType' object has no attribute 'name'
# [2024-04-28 21:53:26,617 api_agent.py->_handle_function_call_return_errors():185]ERROR: Could not make function call, max retries reached. Skipping.
# Response: ChatCompletion(id='chatcmpl-9J4sORhDkJ8wrRJRUHqbrlDDMevos', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```json\n{\n  "header": "QB Coffee Roasters",\n  "text": "An espresso bar and a roasting place producing premium coffee at the premises of a rowing club by the Svratka River. Customers can grab a bag of their premium beans to enjoy at home or savor a coffee with sweet or savory snacks on-site. There are two outdoor seating areas where visitors can relax and soak in the atmosphere surrounded by old docks and an interwar building.",\n  "brief": "QB Coffee Roasters is an espresso bar and roasting place located at the premises of a rowing club by the Svratka River. Offering premium beans for purchase, customers can enjoy coffee and snacks on-site in outdoor seating areas.",\n  "address": "Veslařská 179, Brno, Czech Republic"\n}\n```', role='assistant', function_call=None, tool_calls=None))], created=1714334004, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=171, prompt_tokens=843, total_tokens=1014))
# [2024-04-28 21:53:29,273 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:53:29,274 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4sQpuuuyxIAxCsN72alQ5eW5I5O', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Rebelbean Vlněna","text":"A stylish café with premium coffee from its own roasting place, which is all about quality, sustainability, and fair treatment of farmers. Offering wine by Jan Stávek from Němčičky, a wide range of alcoholic, soft, and coffee-based drinks, as well as a lot of delicacies, sandwiches, and desserts. And a great soup at lunchtime.","brief":"Stylish café with premium coffee, alcoholic and coffee-based drinks, and a variety of delicacies and desserts. Focuses on quality, sustainability, and fair trade. Also serves wine by Jan Stávek.","address":"Přízova 5"}', name='add_place'), tool_calls=None))], created=1714334006, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=156, prompt_tokens=843, total_tokens=999))
# [2024-04-28 21:53:31,559 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:53:31,562 api_agent.py->_handle_call_exception():148]ERROR: No function call found in the response.. Max retries reached. Skipping.
# [2024-04-28 21:53:31,562 api_agent.py->_handle_function_call_return():170]ERROR: Error calling function None: 'NoneType' object has no attribute 'name'
# [2024-04-28 21:53:31,563 api_agent.py->_handle_function_call_return_errors():185]ERROR: Could not make function call, max retries reached. Skipping.
# Response: ChatCompletion(id='chatcmpl-9J4sTua8AxYBn5mfQUlKdNAUyP9Pz', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="This text provides historical information about Brno, Czech Republic, spanning from the 17th to the 19th century. It mentions significant events such as the relocation of the diet and court to Brno during the Thirty Years' War, the siege of Brno by the Prussian Army in 1742, the establishment of the bishopric of Brno in 1777, the Battle of Austerlitz in 1805, the arrival of the first train from Vienna in 1839, the removal of city fortifications, the introduction of horsecar and tram services, and Gregor Mendel's genetic experiments in the 1850s. \n\nI will use the **add_static** function.", role='assistant', function_call=None, tool_calls=None))], created=1714334009, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=146, prompt_tokens=1275, total_tokens=1421))
# [2024-04-28 21:53:37,381 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:53:37,383 api_agent.py->_handle_call_exception():148]ERROR: No function call found in the response.. Max retries reached. Skipping.
# [2024-04-28 21:53:37,384 api_agent.py->_handle_function_call_return():170]ERROR: Error calling function None: 'NoneType' object has no attribute 'name'
# [2024-04-28 21:53:37,385 api_agent.py->_handle_function_call_return_errors():185]ERROR: Could not make function call, max retries reached. Skipping.
# Response: ChatCompletion(id='chatcmpl-9J4sWfqqJeQQsLwirQGk0P516Rhfk', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```json\n{\n  "functions": [\n    {\n      "function": "add_static",\n      "parameters": {\n        "header": "Climate in Brno",\n        "text": "Under the Köppen climate classification, Brno has an oceanic climate (Cfb) for −3 °C original isoterm, but near the (−2.5 °C average temperature in January, month most cold) or include by updated classification in humid continental climate (Dfb) with cold winters and warm to hot summers. The average temperature is 9.4 °C (49 °F), the average annual precipitation is about 505 mm (19.88 in), the average number of precipitation days is 150, the average annual sunshine is 1,771 hours, and the prevailing wind direction is northwest.",\n        "brief": "Information about the climate in Brno including temperature, precipitation, sunshine hours, and wind direction.",\n      }\n    },\n    {\n      "function": "add_place",\n      "parameters": {\n        "header": "Festivals in Brno",\n        "text": "The biggest festival in Brno is the fireworks competition festival, Ignis Brunensis (Latin for \'Flame of Brno\'), held annually in June, part of the \'Brno – City in the Centre of Europe\' festival. Ignis Brunensis is the biggest show of its kind in Central Europe, usually attracting 100,000–200,000 visitors to each display. Other festivals held regularly in Brno include the international film festival Cinema Mundi, Theatre World Brno, International Music Festival Brno, Spilberk International Music Festival, Summer Shakespeare Festival, and the wine festival \'Slavnosti vína\' in September.",\n        "brief": "Overview of the various festivals held in Brno including Ignis Brunensis, Cinema Mundi, Theatre World Brno, International Music Festival, Spilberk International Music Festival, Summer Shakespeare Festival, and the wine festival \'Slavnosti vína.\'",\n        "address": "Brno, Czech Republic"\n      }\n    }\n  ]\n}\n```', role='assistant', function_call=None, tool_calls=None))], created=1714334012, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=434, prompt_tokens=1199, total_tokens=1633))
# [2024-04-28 21:53:43,713 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:53:43,715 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4sbGP0dC114JNcBxbXcJFqQm7NE', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Local Legends of Brno","text":"There are several legends connected with the City of Brno. One of the best known is the Legend of the Brno Dragon. According to this legend, a terrible creature was terrorizing the citizens of Brno. The people had never seen this animal before, so they called it a dragon. They lived in fear of the dragon until one citizen managed to kill the monster by tricking it into eating a carcass filled with lime. In reality the dragon was a crocodile, the preserved body of which is now displayed at the entrance of the Old Town Hall. Crocodile and dragon motifs are common in Brno. A crocodile (Czech: krokodýl) is the local stuffed baguette, and the city radio station is known as Radio Krokodýl. The local baseball team is named Draci Brno (English: Brno Dragons) and the local rugby club is named RC Dragon Brno. There is also a local American football team called the Brno Alligators. An Intercity train connecting Brno and Prague is called Brněnský drak (English: The Brno dragon). Next to the \\"dragon\\" at the Old Town Hall is the town\'s second well-known emblem, a wagon wheel made from a tree found and cut down 50 miles from the city. According to the legend, a local man made a wager that he could fell the tree, make a wheel out of it, and roll the wheel to the City of Brno, all within a single day. Since the achievement was deemed to be impossible by normal human means, the man was believed to have called on the devil for assistance, and died in poverty as a result. Another local legend relates to the siege of the city by Swedish forces in 1645. The locals and the Swedish army were in a stalemate, and the Swedish general declared that he would withdraw if his army had not won by noon. The bell ringer at Petrov Cathedral tricked him by ringing the bell an hour early, and keeping his word, the general and his army left. As a historic tribute to the event, the bell at Petrov Cathedral still rings for noon an hour earlier, at 11 o\'clock. At this time, the Brno astronomical clock also releases a glass ball as a souvenir.","brief":"Information about the local legends of Brno, including the Legend of the Brno Dragon and other significant stories related to the city\'s history and culture."}', name='add_static'), tool_calls=None))], created=1714334017, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=524, prompt_tokens=1342, total_tokens=1866))
# [2024-04-28 21:53:46,048 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:53:46,050 api_agent.py->_handle_call_exception():148]ERROR: No function call found in the response.. Max retries reached. Skipping.
# [2024-04-28 21:53:46,051 api_agent.py->_handle_function_call_return():170]ERROR: Error calling function None: 'NoneType' object has no attribute 'name'
# [2024-04-28 21:53:46,051 api_agent.py->_handle_function_call_return_errors():185]ERROR: Could not make function call, max retries reached. Skipping.
# Response: ChatCompletion(id='chatcmpl-9J4shn7CDmglgA0uN2EYPCRcyH4WT', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```json\n{\n  "header": "Static Information about Brno",\n  "text": "Brno is a city in the Czech Republic with various landmarks and attractions such as Špilberk Castle, Petrov Cathedral, Liberty Square, and the New Town Hall. The city also features the Moravian Gallery, Denis Gardens, the National Theatre, and the Functionalist Agudas Achim Synagogue.",\n  "brief": "Brno is a city rich in history and culture, boasting attractions like Špilberk Castle and the National Theatre. Visitors can explore landmarks such as Petrov Cathedral, Liberty Square, and the Functionalist Agudas Achim Synagogue.",\n}\n```', role='assistant', function_call=None, tool_calls=None))], created=1714334023, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=142, prompt_tokens=996, total_tokens=1138))
# [2024-04-28 21:53:48,565 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:53:48,566 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# ...
# [2024-04-28 21:58:13,644 api_agent.py->_handle_function_call_return():170]ERROR: Error calling function None: 'NoneType' object has no attribute 'name'
# [2024-04-28 21:58:13,645 api_agent.py->_handle_function_call_return_errors():185]ERROR: Could not make function call, max retries reached. Skipping.
# Response: ChatCompletion(id='chatcmpl-9J4x1agzuOaIVV97rnNqOwiS7RktY', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```json\n{\n  "header": "Lady Doctor at Theatre Reduta",\n  "text": "Lady Doctor is a drama play by Robert Icke, focusing on the story of Ruth Wolff, a chief physician at an institute for neurological patients. The play delves into themes of racial and religious prejudice, decision-making in medical ethics, and the consequences of public opinion. The Czech premiere took place on May 25th, 2021, at the Reduta Theatre.",\n  "brief": "Lady Doctor is a drama play by Robert Icke, exploring themes of prejudice and ethics in medical decision-making. The play premiered in the Czech Republic on May 25th, 2021, at the Reduta Theatre.",\n  "address": "Brno, Czech Republic",\n  "dates": "[{\\"start\\": \\"2024-05-02\\", \\"end\\": null}]"\n}\n```', role='assistant', function_call=None, tool_calls=None))], created=1714334291, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=182, prompt_tokens=1379, total_tokens=1561))
# [2024-04-28 21:58:21,219 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:58:21,221 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4x3USy7XeL1GiaAiwGyWQSSDHQb', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content='```arlo Goldoni\nMirandolina\nTheatre Reduta\n\nDominated by masterstrokes of vivacious acting, this dynamic commedia dell´arte gives the audience an intense theatrical experience crowned by astonishing numbers sung by both actors and opera singers. An incredibly sophisticated system of backdrops and drapes enriches the spectators’ visual delight.\nThe peculiar owner of an inn in Florence, as we know her from Carlo Goldoni’s comedy, is a very competent woman who is more versed in business than anybody else.\n\nPremiere: 4th October 2019 at the Reduta Theatre\nProduction team\nAuthor: Carlo Goldoni\nTranslation: Tereza Groszmannová\nDirection: Peter Gábor\nDramaturgy: Hana Hložková\nStage design: Michal Syrový\nCostume design: Tomáš Kypta\nMusic: Mario Buzzi\nSinging cooperation: Petr Svozílek\nMovement cooperation: Jiří Bilbo Reidinger\n\nCast: \n- Vojtěch Blahuta as Hrabě d`Albafiorita\n- Michal Bumbálek as Markýz di Forlipopoli\n- Petr Bláha as Baron di Ripafratta\n- Tereza Groszmannová as Mirandolína, hostinská\n- Petra Lorencová as Ortensia, herečka\n- Jana Štvrtecká as Ortensia, herečka\n- Hana Tomáš Briešťanská as Dejanira, herečka\n- Roman Blumaier as Fabrizio, služebný v hostinci\n- Viktor Kuzník as Sluha barona\n- Tomáš Chudoba as Sluha barona\n\nOverall, the play "Mirandolina" by Carlo Goldoni offers a vibrant and immersive theatrical experience filled with engaging performances and lively storytelling, set in an inn in Florence. With a talented cast and a dedicated production team, this dynamic commedia dell´arte promises to captivate the audience at Theatre Reduta.\n\n"Mirandolina"\nTheatre Reduta\n03/05/2024\n19:00 - 21:50\n```', role='assistant', function_call=FunctionCall(arguments='{"header":"Mirandolina at Theatre Reduta","text":"The play \\"Mirandolina\\" by Carlo Goldoni offers a vibrant and immersive theatrical experience filled with engaging performances and lively storytelling, set in an inn in Florence. With a talented cast and a dedicated production team, this dynamic commedia dell´arte promises to captivate the audience at Theatre Reduta.","brief":"A vibrant and immersive theatrical experience of the play \\"Mirandolina\\" by Carlo Goldoni at Theatre Reduta.","address":"Brno, Czech Republic","dates":"[{\\"start\\":\\"2024-03-05\\",\\"end\\":\\"2024-03-05T21:50:00\\"}]"}', name='add_event'), tool_calls=None))], created=1714334293, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=620, prompt_tokens=1351, total_tokens=1971))
# [2024-04-28 21:58:24,565 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:58:24,567 api_agent.py->_handle_call_exception():148]ERROR: No function call found in the response.. Max retries reached. Skipping.
# [2024-04-28 21:58:24,567 api_agent.py->_handle_function_call_return():170]ERROR: Error calling function None: 'NoneType' object has no attribute 'name'
# [2024-04-28 21:58:24,568 api_agent.py->_handle_function_call_return_errors():185]ERROR: Could not make function call, max retries reached. Skipping.
# Response: ChatCompletion(id='chatcmpl-9J4xBmliuRsHVZykbYFhDj5AwKCMl', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```Jakub Šafránek presents "The Stories of Brno" at Theatre Reduta. The drama performance includes humorous stories and legends about the city of Brno, suitable for children aged 6 and above. The play will be held on multiple dates in April and May 2024 at Theatre Reduta.```\n\nFunctions call:\n```json\n{\n  "header": "The Stories of Brno at Theatre Reduta",\n  "text": "Jakub Šafránek presents \\"The Stories of Brno\\" at Theatre Reduta. The drama performance includes humorous stories and legends about the city of Brno, suitable for children aged 6 and above. The play will be held on multiple dates in April and May 2024 at Theatre Reduta.",\n  "brief": "The Stories of Brno drama performance by Jakub Šafránek at Theatre Reduta.",\n  "address": "Brno, Czech Republic",\n  "dates": "[{\\"start\\": \\"2024-04-28\\"},{\\"start\\": \\"2024-04-30\\"},{\\"start\\": \\"2024-05-05\\"}]"\n}\n```', role='assistant', function_call=None, tool_calls=None))], created=1714334301, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=242, prompt_tokens=1225, total_tokens=1467))
# [2024-04-28 21:58:28,379 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:58:28,381 api_agent.py->_handle_call_exception():148]ERROR: No function call found in the response.. Max retries reached. Skipping.
# [2024-04-28 21:58:28,381 api_agent.py->_handle_function_call_return():170]ERROR: Error calling function None: 'NoneType' object has no attribute 'name'
# [2024-04-28 21:58:28,382 api_agent.py->_handle_function_call_return_errors():185]ERROR: Could not make function call, max retries reached. Skipping.
# Response: ChatCompletion(id='chatcmpl-9J4xEYM5qiMyeiJmRKYD1Cx2eedi9', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The text provides information about the play "Three Sisters" by Anton Pavlovich Chekhov, which will be staged at the Mahen Theatre in Brno. The play follows the story of three sisters - Irina, Masha, and Olga - who face challenges after the death of their father. The production is set to premiere at the Mahen Theatre on October 27th, 2023, directed by Štěpán Pácl.\n\n```json\n{\n  "header": "Three Sisters Play at Mahen Theatre",\n  "text": "The play \'Three Sisters\' by Anton Pavlovich Chekhov will be staged at the Mahen Theatre in Brno. The story follows three sisters facing challenges after the death of their father. The production, directed by Štěpán Pácl, is set to premiere on October 27th, 2023.",\n  "brief": "Information about the upcoming staging of \'Three Sisters\' play at Mahen Theatre in Brno.",\n  "address": "Brno, Czech Republic",\n  "dates": "[{\\"start\\": \\"2023-10-27\\"}]"\n}\n```', role='assistant', function_call=None, tool_calls=None))], created=1714334304, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=242, prompt_tokens=1504, total_tokens=1746))
# [2024-04-28 21:58:32,337 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:58:32,339 api_agent.py->_handle_call_exception():148]ERROR: No function call found in the response.. Max retries reached. Skipping.
# [2024-04-28 21:58:32,340 api_agent.py->_handle_function_call_return():170]ERROR: Error calling function None: 'NoneType' object has no attribute 'name'
# [2024-04-28 21:58:32,340 api_agent.py->_handle_function_call_return_errors():185]ERROR: Could not make function call, max retries reached. Skipping.
# Response: ChatCompletion(id='chatcmpl-9J4xIeLwCfvclUJ2LML2KfDgVSwDZ', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```json\n{\n\t"header": "Floral Object Exhibition by Přemysl Hytych at Palace of the Nobility",\n\t"text": "Florist Přemysl Hytych presents a fashion - floral object - a floral dress inspired by embroidery at the Palace of the Nobility, Chapel of the Purification of the Virgin Mary, Kobližná 1, Brno. The exhibition is part of Brno Art Week 2024 and will be held from April 22 to May 12, 2024. Hytych\'s work is inspired by traditional clothing in Moravia and reflects his personal experience with the collection of the Ethnographic Institute of the MFA.",\n\t"brief": "Floral object exhibition by Přemysl Hytych showcasing a floral dress inspired by Moravian embroidery. The exhibition is part of Brno Art Week 2024 and explores the fusion of tradition and modern design.",\n\t"address": "Kobližná 1, Brno",\n\t"dates": "[{\\"start\\": \\"2024-04-22\\"}, {\\"start\\": \\"2024-05-12\\"}]"\n}\n```', role='assistant', function_call=None, tool_calls=None))], created=1714334308, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=248, prompt_tokens=1006, total_tokens=1254))
# [2024-04-28 21:58:35,729 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:58:35,730 api_agent.py->_handle_call_exception():148]ERROR: No function call found in the response.. Max retries reached. Skipping.
# [2024-04-28 21:58:35,731 api_agent.py->_handle_function_call_return():170]ERROR: Error calling function None: 'NoneType' object has no attribute 'name'
# [2024-04-28 21:58:35,731 api_agent.py->_handle_function_call_return_errors():185]ERROR: Could not make function call, max retries reached. Skipping.
# Response: ChatCompletion(id='chatcmpl-9J4xM966pPUcLmxLfNyq7gVYmdv5X', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```json\n{\n    "header": "Opening of the exhibition Thousand Faces of Amazonia",\n    "text": "The exhibition presents the cultural and natural diversity of the Greater Amazon region and provides insight into the lives of the indigenous inhabitants of this cultural area. What is innovative and remarkable is that it is primarily their own self-representation, meaning that members of local ethnic groups have contributed significantly to the preparation of the exhibition. Visitors will thus learn about their rich culture, understanding of nature, mythology, religion, cosmology and interpretation of the world, customs and rituals.",\n    "brief": "The exhibition presents the cultural and natural diversity of the Greater Amazon region, showcasing the self-representation of local ethnic groups. Visitors will learn about the rich culture, nature, mythology, religion, and customs of the indigenous inhabitants.",\n    "address": "Pisárecká 5, Brno",\n    "dates": "[{\\"start\\": \\"2024-05-16T17:00\\"}]"\n}\n```', role='assistant', function_call=None, tool_calls=None))], created=1714334312, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=205, prompt_tokens=851, total_tokens=1056))
# [2024-04-28 21:58:38,116 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:58:38,119 api_agent.py->_handle_call_exception():148]ERROR: No function call found in the response.. Max retries reached. Skipping.
# [2024-04-28 21:58:38,119 api_agent.py->_handle_function_call_return():170]ERROR: Error calling function None: 'NoneType' object has no attribute 'name'
# [2024-04-28 21:58:38,120 api_agent.py->_handle_function_call_return_errors():185]ERROR: Could not make function call, max retries reached. Skipping.
# Response: ChatCompletion(id='chatcmpl-9J4xPZmdn3roIaH04kYCjYP3k2Zgn', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="I will use the `add_static` function for this text as it contains information about a museum and its new concept. \n\nThe text provides details about the Museum of Decorative Arts in Brno, which has received a new concept in 2021 called ART DESIGN FASHION. This concept focuses on design, fashion, and the relationship between design and art, showcasing permanent exhibitions, new facilities, and designs by leading Czech designers. The museum's changed appearance serves as a showcase for Czech designers and their products, making it a unique and high-quality concept in the Czech Republic.", role='assistant', function_call=None, tool_calls=None))], created=1714334315, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=117, prompt_tokens=966, total_tokens=1083))
# [2024-04-28 21:58:41,271 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:58:41,273 api_agent.py->_handle_call_exception():148]ERROR: No function call found in the response.. Max retries reached. Skipping.
# [2024-04-28 21:58:41,273 api_agent.py->_handle_function_call_return():170]ERROR: Error calling function None: 'NoneType' object has no attribute 'name'
# [2024-04-28 21:58:41,274 api_agent.py->_handle_function_call_return_errors():185]ERROR: Could not make function call, max retries reached. Skipping.
# Response: ChatCompletion(id='chatcmpl-9J4xSVnYRfkO0BGD3oZAWzucGSmzC', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```typescript\nfunctions.add_static({\n    header: "Marie Filippovová - Exhibition Interventions",\n    text: "Marie Filippovová represents one of the most prominent figures on the Brno art scene. Her work impresses with its concentration, sense of rhythm, cyclicality, and temporality. The orderliness with which she completes cycles, sets, and volumes of drawings, watercolours, and prints, as well as her reliance on lapidary means of expression, is probably related to her deep experience with writing, typography, and calligraphy.",\n    brief: "Marie Filippovová is a prominent figure in the Brno art scene known for her work\'s concentration, rhythm, cyclicality, and temporality. Her art is characterized by a sense of austerity and orderliness, influenced by her experience with writing, typography, and calligraphy.",\n});\n```', role='assistant', function_call=None, tool_calls=None))], created=1714334318, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_3b956da36b', usage=CompletionUsage(completion_tokens=186, prompt_tokens=943, total_tokens=1129))

# %%
gpt4_t, gpt4_p = get_classified(gpt4, df)
# Out:
# [2024-04-28 21:58:47,536 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:58:47,538 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4xVwbUCMAf4WQ8Qp6iCOxa4KBNz', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Element Restaurant: Culinary Experience in Brno","text":"“An excellent fusion of top-quality meals and original drinks, ideal for a dinner with your partner or friends.\\" Element combines first-rate food and cocktails. Behind its globally inspired menu from local ingredients stands the well-travelled head chef Tomaš Reger, who has gained culinary experience from around the world. His food is complemented by drinks from champion bartender Jan Liška.","brief":"Element is a restaurant in Brno offering a globally inspired menu prepared from local ingredients by head chef Tomaš Reger. The restaurant is known for its top-quality meals and original cocktails, served by champion bartender Jan Liška. It\'s a perfect spot for dinner with partners or friends.","address":"Běhounská 7, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714334321, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=179, prompt_tokens=818, total_tokens=997))
# [2024-04-28 21:58:58,473 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:58:58,475 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4xcSdoqUV42ZqfUODgYvMW9iyKt', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Hostinec U Semináru","text":"Hostinec U Semináru is a stylish restaurant located at Smetanova 30, specializing in traditional Czech cuisine with an influence from the Austro-Hungarian Empire times. The restaurant offers a unique atmosphere complemented by Pilsner beer and an aura of nostalgia. For more information, visit their website at www.useminaru.cz.","brief":"Hostinec U Semináru is a traditional Czech restaurant in Brno offering a nostalgic atmosphere along with Pilsner beer and dishes inspired by the Austro-Hungarian cuisine.","address":"Smetanova 30"}', name='add_place'), tool_calls=None))], created=1714334328, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_46a93fa712', usage=CompletionUsage(completion_tokens=142, prompt_tokens=813, total_tokens=955))
# [2024-04-28 21:59:06,388 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:59:06,390 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4xmdu4rjymlgFVYMX25qYdoZ52e', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Kohout NA VÍNĚ: A Premier Dining Experience in Brno","text":"Kohout NA VÍNĚ is a restaurant that specializes in coq au vin, which aptly translates to the name of the restaurant in Czech. The chefs at this establishment continually adapt the recipe to showcase their current ideas and culinary skills. The restaurant boasts a selection of over 200 wines from around the world, emphasizing those from Moravia and Bohemia. For those planning private celebrations or business events, Kohout NA VÍNĚ provides two tasting menus, each paired thoughtfully with wines.","brief":"Kohout NA VÍNĚ is a specialized restaurant in Brno offering coq au vin alongside a diverse selection of over 200 global wines, with a focus on local Moravian and Bohemian varieties. It caters to private and business events with tailored tasting menus accompanied by expertly chosen wine pairings. The restaurant is known for its dynamic culinary approach and excellent service.","address":"Malinovského náměstí 2"}', name='add_place'), tool_calls=None))], created=1714334338, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=233, prompt_tokens=847, total_tokens=1080))
# [2024-04-28 21:59:19,725 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:59:19,726 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4xuk95RYAMOqm7HcOCSm9n6jYEQ', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"MANYA Sushi & Sake Izakaya","text":"“Think you know everything about Japanese cuisine? Then you’re in for a pleasant surprise.\\" Not a bistro or just another sushi bar. This is MANYA – Izakaya! opened the gate to Tokyo at night at Průchodní 2 and pass under Godzilla to share big and small bowls overflowing with Japanese food or delicate sushi, while absorbing the informal atmosphere as well as Japanese sake.","brief":"MANYA Sushi & Sake Izakaya is not just a typical sushi bar but a Japanese-inspired Izakaya that offers a unique dining experience in Brno, capturing the nocturnal ambiance of Tokyo. It offers a range of traditional Japanese dishes served in both small and large bowls, accompanied by a variety of sake.","address":"Průchodní 2, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714334346, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_46a93fa712', usage=CompletionUsage(completion_tokens=191, prompt_tokens=831, total_tokens=1022))
# [2024-04-28 21:59:28,940 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:59:28,943 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4y8h436Rm9007zz6LOhSopjR27C', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Mikrofarma: A Paradise for Meat Lovers in Brno","text":"Mikrofarma offers perfectly crafted street food featuring excellent, slowly dry-aged meat sourced from Moravian farmers. It is the only bistro in the area where you can get a cut-up steak in a cone to go. Menu items include pastrami in a sandwich, home-made sauce, and brioche burger buns, all prepared without chemicals. Additionally, they offer lemonades, good wine, fizzy drinks, and regional draught beer.","brief":"Mikrofarma is a unique street food bistro in Brno that specializes in high-quality, dry-aged meats sourced locally. Visitors can enjoy a variety of meat dishes, including a unique steak in a cone, as well as a selection of beverages such as lemonades, wine, and regional beers.","address":"Běhounská 18, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714334360, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=204, prompt_tokens=844, total_tokens=1048))
# [2024-04-28 21:59:39,794 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:59:39,797 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4yH21tSXsY5F4PuOaJLWAkNY74X', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Ramen Brno: Authentic Japanese Cuisine","text":"“No need to head for Japan to get a balanced ramen made of premium ingredients. This is your place now!\\"\\nRamen is a quick Japanese meal surprisingly combining popular Czech flavours. Bowls full of home-made noodles are covered in strong broths with variously flavoured oils and topped with marinated eggs, slow-cooked meat, and many other ingredients. Ramen is prepared freshly within a few minutes right before your eyes in an open kitchen, which is why the owners claim it’s a type of fast food. They also have a second location at Křenová 62a.","brief":"Ramen Brno offers a unique dining experience with its freshly prepared, authentically Japanese ramen that integrates popular Czech flavors. Situated in an open-kitchen setting, guests can watch their meals being made, highlighting its fast-food nature. The restaurant also has a secondary location at Křenová 62a.","address":"Václavská 16, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714334369, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=231, prompt_tokens=865, total_tokens=1096))
# [2024-04-28 21:59:48,055 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:59:48,056 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4ySz7N9mRvPNTSVkqcpFfr5B6Qj', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Singha Thai Restaurant","text":"“Serving fresh meals with a smile while absolutely spoiling you.\\" This Thai restaurant in the centre of Brno focuses on fresh, high-quality ingredients that you can watch get turned into works of art by their experienced chefs. Forget all about glutamate! This place also caters to vegetarians, vegans, and the gluten-sensitive.","brief":"Singha Thai Restaurant offers a variety of freshly prepared meals with an emphasis on high-quality ingredients, free from glutamate. Located in central Brno, the restaurant provides options for vegetarians, vegans, and those sensitive to gluten. It is known for its skilled chefs and artful meal presentations.","address":"Orlí 6, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714334380, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_46a93fa712', usage=CompletionUsage(completion_tokens=163, prompt_tokens=812, total_tokens=975))
# [2024-04-28 21:59:55,018 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 21:59:55,020 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4yaKvIKnSD4tTTbhs2Dnwr5zTwZ', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Soul Bistro","text":"A cosy place to spend time with loved ones.\\nA bistro with a soul. A light, clean interior and simple, high-quality food reflecting the season. People come to Soul for breakfast, work lunches, celebratory dinners with friends, and family parties. You’ll find here dishes ranging from fluffy cakes to light salads, excellent fish & chips, and shredded-beef sandwiches.","brief":"Soul Bistro in Brno offers a diverse menu suitable for breakfasts, work lunches, and celebratory dinners. Its menu features a variety of dishes including fluffy cakes, light salads, fish & chips, and shredded-beef sandwiches, all served in a light and clean environment.","address":"Jezuitská 7, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714334388, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=171, prompt_tokens=820, total_tokens=991))
# [2024-04-28 22:00:02,250 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:00:02,254 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4yh2UPwFsMLy14rrmdUsnhgBB9I', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Večerka Brno: A Fusion Café Bistro","text":"“A perfect fusion of Czech and Vietnamese cuisines at a stylish place.\\" Its name means convenience store in Czech, but you won’t find all kinds of stuff there. In this café bistro on Pekařská Street, the crew bravely combines Czech and Vietnamese cuisines and prepares premium coffee as well as their own kombucha KMBCH coffee.","brief":"Večerka Brno is a café bistro located on Pekařská Street, offering a unique fusion of Czech and Vietnamese cuisines. The place also specializes in premium coffee and their own kombucha called KMBCH coffee. The name \'Večerka\' translates to convenience store in Czech, emphasizing the casual yet diverse offerings.","address":"Pekařská 9"}', name='add_place'), tool_calls=None))], created=1714334395, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=183, prompt_tokens=819, total_tokens=1002))
# [2024-04-28 22:00:12,084 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:00:12,087 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4yoivIPAAPxrFWvUsuyfSuqrmTa', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Cukrárna BezCukru","text":"Cukrárna BezCukru offers a unique dining experience as the first low-carb confectionary in Brno. They specialize in desserts made without sugar or flour, making their offerings suitable for celiac dieters. The cafe features Coffee Square coffee and a variety of delicacies, with the small cream puff being especially popular. Top-quality ingredients underscore the appeal of their menu.","brief":"Cukrárna BezCukru is Brno\'s first low-carb confectionery, making it a haven for those on sugar-free and gluten-free diets. Visitors can enjoy a range of delicacies, including popular cream puffs, complemented by high-quality Coffee Square coffee. Located at Novobranská 4, it merges health with flavor in every dessert.","address":"Novobranská 4, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714334402, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=196, prompt_tokens=834, total_tokens=1030))
# [2024-04-28 22:00:21,679 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:00:21,681 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4yyLTVpleEdMOkjd0M2s6GWYHAX', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Cukrářství Martinák: A Modern Twist on Traditional Desserts","text":"Discover the sweetest things from Europe thanks to Portuguese pastéis de nata and French canelés. Or stay in the Czech Republic and enjoy the unique věneček. A modern interpretation of flawless recipes from interwar bakers made of premium ingredients. Looking to please your taste buds? Come and taste their legendary sweet liquor whips, currant krembos or simply amazing, fresh ice cream. Now with some hot new additions for lovers of salty desserts as well!","brief":"Cukrářství Martinák is a pastry shop offering a mix of traditional European desserts including Portuguese pastéis de nata, French canelés, and Czech věneček. It provides a modern twist on recipes from interwar bakers using premium ingredients. The shop also caters to lovers of both sweet and salty desserts with its range of unique offerings.","address":"Veveří 14, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714334412, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=224, prompt_tokens=855, total_tokens=1079))
# [2024-04-28 22:00:35,365 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:00:35,367 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4z7Vgp9LGAR9fhCJX2XYE2aqTf5', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Kobliha Brno: A Doughnut Lover\'s Delight in the Old Town","text":"“The only problem? Wanting to taste them all, but needing to choose only one.\\" This cosy café in the Old Town is a go-to place for doughnut lovers. For six years now, this is where Marek has been successfully fusing traditions with modern trends. Apart from ten types of doughnuts with flavours that change every month, you can enjoy a cup of premium coffee from Father’s Coffee roasters from Ostrava and even bring home a bottle of salted caramel.","brief":"Kobliha Brno is a popular doughnut café located in the Old Town, renowned for its monthly changing flavors and premium coffee. The café has been in operation for six years and combines traditional methods with modern trends in its offerings. Customers can also purchase unique products like a bottle of salted caramel.","address":"Pekařská 68"}', name='add_place'), tool_calls=None))], created=1714334421, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=206, prompt_tokens=847, total_tokens=1053))
# [2024-04-28 22:00:43,321 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:00:43,323 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4zL3VGak5mkkzBCFS1xPPDVeJal', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Mlsná Holka Confectionery","text":"Mlsná holka is a cosy confectionery located in the centre of Brno, known for its friendly staff who are always ready to recommend the best from their wide selection. Originally starting as a small shop selling doughnuts, it has now expanded into a full-range confectionary offering not just doughnuts but also macarons and other authentic desserts. Additionally, it serves premium coffee sourced from the local Fiftybeans coffee roasters.","brief":"Mlsná holka is a confectionery in Brno known for its cozy atmosphere and wide variety of desserts including doughnuts and macarons. It originally started as a doughnut shop and has since expanded. The confectionery also offers premium coffee from local roasters Fiftybeans.","address":"Poštovská 1"}', name='add_place'), tool_calls=None))], created=1714334435, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=186, prompt_tokens=867, total_tokens=1053))
# [2024-04-28 22:00:50,520 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:00:50,521 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4zTaJSWxUK63IvkHqPleFDY3ePz', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Sorry, pečeme jinak","text":"“A beautiful place with delicious cakes to make your head spin and your taste buds rejoice.\\" Get ready for some different, colourful, crazy, funny-yet-serious, and always excellent baking! So much more than just desserts, these pieces of art are a feast for the eyes and ecstasy for the taste buds.","brief":"Sorry, pečeme jinak is a vibrant bakery known for its unique and delightful cakes. The bakery offers a variety of artistic and delicious desserts that are both visually appealing and tantalizing to the taste buds. It\'s a destination for anyone looking to enjoy high-quality, creative baked goods.","address":"Křídlovická 1, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714334443, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=164, prompt_tokens=817, total_tokens=981))
# [2024-04-28 22:01:00,886 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:01:00,888 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4zbvPy6TQZdyfMk4A7cKQ1FVk7A', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Zemanova cukrárna a kavárna","text":"\\"A trip back to the interwar period in the best possible way.\\"\\nLocated in a functionalist building, protected as a national heritage site, it opened its doors in 1937, making this café and confectionary the longest-serving in Brno. Offering traditional Czech desserts, baked goods, premium coffee, and over 30 types of local liquors and spirits, it boasts several specialties, such as \\"Veletržní dort\\" and baked dragons. And its interwar vibe makes it an ideal place for the cultural events that take place here from time to time.","brief":"Zemanova cukrárna a kavárna, located in a historic functionalist building in Brno, has been in operation since 1937. It offers a wide range of traditional Czech desserts, premium coffee, and local liquors. The café also hosts occasional cultural events, enhancing its interwar atmosphere.","address":"Josefská 4"}', name='add_place'), tool_calls=None))], created=1714334451, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=220, prompt_tokens=874, total_tokens=1094))
# [2024-04-28 22:01:08,747 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:01:08,750 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4zlxLETJEDvn324p85Pd86sXKWX', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Buchta C Café at the Vegetable Market","text":"A younger sister of Buchta B café, this is Zelný trh 10 a small espresso bar hidden in the courtyard at the Vegetable Market. Enjoy its outdoor seating in one of the biggest vertical gardens in the whole country, open year-round. Sweet delicacies are brought here every day from Buchta B to complement their premium coffee from various Czech and European roasting places, or a glass of natural wine made for you by Moravian winemakers.","brief":"Buchta C is a quaint espresso bar located at Zelný trh 10, within a large vertical garden at the Vegetable Market in Brno. It offers an assortment of sweet delicacies sourced daily from its sister café, Buchta B, along with a selection of premium coffees and natural wines from Moravian winemakers. The café is notable for its unique location and its commitment to high-quality, locally sourced products.","address":"Zelný trh 10, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714334461, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=223, prompt_tokens=855, total_tokens=1078))
# [2024-04-28 22:01:15,773 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:01:15,776 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4ztjNcM3oWyMUN1GcOyL8t70rgp', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Café Momenta in Brno","text":"“A luxurious dessert with great coffee and a breathtaking view as the cherry on the top.\\" This charming café in the very heart of Brno at Zelný trh 2 offers a pleasant and comfortable experience. Filled with the rich aroma of freshly made coffee, with a wide range of delicious desserts and savory snacks, this is where you go when in need of a quiet place or a cozy corner to enjoy some time with friends. A place where every moment matters. A place to talk. A place where time slows down.","brief":"Café Momenta, located at Zelný trh 2 in Brno, provides a luxurious dessert experience coupled with excellent coffee and a pleasant ambiance. It offers a variety of delicious desserts and savory snacks perfect for a quiet time or a cozy gathering with friends.","address":"Zelný trh 2, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714334469, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=203, prompt_tokens=858, total_tokens=1061))
# [2024-04-28 22:01:24,312 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:01:24,314 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J4zz5RFs37HrNOyzKMYBovvrf7YB', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Café Placzek","text":"“Brunch, a cup of coffee in the afternoon or a drink in the evening at a stylish location.\\" A place to meet up any time of day. From Minoritská 4 a cup of coffee in the morning made from beans from top-quality roasters, alongside home-baked desserts and authentic brunches made with fresh ingredients to mixed drinks or a glass of good wine from local winemakers in the evening. All in a place with an interwar atmosphere and a superb view of the Church of Saint Johns in the very heart of Brno.","brief":"Café Placzek, located at Minoritská 4 in Brno, offers a variety of experiences throughout the day starting from morning coffees made with top-quality beans to evening drinks including local wine. The café features home-baked desserts and authentic brunches made with fresh ingredients. It enjoys an interwar ambiance and a fantastic view of the Church of Saint Johns.","address":"Minoritská 4, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714334475, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=228, prompt_tokens=858, total_tokens=1086))
# [2024-04-28 22:01:31,276 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:01:31,277 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J508k0hYiuREfzStijB5JF7JuDCS', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Jazzová kavárna Podobrazy","text":"“A classic family-friendly café at an ideal spot in the heart of the Moravian capital.\\" A place with a great vibe to pick you up when you’re feeling blue. Enjoy their premium coffee, savor a cocktail in their year-round outdoor seating, and treat your taste buds to one of their locally made mini desserts.","brief":"Jazzová kavárna Podobrazy is a family-friendly café located in the heart of Brno. It offers premium coffee, cocktails, and locally made mini desserts in a vibrant atmosphere. The café features year-round outdoor seating.","address":"Zelný trh 14, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714334484, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=158, prompt_tokens=815, total_tokens=973))
# [2024-04-28 22:01:37,727 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:01:37,728 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J50FTBtzI2ADhR11kxSu3Xtymgoh', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Kafe Friedrich: A Cozy Spot for Premium Coffee in Brno","text":"Kafe Friedrich offers a perfect cup of coffee served by the nicest staff. This minimalist, living-room-sized café primarily uses local ingredients for its food and sweets, with the notable exception of their premium coffee which is sourced globally. During summer, the café provides seating by its window or on a bench outside, allowing patrons to enjoy moments of sweet laziness.","brief":"Kafe Friedrich is a cozy café in Brno known for its premium coffee and local ingredients. It provides a minimalist, semi-outdoor seating area for a relaxing coffee experience. The café is celebrated for its friendly staff and inviting atmosphere.","address":"Smetanova 45"}', name='add_place'), tool_calls=None))], created=1714334491, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=158, prompt_tokens=828, total_tokens=986))
# [2024-04-28 22:01:44,723 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:01:44,725 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J50Lc6mtt9zK2xY7xypNVm6dpuPC', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Kafe v rozkladu: A Unique Dining Experience in Brno","text":"Welcome to the place where the old blends with the new, like a cosy visit to grandma’s but with a modern vibe. Where each bite and gulp provide an unusual connection between traditions and fresh combinations. Tasty and colourful cocktails, coffee and breakfast served all day. The birthplace of brinner – breakfast served with an evening twist.","brief":"Kafe v rozkladu is a unique café in Brno that combines traditional flavors with modern twists. It offers cocktails, coffee, and all-day breakfast with specialties like \'brinner\', a breakfast served with an evening twist. The ambiance is reminiscent of a cozy visit to grandma\'s house but with a modern approach.","address":"Veselá 6, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714334497, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=179, prompt_tokens=837, total_tokens=1016))
# [2024-04-28 22:01:52,917 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:01:52,918 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J50ShMAqauhb0WSS3UuNCHYCExTY', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Mitte Panská - A Brewed Oasis in Brno","text":"“A brewed oasis in the heart of Brno where they really know their coffee.\\" One of the first cafés in Brno to work with premium coffee now has its own roasting place, bakes its own desserts, and has beautiful outdoor seating in a courtyard. Thanks to its wide range of coffee, everyone can find something to suit their palate and even learn about the coffee\'s origins. There are 4 Mitte cafés in Brno.","brief":"Mitte Panská is one of the pioneering cafés in Brno known for working with premium coffee. It features its own roasting facility, bakes its own desserts, and offers beautiful outdoor seating. The café offers a diverse range of coffee flavors and educates visitors about the origins of their coffee.","address":"Panská 7"}', name='add_place'), tool_calls=None))], created=1714334504, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=191, prompt_tokens=831, total_tokens=1022))
# [2024-04-28 22:01:58,865 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:01:58,867 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J50bMhHGPx9PfvP3lb1MGmzzLtqH', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Punkt Café","text":"A piece of Berlin at a pleasant, quiet place. Here you’ll find espresso and filtered coffees made from premium beans of Czech and foreign roasteries. Coffee specialities and wholesome home-made desserts, with gluten-free and vegan options. The cosy interior and cheerful staff ensure a pleasant experience in any weather.","brief":"Punkt Café offers a Berlin-inspired coffee experience with a selection of espresso and filtered coffees from premium Czech and foreign beans. They serve wholesome home-made desserts, including gluten-free and vegan options, in a cosy and friendly environment.","address":"Bayerova 7, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714334513, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=142, prompt_tokens=803, total_tokens=945))
# [2024-04-28 22:02:05,917 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:02:05,919 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J50hr5M1fdMccNyD4T4lyqjpfALp', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"QB Coffee Roasters","text":"An espresso bar and a roasting place producing premium coffee at the premises of a rowing club by the fizzing Svratka River. Grab a bag of their amazing beans to make your favourite drinks at home or enjoy a coffee and some of their sweet or savoury snacks right there. Relax in one of the two outdoor seating areas and take in the atmosphere of the place, nestled among old docks and an interwar building.","brief":"QB Coffee Roasters offers premium coffee made on-site at a unique location by Svratka River. Customers can buy coffee beans or enjoy drinks and snacks on-site amidst relaxing outdoor seating areas. The shop is situated in a historically rich area near old docks and an interwar building.","address":"Veslařská 179"}', name='add_place'), tool_calls=None))], created=1714334519, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=175, prompt_tokens=843, total_tokens=1018))
# [2024-04-28 22:02:13,464 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:02:13,466 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J50oAm8TC17qA3QPCNMeYL2VMFNs', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Rebelbean Vlněna","text":"“A paradise for those who prefer a café to their office or simply love perfectly prepared coffee.\\" A stylish café with premium coffee from its own roasting place, which is all about quality, sustainability, and fair treatment of farmers. Offering wine by Jan Stávek from Němčičky, a wide range of alcoholic, soft, and coffee-based drinks, as well as a lot of delicacies, sandwiches, and desserts. And a great soup at lunchtime.","brief":"Rebelbean Vlněna is a stylish café in Brno, known for its premium coffee from its own roasting place emphasizing quality and sustainability. It offers a diverse menu including wines by Jan Stávek, various drinks, and a selection of delicacies, sandwiches, and desserts. A notable feature is the excellent soup served at lunchtime.","address":"Přízova 5, Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714334526, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=209, prompt_tokens=843, total_tokens=1052))
# [2024-04-28 22:02:27,084 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:02:27,086 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J50wmuPuVCDH9i0RaRBH60ekMaKc', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Historical Significance of Brno in the 17th and 19th Centuries","text":"In 1641, during the Thirty Years\' War, Ferdinand III, Holy Roman Emperor and Margrave of Moravia, ordered the permanent relocation of the diet, court, and the land tables from Olomouc to Brno, making Brno the sole capital of the Margraviate of Moravia. Brno later successfully defended itself from the Swedish under General Lennart Torstenson, led by Jean-Louis Raduit de Souches. After the war ended in 1648, Brno\'s status was confirmed by further imperial endorsements and the establishment of its bishopric in 1777. The 17th century also saw Špilberk Castle transform into a baroque citadel. The 19th century brought significant developments including the Battle of Austerlitz near Brno in 1805, the arrival of the first train from Vienna in 1839 marking the start of rail transport in the Czech Republic, and the commencement of tram services in 1869. Additionally, Gregor Mendel conducted his crucial genetic experiments at St. Thomas\'s Abbey in Brno during the 1850s.","brief":"Brno played a pivotal role in the 17th and 19th centuries as it transformed into a key administrative and military stronghold. It was during these periods that Brno witnessed the relocation of the Moravian capital from Olomouc, the formidable defense against Swedish sieges, and significant advances in transport and genetics research. The city\'s historical contributions during these times were marked by important events and developments, including the battle of Austerlitz and the pioneering genetic work of Gregor Mendel."}', name='add_static'), tool_calls=None))], created=1714334534, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=370, prompt_tokens=1275, total_tokens=1645))
# [2024-04-28 22:02:36,300 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:02:36,302 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J519mdnjGsOnOdMYcy4sdT3de6BI', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Geographical and Climate Information about Brno","text":"Brno has a climate that closely borders between oceanic (Cfb) and humid continental (Dfb), with cold winters and warm to hot summers. The average temperature in Brno is 9.4 °C, with an annual precipitation of approximately 505 mm, and about 150 days of precipitation annually. The area also enjoys 1,771 hours of sunshine per year, with northwest winds predominantly. Moreover, the temperature trends in the past two decades show a rise, with summer days frequently experiencing temperatures above 30 °C.","brief":"Brno experiences a climate on the borderline between oceanic and humid continental, characterized by cold winters and warm summers, with a rising temperature trend over the past 20 years. The city\'s average temperature is 9.4 °C with an annual precipitation of 505 mm and an average of 1,771 sunshine hours annually. Brno\'s highest point is in Útěchov at 497 meters above sea level."}', name='add_static'), tool_calls=None))], created=1714334547, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=223, prompt_tokens=1199, total_tokens=1422))
# [2024-04-28 22:02:49,714 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:02:49,716 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J51IRJxtmJtMzb0JWD79Q4N6U1v9', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Legends and International Relations of Brno","text":"Brno is rich in folklore and legends, one of the most famous being the Legend of the Brno Dragon. Initially believed to be a dragon terrorizing the locals, it turned out to be a crocodile. Its preserved body is displayed at the Old Town Hall entrance, and the motif of dragons and crocodiles is prevalent in Brno, influencing local teams and even a train service named after the Brno Dragon. Another significant legend is about a wagon wheel and Petrov Cathedral’s bell that rings an hour early in honor of a historical event during the siege by Swedish forces in 1645.\\n\\nBrno maintains international relationships through twinning with cities like Bratislava, Dallas, Debrecen, Kaunas, Kharkiv, Leeds, Leipzig, Poznań, Rennes, Sankt Pölten, and Stuttgart. It also has cooperation agreements with Daejeon, Lviv, Utrecht, and Vienna.","brief":"Brno, a city rich in folklore, features prominent legends such as the Brno Dragon and historical anecdotes such as the Petrov Cathedral bell ringing an hour early. It also boasts various international connections with sister cities across Europe and cooperation agreements with others worldwide. These relations enhance cultural and administrative exchanges between Brno and these cities."}', name='add_static'), tool_calls=None))], created=1714334556, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=284, prompt_tokens=1342, total_tokens=1626))
# [2024-04-28 22:02:58,418 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:02:58,421 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# ...
# [2024-04-28 22:18:41,570 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:18:41,573 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J5GZHUY1B2yJvtTgCeGqmpPTnj6t', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"The Stories of Brno - Theatre Performances","text":"Humorous stories and legends about the city of Brno, presented by an impish storyteller. A play for schoolchildren and their parents, for everyone who enjoys strolling round and about the historic town and discovering its unknown places. Did you know why our city is called Brno? Did you know that long ago a fearsome dragon used to terrify the inhabitants of Líšeň? And that a skilful joiner needed a single day to make a wheel and to transport it from the South-Moravian city of Lednice all the way to Brno? Can you imagine all that may happen when, on a rainy afternoon, three pilgrims meet at a local inn and begin to tell their incredible life stories? You can bet that there are some mischievous tales involved! World premiere: at Reduta Theatre on June 14 th, 2014 Performance length: 65 minutes without intermission This play is suitable for children aged 6 and above.","brief":"The Stories of Brno is a humorous play happening at Theatre Reduta that explores the legends and stories of Brno. Aimed at schoolchildren and their families, the performance includes tales of the city\'s name origin, local legends, and historical anecdotes portrayed humorously. The play lasts 65 minutes and is geared towards children aged 6 and above.","address":"Brno, Czech Republic","dates":"[{\\"start\\": \\"2024-04-28T14:00\\",\\"end\\": \\"2024-04-28T15:15\\"},{\\"start\\": \\"2024-04-30T10:00\\",\\"end\\": \\"2024-04-30T11:15\\"},{\\"start\\": \\"2024-05-05T14:00\\",\\"end\\": \\"2024-05-05T15:15\\"}]"}', name='add_event'), tool_calls=None))], created=1714335503, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=398, prompt_tokens=1225, total_tokens=1623))
# [2024-04-28 22:19:32,357 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:19:32,360 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J5Gsgihf1FkAIx8jB9pG42aDSPi7', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n  "header": "Three Sisters by Anton Pavlovich Chekhov at Mahen Theatre",\n  "text": "Being happy is possible! But maybe at some other place or at some other time \\u2026 After the decease of their father, who provided the whole family with financial support and maintained its thriving social life, the three sisters \\u2013 Irina, Masha and Olga \\u2013 are left all by themselves in their small town and their future is far from being bright. The family house, which used to be attended by renowned guests, now attracts merely eccentrics and outsiders. Soon, their brother dissipates the bequest and the necessity of earning their living makes them loose what aristocrats took for granted: free time. Their desire to live a happy and fuller life, their longing for love and for a new home leads the sisters into extreme situations. Bitter laughter, laughable tears \\u2013 what seems to be ordinary fortunes of common people unlocks great stories of love and adversity. Three Sisters, one of the two plays that Anton Pavlovich Chekhov (1860\\u20131904) wrote specifically for the Moscow Art Theater, is considered to be the Russian playwright\\u2019s masterpiece. The four-act drama had a significant impact on European theater, including the Czech one: performed by the Moscow ensemble in Prague in 1906 it revolutionized the local approach to modern acting and directing. In Brno, Three Sisters will be staged by \\u0160t\\u011bp\\u00e1n P\\u00e1cl, in-house director of the Dramatic Company of the National Theater Brno, whose successful production of Chekhov\\u2019s play The Seagull was adapted into film. Premiere: at Mahen Theater on October 27th, 2023. Production team includes Anton Pavlovich Chekhov as the author, Jaroslav Vostr\\u00fd for translation, and \\u0160t\\u011bp\\u00e1n P\\u00e1cl for direction. Cast roles include Jakub Svojanovsk\\u00fd as Andrej Sergejevi\\u010d Prozorov, Zuzana \\u010cern\\u00e1 as Nata\\u0161a, Kate\\u0159ina Li\\u010f\\u00e1kov\\u00e1 as Olga, and many others.",\n  "brief": "Anton Chekhov\'s \'Three Sisters\' explores the diminished fortunes and complex emotional lives of three sisters after their father\'s death. Directed by \\u0160t\\u011bp\\u00e1n P\\u00e1cl, the play delves into themes of lost happiness and the search for meaning. The production features a comprehensive cast and was translated by Jaroslav Vostr\\u00fd.",\n  "address": "Brno, Czech Republic",\n  "dates": "[{\\"start\\":\\"2024-05-05T17:00:00\\",\\"end\\":\\"2024-05-05T19:45:00\\"}]"\n}', role='assistant', function_call=FunctionCall(arguments='{"header":"Three Sisters by Anton Pavlovich Chekhov at Mahen Theatre","text":"Being happy is possible! But maybe at some other place or at some other time … After the decease of their father, who provided the whole family with financial support and maintained its thriving social life, the three sisters – Irina, Masha and Olga – are left all by themselves in their small town and their future is far from being bright. The family house, which used to be attended by renowned guests, now attracts merely eccentrics and outsiders. Soon, their brother dissipates the bequest and the necessity of earning their living makes them loose what aristocrats took for granted: free time. Their desire to live a happy and fuller life, their longing for love and for a new home leads the sisters into extreme situations. Bitter laughter, laughable tears – what seems to be ordinary fortunes of common people unlocks great stories of love and adversity. Three Sisters, one of the two plays that Anton Pavlovich Chekhov (1860–1904) wrote specifically for the Moscow Art Theater, is considered to be the Russian playwright’s masterpiece. The four-act drama had a significant impact on European theater, including the Czech one: performed by the Moscow ensemb ...
# [2024-04-28 22:21:02,754 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:21:02,756 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J5IgyhabfuiNGTiW1nErbWQKpYXr', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"INTERVENTION. Přemysl Hytych / Floral object","text":"Florist Přemysl Hytych presents a fashion - floral object - a floral dress inspired by embroidery, which attracted him to traditional clothing in Moravia. The author worked on the basis of personal experience with the collection of the Ethnographic Institute of the MFA. The direct contact with the documents of traditional folk culture, as well as the opportunity to look \\"behind the mirror\\", i.e. into the depositories of textiles, were subsequently reflected in his work. He was able to translate the floral motifs from costume embroidery into the plane of fashion and the carnation or tulip flowers thus acquired another dimension. This position is underlined by the colours in the basic tones of red - blue - white as a visual echo of the culture of the Moravian countryside. The accentuation of a simple, seemingly notorious detail evokes the message of the past, which the author has translated into the artistic language of today. The exhibited object takes the relationship between tradition and design to a new level of meaning.","brief":"The floral object exhibition by Přemysl Hytych takes place at the Chapel of the Purification of the Virgin Mary in Brno as part of Brno Art Week 2024. The exhibition features a floral-inspired dress reflecting traditional Moravian embroidery and the connection between traditional culture and modern fashion. The exposition explores deeper meanings within the interplay of design and tradition through intricate floral design and vivid colors.","address":"Palace of the Nobility, Chapel of the Purification of the Virgin Mary, Kobližná 1, Brno","dates":"[{\\"start\\":\\"2024-04-22\\",\\"end\\":\\"2024-05-12\\"}]"}', name='add_event'), tool_calls=None))], created=1714335634, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=375, prompt_tokens=1006, total_tokens=1381))
# [2024-04-28 22:21:14,316 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:21:14,318 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J5J9a8346sNAjiDJA0nV5Ah4Urh3', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Thousand Faces of Amazonia: An Exhibition","text":"The exhibition presents the cultural and natural diversity of the Greater Amazon region and provides insight into the lives of the indigenous inhabitants of this cultural area. What is innovative and remarkable is that it is primarily their own self-representation, meaning that members of local ethnic groups have contributed significantly to the preparation of the exhibition. Visitors will thus learn about their rich culture, understanding of nature, mythology, religion, cosmology and interpretation of the world, customs and rituals.","brief":"The exhibition \\"Thousand Faces of Amazonia\\" explores the cultural and natural diversity of the Amazon through the self-representation of its indigenous people. It offers insights into their culture, nature understanding, mythology, religion, and more, engaging visitors in a deep and meaningful experience. This exhibition is set to open on 16th May 2024 at the Anthropos Pavilion in Brno.","address":"Anthropos Pavilion, Pisárecká 5, Brno","dates":"[{\\"start\\":\\"2024-05-16T17:00\\"}]"}', name='add_event'), tool_calls=None))], created=1714335663, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=230, prompt_tokens=851, total_tokens=1081))
# [2024-04-28 22:21:22,711 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:21:22,713 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J5JK3zrWNDDfzHLDhy64prJ79L0Y', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Museum of Decorative Arts at the Moravian Gallery","text":"The Museum of Decorative Arts of the Moravian Gallery in Brno underwent significant changes in 2021 with a new concept titled ART DESIGN FASHION. This initiative highlights the museum\'s commitment to not only design but also fashion, and the interaction between design and art. The permanent exhibition, featuring works and new installations by leading Czech designers, transforms the museum into a showcase for Czech design excellence. Designers involved in this reconfiguration include Maxim Velčovský, Radek Wohlmuth, edit! studio, Eva Eisler, David Karásek, and the Olgoj Chorchoj studio with Marek Štěpán. Recently, the museum also features interventions by artist Krištof Kintera, particularly his \'Demon of Growth\'.","brief":"The Museum of Decorative Arts in Brno showcases a refreshed concept focussing on ART DESIGN FASHION since 2021. It features both a permanent exhibition and installations by renowned Czech designers, exploring the synergy between design, art, and fashion. Notable recent additions include works by Krištof Kintera.","address":"Brno, Czech Republic"}', name='add_place'), tool_calls=None))], created=1714335674, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=265, prompt_tokens=966, total_tokens=1231))
# [2024-04-28 22:21:33,708 _client.py->_send_single_request():1026]INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2024-04-28 22:21:33,710 api_agent.py->_repair_output_json():249]INFO: Error parsing function arguments to dictionary: dictionary update sequence element #0 has length 1; 2 is required. Handling.
# Response: ChatCompletion(id='chatcmpl-9J5JSsT4eh4xJI61cPMxXHN06gjPo', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=FunctionCall(arguments='{"header":"Exhibition Interventions: Marie Filippovová","text":"Marie Filippovová represents one of the most prominent figures on the Brno art scene. At first glance, her work impresses with its concentration, sense of rhythm, cyclicality and temporality. To a certain extent, it is also characterised by a certain austerity, or even asceticism. The orderliness with which he completes cycles, sets and volumes of drawings, watercolours and prints, as well as his reliance on lapidary means of expression, is probably related to his deep experience with writing, typography and calligraphy. The generational experience of the artist, who studied free and applied graphics, design and book culture at the Academy of Arts and Crafts in Prague at the turn of the 1950s and 1960s, and then settled permanently in Brno, where she began her independent creative career.","brief":"The exhibition showcases the work of Marie Filippovová, a prominent figure in the Brno art scene, known for her rhythmic, cyclic, and temporal artwork. Her disciplined approach to creating cycles of drawings, watercolours, and prints exhibits a deep connection with writing, typography, and calligraphy. Filippovová\'s education in graphics and design in Prague, followed by a significant career in Brno, adds depth to her artistic endeavors.","address":"Pražák Palace, Brno, Czech Republic","dates":"[{\\"start\\": \\"2024-04-19\\"}]"}', name='add_event'), tool_calls=None))], created=1714335682, model='gpt-4-turbo-2024-04-09', object='chat.completion', system_fingerprint='fp_ea6eb70039', usage=CompletionUsage(completion_tokens=324, prompt_tokens=943, total_tokens=1267))

# %%
df['mixtral'] = mixtral_t
df['llama3_70'] = llama3_70_t
df['llama2_70'] = llama2_70_t
df['llama3_8'] = llama3_8_t
df['gpt3'] = gpt3_t
df['gpt4'] = gpt4_t

df['mixtral_parsed'] = mixtral_p
df['llama3_70_parsed'] = llama3_70_p
df['llama2_70_parsed'] = llama2_70_p
df['llama3_8_parsed'] = llama3_8_p
df['gpt3_parsed'] = gpt3_p
df['gpt4_parsed'] = gpt4_p

df.to_csv('divided-function-call.csv')

# %%
df_path = '/home/rinaen/PycharmProjects/communication_agent/testing/divided-function-call.csv'
df = pd.read_csv(df_path)

# %%
df['mixtral_same'] = df['mixtral'] == df['type']
df['llama3_70_same'] = df['llama3_70'] == df['type']
df['llama2_70_same'] = df['llama2_70'] == df['type']
df['llama3_8_same'] = df['llama3_8'] == df['type']
df['gpt3_same'] = df['gpt3'] == df['type']
df['gpt4_same'] = df['gpt4'] == df['type']

# %%
mixtral_same = df['mixtral_same'].sum()
llama3_70_same = df['llama3_70_same'].sum()
llama2_70_same = df['llama2_70_same'].sum()
llama3_8_same = df['llama3_8_same'].sum()
gpt3_same = df['gpt3_same'].sum()
gpt4_same = df['gpt4_same'].sum()

# %%
mixtral_none = df['mixtral'].isna().sum()
llama3_70_none = df['llama3_70'].isna().sum()
llama2_70_none = df['llama2_70'].isna().sum()
llama3_8_none = df['llama3_8'].isna().sum()
gpt3_none = df['gpt3'].isna().sum()
gpt4_none = df['gpt4'].isna().sum()

# %%
place_df = df[df['type'] == 'place']
mixtral_same_place = place_df['mixtral_same'].sum()
llama3_70_same_place = place_df['llama3_70_same'].sum()
llama2_70_same_place = place_df['llama2_70_same'].sum()
llama3_8_same_place = place_df['llama3_8_same'].sum()
gpt3_same_place = place_df['gpt3_same'].sum()
gpt4_same_place = place_df['gpt4_same'].sum()

# %%
static_df = df[df['type'] == 'static']
mixtral_same_static = static_df['mixtral_same'].sum()
llama3_70_same_static = static_df['llama3_70_same'].sum()
llama2_70_same_static = static_df['llama2_70_same'].sum()
llama3_8_same_static = static_df['llama3_8_same'].sum()
gpt3_same_static = static_df['gpt3_same'].sum()
gpt4_same_static = static_df['gpt4_same'].sum()

# %%
administration_df = df[df['type'] == 'administration']
mixtral_same_administration = administration_df['mixtral_same'].sum()
llama3_70_same_administration = administration_df['llama3_70_same'].sum()
llama2_70_same_administration = administration_df['llama2_70_same'].sum()
llama3_8_same_administration = administration_df['llama3_8_same'].sum()
gpt3_same_administration = administration_df['gpt3_same'].sum()
gpt4_same_administration = administration_df['gpt4_same'].sum()

# %%
event_df = df[df['type'] == 'event']
mixtral_same_event = event_df['mixtral_same'].sum()
llama3_70_same_event = event_df['llama3_70_same'].sum()
llama2_70_same_event = event_df['llama2_70_same'].sum()
llama3_8_same_event = event_df['llama3_8_same'].sum()
gpt3_same_event = event_df['gpt3_same'].sum()
gpt4_same_event = event_df['gpt4_same'].sum()

# %%
mixtral_same = str(mixtral_same) + ' %'
llama3_70_same = str(llama3_70_same) + ' %'
llama2_70_same = str(llama2_70_same) + ' %'
llama3_8_same = str(llama3_8_same) + ' %'
gpt3_same = str(gpt3_same) + ' %'
gpt4_same = str(gpt4_same) + ' %'

mixtral_none = str(mixtral_none) + ' %'
llama3_70_none = str(llama3_70_none) + ' %'
llama2_70_none = str(llama2_70_none) + ' %'
llama3_8_none = str(llama3_8_none) + ' %'
gpt3_none = str(gpt3_none) + ' %'
gpt4_none = str(gpt4_none) + ' %'

mixtral_same_place = str(mixtral_same_place / len(place_df) * 100) + ' %'
llama3_70_same_place = str(llama3_70_same_place / len(place_df) * 100) + ' %'
llama2_70_same_place = str(llama2_70_same_place / len(place_df) * 100) + ' %'
llama3_8_same_place = str(llama3_8_same_place / len(place_df) * 100) + ' %'
gpt3_same_place = str(gpt3_same_place / len(place_df) * 100) + ' %'
gpt4_same_place = str(gpt4_same_place / len(place_df) * 100) + ' %'

mixtral_same_static = str(mixtral_same_static / len(static_df) * 100) + ' %'
llama3_70_same_static = str(llama3_70_same_static / len(static_df) * 100) + ' %'
llama2_70_same_static = str(llama2_70_same_static / len(static_df) * 100) + ' %'
llama3_8_same_static = str(llama3_8_same_static / len(static_df) * 100) + ' %'
gpt3_same_static = str(gpt3_same_static / len(static_df) * 100) + ' %'
gpt4_same_static = str(gpt4_same_static / len(static_df) * 100) + ' %'

mixtral_same_administration = str(mixtral_same_administration / len(administration_df) * 100) + ' %'
llama3_70_same_administration = str(llama3_70_same_administration / len(administration_df) * 100) + ' %'
llama2_70_same_administration = str(llama2_70_same_administration / len(administration_df) * 100) + ' %'
llama3_8_same_administration = str(llama3_8_same_administration / len(administration_df) * 100) + ' %'
gpt3_same_administration = str(gpt3_same_administration / len(administration_df) * 100) + ' %'
gpt4_same_administration = str(gpt4_same_administration / len(administration_df) * 100) + ' %'

mixtral_same_event = str(mixtral_same_event / len(event_df) * 100) + ' %'
llama3_70_same_event = str(llama3_70_same_event / len(event_df) * 100) + ' %'
llama2_70_same_event = str(llama2_70_same_event / len(event_df) * 100) + ' %'
llama3_8_same_event = str(llama3_8_same_event / len(event_df) * 100) + ' %'
gpt3_same_event = str(gpt3_same_event / len(event_df) * 100) + ' %'
gpt4_same_event = str(gpt4_same_event / len(event_df) * 100) + ' %'

# %%
eval_df = pd.DataFrame({
    'Model': ['mixtral', 'llama3_70b', 'llama2_70b', 'llama3_8b', 'gpt-3.5', 'gpt-4'],
    'Celkem správně': [mixtral_same, llama3_70_same, llama2_70_same, llama3_8_same, gpt3_same, gpt4_same],
    'Špatný formát': [mixtral_none, llama3_70_none, llama2_70_none, llama3_8_none, gpt3_none, gpt4_none],
    'place': [mixtral_same_place, llama3_70_same_place, llama2_70_same_place, llama3_8_same_place, gpt3_same_place,
              gpt4_same_place],
    'static': [mixtral_same_static, llama3_70_same_static, llama2_70_same_static, llama3_8_same_static,
               gpt3_same_static, gpt4_same_static],
    'administration': [mixtral_same_administration, llama3_70_same_administration, llama2_70_same_administration,
                       llama3_8_same_administration, gpt3_same_administration, gpt4_same_administration],
    'event': [mixtral_same_event, llama3_70_same_event, llama2_70_same_event, llama3_8_same_event, gpt3_same_event,
              gpt4_same_event],
})

eval_df.to_csv('eval_function_call_cls.csv')

# %%
display(eval_df)
# Out:
#         Model Celkem správně Špatný formát    place                static  \
# 0     mixtral           82 %           8 %   96.0 %   56.00000000000001 %
# 1  llama3_70b           80 %           0 %  100.0 %  28.000000000000004 %
# 2  llama2_70b            4 %          96 %    0.0 %                 4.0 %
# 3   llama3_8b           76 %          12 %   92.0 %                88.0 %
# 4     gpt-3.5           42 %          53 %   76.0 %                40.0 %
# 5       gpt-4           90 %           1 %  100.0 %                64.0 %
#
#   administration   event
# 0         88.0 %  88.0 %
# 1        100.0 %  92.0 %
# 2          8.0 %   4.0 %
# 3         92.0 %  32.0 %
# 4         48.0 %   4.0 %
# 5        100.0 %  96.0 %

# %%
mixtral_ok_p = str(df['mixtral_parsed'].notna().sum()) + ' %'
llama3_70_ok_p = str(df['llama3_70_parsed'].notna().sum()) + ' %'
llama2_70_ok_p = str(df['llama2_70_parsed'].notna().sum()) + ' %'
llama3_8_ok_p = str(df['llama3_8_parsed'].notna().sum()) + ' %'
gpt3_ok_p = str(df['gpt3_parsed'].notna().sum()) + ' %'
gpt4_ok_p = str(df['gpt4_parsed'].notna().sum()) + ' %'

# %%
mixtral_ok_p_place = str(df[df['type'] == 'place']['mixtral_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama3_70_ok_p_place = str(df[df['type'] == 'place']['llama3_70_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama2_70_ok_p_place = str(df[df['type'] == 'place']['llama2_70_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama3_8_ok_p_place = str(df[df['type'] == 'place']['llama3_8_parsed'].notna().sum() / len(event_df) * 100) + ' %'
gpt3_ok_p_place = str(df[df['type'] == 'place']['gpt3_parsed'].notna().sum() / len(event_df) * 100) + ' %'
gpt4_ok_p_place = str(df[df['type'] == 'place']['gpt4_parsed'].notna().sum() / len(event_df) * 100) + ' %'

mixtral_ok_p_static = str(df[df['type'] == 'static']['mixtral_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama3_70_ok_p_static = str(df[df['type'] == 'static']['llama3_70_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama2_70_ok_p_static = str(df[df['type'] == 'static']['llama2_70_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama3_8_ok_p_static = str(df[df['type'] == 'static']['llama3_8_parsed'].notna().sum() / len(event_df) * 100) + ' %'
gpt3_ok_p_static = str(df[df['type'] == 'static']['gpt3_parsed'].notna().sum() / len(event_df) * 100) + ' %'
gpt4_ok_p_static = str(df[df['type'] == 'static']['gpt4_parsed'].notna().sum() / len(event_df) * 100) + ' %'

mixtral_ok_p_administration = str(
    df[df['type'] == 'administration']['mixtral_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama3_70_ok_p_administration = str(
    df[df['type'] == 'administration']['llama3_70_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama2_70_ok_p_administration = str(
    df[df['type'] == 'administration']['llama2_70_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama3_8_ok_p_administration = str(
    df[df['type'] == 'administration']['llama3_8_parsed'].notna().sum() / len(event_df) * 100) + ' %'
gpt3_ok_p_administration = str(
    df[df['type'] == 'administration']['gpt3_parsed'].notna().sum() / len(event_df) * 100) + ' %'
gpt4_ok_p_administration = str(
    df[df['type'] == 'administration']['gpt4_parsed'].notna().sum() / len(event_df) * 100) + ' %'

mixtral_ok_p_event = str(df[df['type'] == 'event']['mixtral_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama3_70_ok_p_event = str(df[df['type'] == 'event']['llama3_70_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama2_70_ok_p_event = str(df[df['type'] == 'event']['llama2_70_parsed'].notna().sum() / len(event_df) * 100) + ' %'
llama3_8_ok_p_event = str(df[df['type'] == 'event']['llama3_8_parsed'].notna().sum() / len(event_df) * 100) + ' %'
gpt3_ok_p_event = str(df[df['type'] == 'event']['gpt3_parsed'].notna().sum() / len(event_df) * 100) + ' %'
gpt4_ok_p_event = str(df[df['type'] == 'event']['gpt4_parsed'].notna().sum() / len(event_df) * 100) + ' %'

# %%
mixtral_time = '29m 05s'
llama3_70_time = '116m 32s'
llama2_70_time = '45m 49s'
llama3_8_time = '105m 18s'
gpt3_time = '6m 02s'
gpt4_time = '11m 18s'

# %%
# eval parsing
eval_df = pd.DataFrame({
    'Model': ['mixtral', 'llama3_70b', 'llama2_70b', 'llama3_8b', 'gpt-3.5', 'gpt-4'],
    'Správný formát': [mixtral_ok_p, llama3_70_ok_p, llama2_70_ok_p, llama3_8_ok_p, gpt3_ok_p, gpt4_ok_p],
    'place': [mixtral_ok_p_place, llama3_70_ok_p_place, llama2_70_ok_p_place, llama3_8_ok_p_place, gpt3_ok_p_place,
              gpt4_ok_p_place],
    'static': [mixtral_ok_p_static, llama3_70_ok_p_static, llama2_70_ok_p_static, llama3_8_ok_p_static,
               gpt3_ok_p_static, gpt4_ok_p_static],
    'administration': [mixtral_ok_p_administration, llama3_70_ok_p_administration, llama2_70_ok_p_administration,
                       llama3_8_ok_p_administration, gpt3_ok_p_administration, gpt4_ok_p_administration],
    'event': [mixtral_ok_p_event, llama3_70_ok_p_event, llama2_70_ok_p_event, llama3_8_ok_p_event, gpt3_ok_p_event,
              gpt4_ok_p_event],
    'Čas': [mixtral_time, llama3_70_time, llama2_70_time, llama3_8_time, gpt3_time, gpt4_time]
})

eval_df.to_csv('eval_function_call_par.csv')

# %%
display(eval_df)
# Out:
#         Model Správný formát    place   static administration    event  \
# 0     mixtral           92 %   96.0 %   96.0 %         88.0 %   88.0 %
# 1  llama3_70b          100 %  100.0 %  100.0 %        100.0 %  100.0 %
# 2  llama2_70b            4 %    0.0 %    4.0 %          8.0 %    4.0 %
# 3   llama3_8b           88 %   96.0 %   96.0 %         96.0 %   64.0 %
# 4     gpt-3.5           47 %   76.0 %   60.0 %         48.0 %    4.0 %
# 5       gpt-4           99 %  100.0 %   96.0 %        100.0 %  100.0 %
#
#         Čas
# 0   29m 05s
# 1  116m 32s
# 2   45m 49s
# 3  105m 18s
# 4    6m 02s
# 5   11m 18s
